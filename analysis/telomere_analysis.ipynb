# %% [markdown]
# # Telomere Analysis Pipeline
#
# This notebook is a walkthrough of the **local FASTQ/FASTA pipeline**: it counts canonical and mutant telomere repeat sequences in raw sequencing reads, then plots how mutation rates relate to age and telomere length.
#
# **What's being counted:** each read is scanned for the canonical telomere repeat (`GGGTTA` on the G-strand / `CCCTAA` on the C-strand, repeated `k` times) and for single-base "mutant" variants of that repeat (e.g. `GGGTTA` → `GAGTTA`). The ratio of mutant-to-canonical hits per sample is the mutation signature analyzed below.
#
# **Workflow:**
# 1. **Generate** — scan FASTQ/FASTA files and build a `telomere_analysis_<k>x_repeat.csv` with raw + normalized (per-1k) mutation counts per sample.
# 2. **Plot** — histograms, mutational signatures, Spearman correlations, pairwise heatmap, trendlines, and curve fitting vs. age.
#
# All counting and plotting logic lives in `generate_csv.py` / `plotting.py` / `pattern_generator.py` in this directory — this notebook just calls into them, the same way `main.py`'s CLI does (`python main.py run --k 3 --fastq-dir ...`).
#
# > For the UK Biobank / DNAnexus CRAM pipeline (a different input format with an intentionally different, CRAM-specific detection algorithm), see `ukb/telomere_analysis_ukb_cram_update_fixed.ipynb`.
#
# Edit the **Configuration** cell below to set paths, then run cells in order.

# %%
# Imports
import os
import sys
import time
import threading
from datetime import datetime

if '__file__' in dir():
    _ANALYSIS_DIR = os.path.dirname(os.path.abspath(__file__))
else:
    _cwd = os.getcwd()
    _ANALYSIS_DIR = os.path.join(_cwd, 'analysis') if os.path.isdir(os.path.join(_cwd, 'analysis')) and os.path.basename(_cwd) != 'analysis' else _cwd

if _ANALYSIS_DIR not in sys.path:
    sys.path.insert(0, _ANALYSIS_DIR)

from generate_csv import generate_csv
from plotting import (
    plot_histograms_from_csv,
    plot_mutational_signatures_main,
    plot_spearman_with_age_main,
    plot_pairwise_r_heatmap_main,
    plot_trendlines_main,
    curve_fitting_analysis_main,
    _default_csv_path_from_patterns,
)

# %% [markdown]
# ## Configuration
#
# Set these paths to match your setup. Run from the **analysis** directory or adjust paths accordingly.

# %%
# Number of GGGTTA / CCCTAA repeat units. Single-base modifications are always
# evaluated in the 2nd repeat (e.g. k=3 -> an 18-base canonical pattern).
REPEAT_K = 3

# FASTQ/FASTA input: greider_data_download is a sibling of analysis/ (same level as analysis in the repo)
FASTQ_DIR = os.path.abspath(os.path.join(_ANALYSIS_DIR, "..", "greider_data_download"))
METADATA_PATH = None  # None = auto-detect greider_methods_table_s2_outliers_removed.csv
CSV_OUT = None  # None = auto-derived from REPEAT_K (e.g. telomere_analysis_3x_repeat.csv)

# Outputs
OUTPUT_TXT = os.path.join(_ANALYSIS_DIR, "output.txt")
_TRENDLINES_DIR = os.path.join(_ANALYSIS_DIR, 'trendlines')
_SPEARMAN_CORRELATIONS_DIR = os.path.join(_ANALYSIS_DIR, 'spearman_correlations')
_HISTOGRAM_DIR = os.path.join(_ANALYSIS_DIR, 'histograms')

print("Configuration complete")
print(f"Repeat k            : {REPEAT_K}")
print(f"FASTQ/FASTA dir     : {FASTQ_DIR}")
print(f"Output TXT          : {OUTPUT_TXT}")

# %% [markdown]
# ## Generate CSV
#
# Scans every FASTQ/FASTA file in `FASTQ_DIR`, counts canonical + mutant telomere repeats per sample (pre-screened for a telomeric anchor first, for speed), and writes one combined CSV plus a human-readable `output.txt` run summary.

# %%
print("[1/2] Generating telomere_analysis CSV ...")
print(f"  Repeat k        : {REPEAT_K}")
print(f"  FASTQ/FASTA dir : {FASTQ_DIR}")
print()

output_path = CSV_OUT if CSV_OUT else _default_csv_path_from_patterns(REPEAT_K)

_stop_ticker = threading.Event()

def _ticker(start):
    while not _stop_ticker.is_set():
        elapsed = time.time() - start
        m, s = divmod(int(elapsed), 60)
        h, m = divmod(m, 60)
        print(f'  Elapsed: {h:02d}:{m:02d}:{s:02d}', end='\r', flush=True)
        time.sleep(1)

start_time = time.time()
_ticker_thread = threading.Thread(target=_ticker, args=(start_time,), daemon=True)
_ticker_thread.start()

try:
    csv_path_result = generate_csv(
        data_dir=FASTQ_DIR,
        k=REPEAT_K,
        metadata_file_path=METADATA_PATH,
        output_csv_path=output_path,
        output_txt_path=OUTPUT_TXT,
    )
finally:
    _stop_ticker.set()
    _ticker_thread.join()

elapsed = time.time() - start_time
h, rem = divmod(int(elapsed), 3600)
m, s = divmod(rem, 60)
print(f'  Elapsed: {h:02d}:{m:02d}:{s:02d}  (done)')

csv_path = csv_path_result if csv_path_result else output_path
print(f"CSV written to    : {csv_path}")
if OUTPUT_TXT:
    print(f"Summary written to: {OUTPUT_TXT}")

# %% [markdown]
# ## Plotting
#
# Run all plotting pipelines against the CSV generated above (or set `csv_path` manually if you already have one):
#
# - **Histograms** — mutation rate distributions by 10-year age bin, and total mutations per sample.
# - **Mutational signatures** — per-sample bar chart of which mutation types (G>A, T>C, ...) make up its mutation count.
# - **Spearman scatter plots** — correlation of each mutation-rate column against Age.
# - **Pairwise heatmap** — correlation between mutation types themselves (do certain mutation types co-occur?).
# - **Trendlines** — linear fit of key normalized mutation rates vs. Age.
# - **Curve fitting** — non-linear model fit of telomere length / mutation rate vs. Age.

# %%
print("[2/2] Running plots ...")
os.makedirs(_HISTOGRAM_DIR, exist_ok=True)
plot_histograms_from_csv(csv_path, output_dir=_HISTOGRAM_DIR)
plot_mutational_signatures_main(REPEAT_K)
plot_spearman_with_age_main(REPEAT_K)
plot_pairwise_r_heatmap_main(REPEAT_K)

# Trendlines
def _unique_output_path(directory, base_name, ext):
    os.makedirs(directory, exist_ok=True)
    timestamp = datetime.now().strftime('%Y-%m-%d_%H%M%S')
    return os.path.join(directory, f"{base_name}_{timestamp}.{ext}")

_TRENDLINE_VARIABLES = [
    "total_mutations_over_total_g_strand_per_1k",
    "g_strand_T>C_sum_per_1k",
    "g_strand_G>T_sum_per_1k",
    "g_strand_T>G_sum_per_1k",
]
_TRENDLINE_TITLES = [
    "Total Mutations Normalized",
    "T > C Mutation Rate Normalized",
    "G > T Mutation Rate Normalized",
    "T > G Mutation Rate Normalized",
]
trendline_output = _unique_output_path(_TRENDLINES_DIR, "trendline", "png")
spearman_output = _unique_output_path(_SPEARMAN_CORRELATIONS_DIR, "spearman_correlation", "png")
plot_trendlines_main(csv_path, trendline_output, spearman_output, _TRENDLINE_VARIABLES, _TRENDLINE_TITLES, REPEAT_K)

# Curve fitting
curve_fitting_analysis_main(REPEAT_K)

print("\nAll plotting complete.")
