# %% [markdown]
# # Telomere Analysis Pipeline
#
# **Workflow:**
# 1. **Generate** - Build telomere_analysis CSV from FASTQ/FASTA files
# 2. **Plot** - Run histograms, mutational signatures, Spearman correlations, pairwise heatmap, trendlines, and curve fitting
#
# Edit the **Configuration** cell below to set paths, then run cells in order.

# %%
# Imports
import gzip
import json
from collections import defaultdict
import csv
import os
import numpy as np
import glob
import HTSeq
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.optimize import curve_fit
from scipy import stats
from scipy.stats import spearmanr, linregress
import numbers
from datetime import datetime

# %% [markdown]
# ## Configuration
#
# Set these paths to match your setup. Run from the **analysis** directory or adjust paths accordingly.

# %%
# Configuration - edit these paths.
# _ANALYSIS_DIR: folder containing this notebook (analysis/). Works when run from repo root or from analysis/.
if '__file__' in dir():
    _ANALYSIS_DIR = os.path.dirname(os.path.abspath(__file__))
else:
    _cwd = os.getcwd()
    _ANALYSIS_DIR = os.path.join(_cwd, 'analysis') if os.path.isdir(os.path.join(_cwd, 'analysis')) and os.path.basename(_cwd) != 'analysis' else _cwd

PATTERNS_PATH = os.path.join(_ANALYSIS_DIR, "telomere_patterns_3x.json")
# FASTQ/FASTA input: greider_data_download is a sibling of analysis/ (same level as analysis in the repo)
FASTQ_DIR = os.path.abspath(os.path.join(_ANALYSIS_DIR, "..", "greider_data_download"))
METADATA_PATH = None  # None = auto-detect greider_methods_table_s2_outliers_removed.csv
CSV_OUT = None  # None = auto-derived from patterns version (e.g. telomere_analysis_2x_repeat.csv)

# Output directories (same as main.py)
_TRENDLINES_DIR = os.path.join(_ANALYSIS_DIR, 'trendlines')
_SPEARMAN_CORRELATIONS_DIR = os.path.join(_ANALYSIS_DIR, 'spearman_correlations')
_HISTOGRAM_DIR = os.path.join(_ANALYSIS_DIR, 'histograms')
print("Configuration complete")
# Out:
# Configuration complete

# %% [markdown]
# ## Generate CSV (from generate_csv.py)
#
# Load patterns, count mutations in FASTQ/FASTA files, and write the combined CSV.

# %%
def load_patterns(patterns_file_path):
    """Load patterns and general_mutation_map from the given patterns JSON path."""
    with open(patterns_file_path, 'r') as f:
        data = json.load(f)
    version = data.get('version', 'unknown')
    return data['patterns'], data['general_mutation_map'], version


def read_sequence_file(file_path: str):
    """Read FASTQ or FASTA file and yield sequences."""
    open_func = gzip.open if file_path.endswith('.gz') else open
    mode = 'rt' if file_path.endswith('.gz') else 'r'
    is_fasta = any(ext in file_path.lower() for ext in ['.fasta', '.fa', '.fas'])
    with open_func(file_path, mode) as f:
        if is_fasta:
            current_sequence = ""
            for line in f:
                line = line.strip()
                if line.startswith('>'):
                    if current_sequence:
                        yield current_sequence
                    current_sequence = ""
                else:
                    current_sequence += line
            if current_sequence:
                yield current_sequence
        else:
            while True:
                header = f.readline().strip()
                if not header:
                    break
                sequence = f.readline().strip()
                _ = f.readline()
                _ = f.readline()
                yield sequence


def count_patterns(sequence: str, pattern: str) -> int:
    return sequence.count(pattern)


def count_total_reads(file_path: str) -> int:
    """Count the total number of reads in a FASTQ or FASTA file."""
    count = 0
    for _ in HTSeq.FastqReader(file_path):
        count += 1
    return count


def load_age_data(metadata_file_path=None):
    """Load age data from greider_methods_table_s2_outliers_removed.csv."""
    age_data = {}
    if metadata_file_path is None:
        if os.path.exists('greider_methods_table_s2_outliers_removed.csv'):
            metadata_file_path = 'greider_methods_table_s2_outliers_removed.csv'
        elif os.path.exists('../analysis/greider_methods_table_s2_outliers_removed.csv'):
            metadata_file_path = '../analysis/greider_methods_table_s2_outliers_removed.csv'
        elif os.path.exists('analysis/greider_methods_table_s2_outliers_removed.csv'):
            metadata_file_path = 'analysis/greider_methods_table_s2_outliers_removed.csv'
        else:
            raise FileNotFoundError("greider_methods_table_s2_outliers_removed.csv not found in current directory, analysis directory, or parent directory")
    with open(metadata_file_path, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            fastq_name = row['fastq file name'].replace('_', '.')
            age_data[fastq_name] = row['Age (Years)']
    return age_data


def load_length_data(metadata_file_path=None):
    """Load length data from greider_methods_table_s2_outliers_removed.csv."""
    length_data = {}
    if metadata_file_path is None:
        if os.path.exists('greider_methods_table_s2_outliers_removed.csv'):
            metadata_file_path = 'greider_methods_table_s2_outliers_removed.csv'
        elif os.path.exists('../analysis/greider_methods_table_s2_outliers_removed.csv'):
            metadata_file_path = '../analysis/greider_methods_table_s2_outliers_removed.csv'
        elif os.path.exists('analysis/greider_methods_table_s2_outliers_removed.csv'):
            metadata_file_path = 'analysis/greider_methods_table_s2_outliers_removed.csv'
        else:
            raise FileNotFoundError("greider_methods_table_s2_outliers_removed.csv not found in current directory, analysis directory, or parent directory")
    with open(metadata_file_path, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            fastq_name = row['fastq file name'].replace('_', '.')
            length_data[fastq_name] = row['Mean Telomere Length (bps)']
    return length_data


def get_sequence_files(directory: str):
    """Get all FASTQ and FASTA files in the given directory."""
    sequence_files = []
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fastq")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fastq.gz")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fasta")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fasta.gz")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fa")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fa.gz")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fas")))
    sequence_files.extend(glob.glob(os.path.join(directory, "*.fas.gz")))
    return sorted(sequence_files)

# %%
def generate_csv(
    data_dir: str,
    output_callback=None,
    metadata_file_path=None,
    patterns_file_path=None,
    output_csv_path=None,
):
    """Generate a single CSV file from sequence data containing both raw counts and normalized (per-1k) metrics."""
    if patterns_file_path is None:
        raise ValueError("patterns_file_path is required.")
    patterns, general_mutation_map, patterns_version = load_patterns(patterns_file_path)
    if output_csv_path is None:
        safe_version = patterns_version.replace(' ', '_')
        csv_path = f"telomere_analysis_{safe_version}.csv"
    else:
        csv_path = output_csv_path
        parent = os.path.dirname(csv_path)
        if parent:
            os.makedirs(parent, exist_ok=True)
    sequence_files = get_sequence_files(data_dir)
    if not sequence_files:
        message = f"No FASTQ or FASTA files found in {data_dir} directory"
        print(message)
        if output_callback:
            output_callback(message)
        return
    try:
        age_data = load_age_data(metadata_file_path)
        length_data = load_length_data(metadata_file_path)
    except FileNotFoundError:
        age_data = {}
        length_data = {}
    fieldnames = ['FileName', 'Age', 'Telomere_Length', 'Total_Reads', 'c_strand', 'g_strand']
    mutation_keys = []
    for group in ['g_strand_mutations', 'c_strand_mutations']:
        for subkey in patterns[group].keys():
            mutation_keys.append(f"{group}_{subkey}")
    fieldnames.extend(mutation_keys)
    fieldnames.extend([f"{k}_per_1k" for k in mutation_keys])
    general_mutation_headers = []
    for strand, mutmap in general_mutation_map.items():
        for mut in mutmap:
            general_mutation_headers.append(f"{strand}_{mut}_per_1k")
    fieldnames.extend(general_mutation_headers)
    fieldnames.extend([
        'composite_transition_per_1k', 'composite_transversion_per_1k',
        'g_strand_mutations_sum_per_1k', 'c_strand_mutations_sum_per_1k',
        'log_telomere_length', 'telomere_length_bin', 'mutation_rate_normalized_by_length',
    ])
    summed_per_1k_headers = []
    for strand, mutmap in general_mutation_map.items():
        for mut, subtypes in mutmap.items():
            summed_per_1k_headers.append(f"{strand}_{mut}_sum_per_1k")
    fieldnames.extend(summed_per_1k_headers)
    fieldnames.append('total_mutations_per_1k_strand_specific')
    fieldnames.extend([
        'total_mutations_over_total_g_strand_per_1k',
        'total_mutations_over_total_c_strand_per_1k',
    ])
    with open(csv_path, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for file_path in sequence_files:
            counts = defaultdict(int)
            total_reads = count_total_reads(file_path)
            for sequence in read_sequence_file(file_path):
                counts['c_strand'] += count_patterns(sequence, patterns['c_strand'])
                counts['g_strand'] += count_patterns(sequence, patterns['g_strand'])
                for group in ['g_strand_mutations', 'c_strand_mutations']:
                    for subkey, subpattern in patterns[group].items():
                        counts[f"{group}_{subkey}"] += count_patterns(sequence, subpattern)
            filename = os.path.basename(file_path)
            filename_base = filename
            for ext in ['.fastq.gz', '.fastq', '.fasta.gz', '.fasta', '.fa.gz', '.fa', '.fas.gz', '.fas']:
                if filename_base.endswith(ext):
                    filename_base = filename_base[:-len(ext)]
                    break
            age = age_data.get(filename_base, '')
            length = length_data.get(filename_base, '')
            g_strand_total = counts['g_strand']
            c_strand_total = counts['c_strand']
            g_strand_mutations_total = sum(counts[k] for k in counts if k.startswith('g_strand_mutations_'))
            c_strand_mutations_total = sum(counts[k] for k in counts if k.startswith('c_strand_mutations_'))
            g_strand_normalizer = g_strand_total + g_strand_mutations_total
            c_strand_normalizer = c_strand_total + c_strand_mutations_total
            def per_1k_strand_specific(val, strand_normalizer):
                return (val / strand_normalizer) * 1000 if strand_normalizer > 0 else 0
            def per_1k(val, total):
                return (val / total) * 1000 if total > 0 else 0
            row = {
                'FileName': filename, 'Age': age, 'Telomere_Length': length,
                'Total_Reads': total_reads, 'c_strand': c_strand_total, 'g_strand': g_strand_total,
            }
            for k in mutation_keys:
                row[k] = counts.get(k, 0)
                if k.startswith('g_strand_mutations_'):
                    row[f"{k}_per_1k"] = per_1k_strand_specific(counts.get(k, 0), g_strand_normalizer)
                elif k.startswith('c_strand_mutations_'):
                    row[f"{k}_per_1k"] = per_1k_strand_specific(counts.get(k, 0), c_strand_normalizer)
                else:
                    row[f"{k}_per_1k"] = per_1k_strand_specific(counts.get(k, 0), g_strand_normalizer)
            for strand, mutmap in general_mutation_map.items():
                for mut, subtypes in mutmap.items():
                    total = sum(counts.get(f"{strand}_mutations_{subtype}", 0) for subtype in subtypes)
                    if strand == 'g_strand':
                        row[f"{strand}_{mut}_per_1k"] = per_1k_strand_specific(total, g_strand_normalizer)
                    else:
                        row[f"{strand}_{mut}_per_1k"] = per_1k_strand_specific(total, c_strand_normalizer)
            for strand, mutmap in general_mutation_map.items():
                for mut, subtypes in mutmap.items():
                    per_1k_sum = sum(row.get(f"{strand}_mutations_{subtype}_per_1k", 0) for subtype in subtypes)
                    row[f"{strand}_{mut}_sum_per_1k"] = per_1k_sum
            total_mutations = sum(counts[k] for k in mutation_keys)
            if g_strand_normalizer > 0 or c_strand_normalizer > 0:
                g_weight = g_strand_mutations_total / total_mutations if total_mutations > 0 else 0
                c_weight = c_strand_mutations_total / total_mutations if total_mutations > 0 else 0
                weighted_normalizer = (g_weight * g_strand_normalizer) + (c_weight * c_strand_normalizer)
                row['total_mutations_per_1k_strand_specific'] = per_1k_strand_specific(total_mutations, weighted_normalizer)
            else:
                row['total_mutations_per_1k_strand_specific'] = 0
            row['total_mutations_over_total_g_strand_per_1k'] = per_1k_strand_specific(total_mutations, g_strand_normalizer)
            row['total_mutations_over_total_c_strand_per_1k'] = per_1k_strand_specific(total_mutations, c_strand_normalizer)
            row['g_strand_mutations_sum_per_1k'] = sum(row.get(k, 0) for k in row if k.startswith('g_strand_mutations') and k.endswith('_per_1k'))
            row['c_strand_mutations_sum_per_1k'] = sum(row.get(k, 0) for k in row if k.startswith('c_strand_mutations') and k.endswith('_per_1k'))
            try:
                row['log_telomere_length'] = np.log1p(float(row['Telomere_Length'])) if row['Telomere_Length'] else 0
            except Exception:
                row['log_telomere_length'] = 0
            try:
                length_val = float(row['Telomere_Length'])
                if length_val < 5000:
                    row['telomere_length_bin'] = 'short'
                elif length_val < 8000:
                    row['telomere_length_bin'] = 'medium'
                else:
                    row['telomere_length_bin'] = 'long'
            except Exception:
                row['telomere_length_bin'] = 'unknown'
            try:
                telomere_length = float(row['Telomere_Length'])
                if telomere_length > 0:
                    row['mutation_rate_normalized_by_length'] = row['g_strand_mutations_sum_per_1k'] / telomere_length
                else:
                    row['mutation_rate_normalized_by_length'] = 0
            except Exception:
                row['mutation_rate_normalized_by_length'] = 0
            writer.writerow(row)
            messages = [
                f"\nProcessing {filename}:", f"Age: {age}", f"Telomere Length: {length}",
                f"Total Reads: {total_reads}", f"{patterns_version} c-strand total: {c_strand_total}",
                f"{patterns_version} g-strand total: {g_strand_total}",
                f"G-strand mutations total: {g_strand_mutations_total}",
                f"C-strand mutations total: {c_strand_mutations_total}",
                f"G-strand normalizer ({patterns_version} + mutations): {g_strand_normalizer}",
                f"C-strand normalizer ({patterns_version} + mutations): {c_strand_normalizer}",
                f"Total mutations found: {total_mutations}",
            ]
            if counts['g_strand'] == 0 and counts['c_strand'] == 0:
                messages.append(f"Warning: No telomere sequences found in {filename}")
            for message in messages:
                print(message)
                if output_callback:
                    output_callback(message)
    return csv_path

# %%
# Run generate CSV (equivalent to: main.py generate --patterns ... --fastq-dir ... --metadata ... --csv-out ...)
def _default_csv_path_from_patterns(patterns_file_path):
    """Construct the default telomere_analysis CSV path based on patterns version."""
    with open(patterns_file_path) as f:
        version = json.load(f).get('version', 'unknown')
    safe_version = str(version).replace(' ', '_')
    return os.path.join(_ANALYSIS_DIR, f'telomere_analysis_{safe_version}.csv')

print("[1/2] Generating telomere_analysis CSV ...")
output_path = CSV_OUT if CSV_OUT else _default_csv_path_from_patterns(PATTERNS_PATH)
csv_path_result = generate_csv(
    data_dir=FASTQ_DIR,
    metadata_file_path=METADATA_PATH,
    patterns_file_path=PATTERNS_PATH,
    output_csv_path=output_path,
)
csv_path = csv_path_result if csv_path_result else output_path
print(f"CSV written to: {csv_path}")
# Out:
# [1/2] Generating telomere_analysis CSV ...
#
# Processing JH100.F49.NB67.fastq.gz:
# Age: 22
# Telomere Length: 7188
# Total Reads: 4473
# 3x_repeat c-strand total: 60582
# 3x_repeat g-strand total: 626822
# G-strand mutations total: 39385
# C-strand mutations total: 3083
# G-strand normalizer (3x_repeat + mutations): 666207
# C-strand normalizer (3x_repeat + mutations): 63665
# Total mutations found: 42468
#
# Processing JH101.F47.NB69.fastq.gz:
# Age: 36
# Telomere Length: 6863
# Total Reads: 4091
# 3x_repeat c-strand total: 52252
# 3x_repeat g-strand total: 540563
# G-strand mutations total: 31345
# C-strand mutations total: 3136
# G-strand normalizer (3x_repeat + mutations): 571908
# C-strand normalizer (3x_repeat + mutations): 55388
# Total mutations found: 34481
#
# Processing JH102.F47.NB01.fastq.gz:
# Age: 27
# Telomere Length: 6677
# Total Reads: 7271
# 3x_repeat c-strand total: 91923
# 3x_repeat g-strand total: 991850
# G-strand mutations total: 59486
# C-strand mutations total: 6185
# G-strand normalizer (3x_repeat + mutations): 1051336
# C-strand normalizer (3x_repeat + mutations): 98108
# Total mutations found: 65671
#
# Processing JH103.F48.NB15.fastq.gz:
# Age: 46
# Telomere Length: 5247
# Total Reads: 5361
# 3x_repeat c-strand total: 21899
# 3x_repeat g-strand total: 574497
# G-strand mutations total: 52684
# C-strand mutations total: 1984
# G-strand normalizer (3x_repeat + mutations): 627181
# C-strand normalizer (3x_repeat + mutations): 23883
# Total mutations found: 54668
#
# Processing JH104.F48.NB70.fastq.gz:
# Age: 29
# Telomere Length: 5680
# Total Reads: 5148
# 3x_repeat c-strand total: 28980
# 3x_repeat g-strand total: 502322
# G-strand mutations total: 46546
# C-strand mutations total: 2902
# G-strand normalizer (3x_repeat + mutations): 548868
# C-strand normalizer (3x_repeat + mutations): 31882
# Total mutations found: 49448
#
# Processing JH105.F50.NB19.fastq.gz:
# Age: 25
# Telomere Length: 6427
# Total Reads: 8437
# 3x_repeat c-strand total: 72910
# 3x_repeat g-strand total: 1093235
# G-strand mutations total: 71611
# C-strand mutations total: 5566
# G-strand normalizer (3x_repeat + mutations): 1164846
# C-strand normalizer (3x_repeat + mutations): 78476
# Total mutations found: 77177
#
# Processing JH106.F50.NB65.fastq.gz:
# Age: 38
# Telomere Length: 5602
# Total Reads: 8504
# 3x_repeat c-strand total: 62583
# 3x_repeat g-strand total: 918476
# G-strand mutations total: 62407
# C-strand mutations total: 4564
# G-strand normalizer (3x_repeat + mutations): 980883
# C-strand normalizer (3x_repeat + mutations): 67147
# Total mutations found: 66971
#
# Processing JH109.F53.NB68.fastq.gz:
# Age: 29
# Telomere Length: 5699
# Total Reads: 11989
# 3x_repeat c-strand total: 78089
# 3x_repeat g-strand total: 921741
# G-strand mutations total: 71141
# C-strand mutations total: 4789
# G-strand normalizer (3x_repeat + mutations): 992882
# C-strand normalizer (3x_repeat + mutations): 82878
# Total mutations found: 75930
#
# Processing JH110.F53.NB19.fastq.gz:
# Age: 31
# Telomere Length: 5774
# Total Reads: 7805
# 3x_repeat c-strand total: 53004
# 3x_repeat g-strand total: 650214
# G-strand mutations total: 48143
# C-strand mutations total: 3747
# G-strand normalizer (3x_repeat + mutations): 698357
# C-strand normalizer (3x_repeat + mutations): 56751
# Total mutations found: 51890
#
# Processing JH111.F54.NB88.fastq.gz:
# Age: 31
# Telomere Length: 5767
# Total Reads: 10548
# 3x_repeat c-strand total: 120860
# 3x_repeat g-strand total: 1134368
# G-strand mutations total: 61148
# C-strand mutations total: 5621
# G-strand normalizer (3x_repeat + mutations): 1195516
# C-strand normalizer (3x_repeat + mutations): 126481
# Total mutations found: 66769
#
# Processing JH112.F54.NB65.fastq.gz:
# Age: 62
# Telomere Length: 4877
# Total Reads: 18245
# 3x_repeat c-strand total: 169849
# 3x_repeat g-strand total: 1694160
# G-strand mutations total: 104243
# C-strand mutations total: 9713
# G-strand normalizer (3x_repeat + mutations): 1798403
# C-strand normalizer (3x_repeat + mutations): 179562
# Total mutations found: 113956
#
# Processing JH113.F38.NB67.fastq.gz:
# Age: 52
# Telomere Length: 5459
# Total Reads: 6041
# 3x_repeat c-strand total: 77090
# 3x_repeat g-strand total: 582676
# G-strand mutations total: 40026
# C-strand mutations total: 4669
# G-strand normalizer (3x_repeat + mutations): 622702
# C-strand normalizer (3x_repeat + mutations): 81759
# Total mutations found: 44695
#
# Processing JH114.F55.NB65.fastq.gz:
# Age: 46
# Telomere Length: 4882
# Total Reads: 15380
# 3x_repeat c-strand total: 133481
# 3x_repeat g-strand total: 1126123
# G-strand mutations total: 72120
# C-strand mutations total: 8730
# G-strand normalizer (3x_repeat + mutations): 1198243
# C-strand normalizer (3x_repeat + mutations): 142211
# Total mutations found: 80850
#
# Processing JH115.F55.NB67.fastq.gz:
# Age: 59
# Telomere Length: 4972
# Total Reads: 13495
# 3x_repeat c-strand total: 150540
# 3x_repeat g-strand total: 1143370
# G-strand mutations total: 71039
# C-strand mutations total: 7726
# G-strand normalizer (3x_repeat + mutations): 1214409
# C-strand normalizer (3x_repeat + mutations): 158266
# Total mutations found: 78765
#
# Processing JH116.F56.NB69.fastq.gz:
# Age: 60
# Telomere Length: 4568
# Total Reads: 11891
# 3x_repeat c-strand total: 107901
# 3x_repeat g-strand total: 898192
# G-strand mutations total: 66189
# C-strand mutations total: 7110
# G-strand normalizer (3x_repeat + mutations): 964381
# C-strand normalizer (3x_repeat + mutations): 115011
# Total mutations found: 73299
#
# Processing JH117.F56.NB70.fastq.gz:
# Age: 57
# Telomere Length: 4879
# Total Reads: 16702
# 3x_repeat c-strand total: 154981
# 3x_repeat g-strand total: 1294686
# G-strand mutations total: 91150
# C-strand mutations total: 9827
# G-strand normalizer (3x_repeat + mutations): 1385836
# C-strand normalizer (3x_repeat + mutations): 164808
# Total mutations found: 100977
#
# Processing JH118.F57.NB72.fastq.gz:
# Age: 21
# Telomere Length: 6062
# Total Reads: 8584
# 3x_repeat c-strand total: 58884
# 3x_repeat g-strand total: 739579
# G-strand mutations total: 46273
# C-strand mutations total: 3750
# G-strand normalizer (3x_repeat + mutations): 785852
# C-strand normalizer (3x_repeat + mutations): 62634
# Total mutations found: 50023
#
# Processing JH119.F57.NB01.fastq.gz:
# Age: 33
# Telomere Length: 5926
# Total Reads: 12885
# 3x_repeat c-strand total: 75173
# 3x_repeat g-strand total: 937780
# G-strand mutations total: 61215
# C-strand mutations total: 5083
# G-strand normalizer (3x_repeat + mutations): 998995
# C-strand normalizer (3x_repeat + mutations): 80256
# Total mutations found: 66298
#
# Processing JH120.F58.NB15.fastq.gz:
# Age: 58
# Telomere Length: 4998
# Total Reads: 10759
# 3x_repeat c-strand total: 67461
# 3x_repeat g-strand total: 988536
# G-strand mutations total: 68711
# C-strand mutations total: 4121
# G-strand normalizer (3x_repeat + mutations): 1057247
# C-strand normalizer (3x_repeat + mutations): 71582
# Total mutations found: 72832
#
# Processing JH121.F58.NB19.fastq.gz:
# Age: 22
# Telomere Length: 5046
# Total Reads: 11083
# 3x_repeat c-strand total: 90274
# 3x_repeat g-strand total: 918484
# G-strand mutations total: 66457
# C-strand mutations total: 5829
# G-strand normalizer (3x_repeat + mutations): 984941
# C-strand normalizer (3x_repeat + mutations): 96103
# Total mutations found: 72286
#
# Processing JH122.F38.NB69.fastq.gz:
# Age: 0
# Telomere Length: 7736
# Total Reads: 7261
# 3x_repeat c-strand total: 75305
# 3x_repeat g-strand total: 686777
# G-strand mutations total: 42776
# C-strand mutations total: 4244
# G-strand normalizer (3x_repeat + mutations): 729553
# C-strand normalizer (3x_repeat + mutations): 79549
# Total mutations found: 47020
#
# Processing JH123.F39.NB70.fastq.gz:
# Age: 0
# Telomere Length: 8013
# Total Reads: 11516
# 3x_repeat c-strand total: 97822
# 3x_repeat g-strand total: 927255
# G-strand mutations total: 54757
# C-strand mutations total: 5698
# G-strand normalizer (3x_repeat + mutations): 982012
# C-strand normalizer (3x_repeat + mutations): 103520
# Total mutations found: 60455
#
# Processing JH124.F39.NB72.fastq.gz:
# Age: 0
# Telomere Length: 7671
# Total Reads: 8376
# 3x_repeat c-strand total: 68173
# 3x_repeat g-strand total: 719886
# G-strand mutations total: 42970
# C-strand mutations total: 3685
# G-strand normalizer (3x_repeat + mutations): 762856
# C-strand normalizer (3x_repeat + mutations): 71858
# Total mutations found: 46655
#
# Processing JH125.F59.NB01.fastq.gz:
# Age: 0
# Telomere Length: 7650
# Total Reads: 15856
# 3x_repeat c-strand total: 30315
# 3x_repeat g-strand total: 1053719
# G-strand mutations total: 89606
# C-strand mutations total: 3887
# G-strand normalizer (3x_repeat + mutations): 1143325
# C-strand normalizer (3x_repeat + mutations): 34202
# Total mutations found: 93493
#
# Processing JH126.F59.NB15.fastq.gz:
# Age: 0
# Telomere Length: 8131
# Total Reads: 9620
# 3x_repeat c-strand total: 17264
# 3x_repeat g-strand total: 709898
# G-strand mutations total: 57640
# C-strand mutations total: 1909
# G-strand normalizer (3x_repeat + mutations): 767538
# C-strand normalizer (3x_repeat + mutations): 19173
# Total mutations found: 59549
#
# Processing JH127.F61.NB01.fastq.gz:
# Age: 6
# Telomere Length: 7372
# Total Reads: 6741
# 3x_repeat c-strand total: 59254
# 3x_repeat g-strand total: 926239
# G-strand mutations total: 59427
# C-strand mutations total: 4504
# G-strand normalizer (3x_repeat + mutations): 985666
# C-strand normalizer (3x_repeat + mutations): 63758
# Total mutations found: 63931
#
# Processing JH128.F61.NB02.fastq.gz:
# Age: 7
# Telomere Length: 8015
# Total Reads: 3162
# 3x_repeat c-strand total: 24841
# 3x_repeat g-strand total: 507553
# G-strand mutations total: 31766
# C-strand mutations total: 2093
# G-strand normalizer (3x_repeat + mutations): 539319
# C-strand normalizer (3x_repeat + mutations): 26934
# Total mutations found: 33859
#
# Processing JH129.F61.NB50.fastq.gz:
# Age: 12
# Telomere Length: 7728
# Total Reads: 5971
# 3x_repeat c-strand total: 48948
# 3x_repeat g-strand total: 1035270
# G-strand mutations total: 66772
# C-strand mutations total: 3782
# G-strand normalizer (3x_repeat + mutations): 1102042
# C-strand normalizer (3x_repeat + mutations): 52730
# Total mutations found: 70554
#
# Processing JH130.F61.NB66.fastq.gz:
# Age: 10
# Telomere Length: 7304
# Total Reads: 4333
# 3x_repeat c-strand total: 43652
# 3x_repeat g-strand total: 553271
# G-strand mutations total: 35916
# C-strand mutations total: 3829
# G-strand normalizer (3x_repeat + mutations): 589187
# C-strand normalizer (3x_repeat + mutations): 47481
# Total mutations found: 39745
#
# Processing JH131.F61.NB15.fastq.gz:
# Age: 11
# Telomere Length: 7314
# Total Reads: 3925
# 3x_repeat c-strand total: 35496
# 3x_repeat g-strand total: 580845
# G-strand mutations total: 38260
# C-strand mutations total: 2439
# G-strand normalizer (3x_repeat + mutations): 619105
# C-strand normalizer (3x_repeat + mutations): 37935
# Total mutations found: 40699
#
# Processing JH132.F62.NB15.fastq.gz:
# Age: 10
# Telomere Length: 7618
# Total Reads: 3811
# 3x_repeat c-strand total: 37615
# 3x_repeat g-strand total: 606126
# G-strand mutations total: 37354
# C-strand mutations total: 2608
# G-strand normalizer (3x_repeat + mutations): 643480
# C-strand normalizer (3x_repeat + mutations): 40223
# Total mutations found: 39962
#
# Processing JH133.F62.NB01.fastq.gz:
# Age: 6
# Telomere Length: 7994
# Total Reads: 7240
# 3x_repeat c-strand total: 64791
# 3x_repeat g-strand total: 1109534
# G-strand mutations total: 69037
# C-strand mutations total: 5197
# G-strand normalizer (3x_repeat + mutations): 1178571
# C-strand normalizer (3x_repeat + mutations): 69988
# Total mutations found: 74234
#
# Processing JH134.F62.NB02.fastq.gz:
# Age: 5
# Telomere Length: 8029
# Total Reads: 3680
# 3x_repeat c-strand total: 28308
# 3x_repeat g-strand total: 641105
# G-strand mutations total: 38666
# C-strand mutations total: 2312
# G-strand normalizer (3x_repeat + mutations): 679771
# C-strand normalizer (3x_repeat + mutations): 30620
# Total mutations found: 40978
#
# Processing JH135.F62.NB66.fastq.gz:
# Age: 8
# Telomere Length: 7850
# Total Reads: 4758
# 3x_repeat c-strand total: 45452
# 3x_repeat g-strand total: 710249
# G-strand mutations total: 43750
# C-strand mutations total: 3699
# G-strand normalizer (3x_repeat + mutations): 753999
# C-strand normalizer (3x_repeat + mutations): 49151
# Total mutations found: 47449
#
# Processing JH136.F62.NB50.fastq.gz:
# Age: 11
# Telomere Length: 7491
# Total Reads: 6836
# 3x_repeat c-strand total: 65377
# 3x_repeat g-strand total: 1160313
# G-strand mutations total: 72527
# C-strand mutations total: 4712
# G-strand normalizer (3x_repeat + mutations): 1232840
# C-strand normalizer (3x_repeat + mutations): 70089
# Total mutations found: 77239
#
# Processing JH137.F64.NB01.fastq.gz:
# Age: 0
# Telomere Length: 7975
# Total Reads: 6528
# 3x_repeat c-strand total: 30817
# 3x_repeat g-strand total: 1166827
# G-strand mutations total: 79633
# C-strand mutations total: 2899
# G-strand normalizer (3x_repeat + mutations): 1246460
# C-strand normalizer (3x_repeat + mutations): 33716
# Total mutations found: 82532
#
# Processing JH138.F64.NB02.fastq.gz:
# Age: 0
# Telomere Length: 7896
# Total Reads: 3523
# 3x_repeat c-strand total: 18632
# 3x_repeat g-strand total: 621026
# G-strand mutations total: 42891
# C-strand mutations total: 1924
# G-strand normalizer (3x_repeat + mutations): 663917
# C-strand normalizer (3x_repeat + mutations): 20556
# Total mutations found: 44815
#
# Processing JH139.F64.NB15.fastq.gz:
# Age: 0
# Telomere Length: 7753
# Total Reads: 3656
# 3x_repeat c-strand total: 16786
# 3x_repeat g-strand total: 651772
# G-strand mutations total: 44395
# C-strand mutations total: 1371
# G-strand normalizer (3x_repeat + mutations): 696167
# C-strand normalizer (3x_repeat + mutations): 18157
# Total mutations found: 45766
#
# Processing JH140.F64.NB19.fastq.gz:
# Age: 0
# Telomere Length: 7521
# Total Reads: 3538
# 3x_repeat c-strand total: 22463
# 3x_repeat g-strand total: 471144
# G-strand mutations total: 33480
# C-strand mutations total: 2262
# G-strand normalizer (3x_repeat + mutations): 504624
# C-strand normalizer (3x_repeat + mutations): 24725
# Total mutations found: 35742
#
# Processing JH141.F65.NB20.fastq.gz:
# Age: 0
# Telomere Length: 8136
# Total Reads: 3410
# 3x_repeat c-strand total: 28479
# 3x_repeat g-strand total: 441295
# G-strand mutations total: 27526
# C-strand mutations total: 2042
# G-strand normalizer (3x_repeat + mutations): 468821
# C-strand normalizer (3x_repeat + mutations): 30521
# Total mutations found: 29568
#
# Processing JH142.F65.NB50.fastq.gz:
# Age: 0
# Telomere Length: 8079
# Total Reads: 9728
# 3x_repeat c-strand total: 81435
# 3x_repeat g-strand total: 1141871
# G-strand mutations total: 73079
# C-strand mutations total: 5952
# G-strand normalizer (3x_repeat + mutations): 1214950
# C-strand normalizer (3x_repeat + mutations): 87387
# Total mutations found: 79031
#
# Processing JH143.F65.NB65.fastq.gz:
# Age: 0
# Telomere Length: 8133
# Total Reads: 5080
# 3x_repeat c-strand total: 47384
# 3x_repeat g-strand total: 433895
# G-strand mutations total: 28086
# C-strand mutations total: 4155
# G-strand normalizer (3x_repeat + mutations): 461981
# C-strand normalizer (3x_repeat + mutations): 51539
# Total mutations found: 32241
#
# Processing JH144.F65.NB66.fastq.gz:
# Age: 0
# Telomere Length: 7921
# Total Reads: 4921
# 3x_repeat c-strand total: 28611
# 3x_repeat g-strand total: 599597
# G-strand mutations total: 37463
# C-strand mutations total: 2791
# G-strand normalizer (3x_repeat + mutations): 637060
# C-strand normalizer (3x_repeat + mutations): 31402
# Total mutations found: 40254
#
# Processing JH145.F66.NB67.fastq.gz:
# Age: 0
# Telomere Length: 8214
# Total Reads: 2622
# 3x_repeat c-strand total: 24181
# 3x_repeat g-strand total: 450540
# G-strand mutations total: 27180
# C-strand mutations total: 1340
# G-strand normalizer (3x_repeat + mutations): 477720
# C-strand normalizer (3x_repeat + mutations): 25521
# Total mutations found: 28520
#
# Processing JH146.F66.NB68.fastq.gz:
# Age: 0
# Telomere Length: 8319
# Total Reads: 7123
# 3x_repeat c-strand total: 83425
# 3x_repeat g-strand total: 839414
# G-strand mutations total: 51271
# C-strand mutations total: 6634
# G-strand normalizer (3x_repeat + mutations): 890685
# C-strand normalizer (3x_repeat + mutations): 90059
# Total mutations found: 57905
#
# Processing JH147.F66.NB69.fastq.gz:
# Age: 0
# Telomere Length: 8363
# Total Reads: 2984
# 3x_repeat c-strand total: 23717
# 3x_repeat g-strand total: 484471
# G-strand mutations total: 29026
# C-strand mutations total: 1961
# G-strand normalizer (3x_repeat + mutations): 513497
# C-strand normalizer (3x_repeat + mutations): 25678
# Total mutations found: 30987
#
# Processing JH148.F66.NB70.fastq.gz:
# Age: 0
# Telomere Length: 7959
# Total Reads: 2940
# 3x_repeat c-strand total: 24585
# 3x_repeat g-strand total: 452975
# G-strand mutations total: 26301
# C-strand mutations total: 1823
# G-strand normalizer (3x_repeat + mutations): 479276
# C-strand normalizer (3x_repeat + mutations): 26408
# Total mutations found: 28124
#
# Processing JH149.F66.NB72.fastq.gz:
# Age: 0
# Telomere Length: 8286
# Total Reads: 2584
# 3x_repeat c-strand total: 22302
# 3x_repeat g-strand total: 431063
# G-strand mutations total: 26040
# C-strand mutations total: 1725
# G-strand normalizer (3x_repeat + mutations): 457103
# C-strand normalizer (3x_repeat + mutations): 24027
# Total mutations found: 27765
#
# Processing JH150.F76.NB01.fastq.gz:
# Age: 91
# Telomere Length: 4327
# Total Reads: 11545
# 3x_repeat c-strand total: 46817
# 3x_repeat g-strand total: 582696
# G-strand mutations total: 53786
# C-strand mutations total: 4854
# G-strand normalizer (3x_repeat + mutations): 636482
# C-strand normalizer (3x_repeat + mutations): 51671
# Total mutations found: 58640
#
# Processing JH151.F76.NB50.fastq.gz:
# Age: 89
# Telomere Length: 3921
# Total Reads: 13816
# 3x_repeat c-strand total: 67838
# 3x_repeat g-strand total: 455660
# G-strand mutations total: 43538
# C-strand mutations total: 6686
# G-strand normalizer (3x_repeat + mutations): 499198
# C-strand normalizer (3x_repeat + mutations): 74524
# Total mutations found: 50224
#
# Processing JH152.F76.NB66.fastq.gz:
# Age: 87
# Telomere Length: 4955
# Total Reads: 7570
# 3x_repeat c-strand total: 31126
# 3x_repeat g-strand total: 379963
# G-strand mutations total: 34113
# C-strand mutations total: 3636
# G-strand normalizer (3x_repeat + mutations): 414076
# C-strand normalizer (3x_repeat + mutations): 34762
# Total mutations found: 37749
#
# Processing JH153.F76.NB15.fastq.gz:
# Age: 86
# Telomere Length: 4192
# Total Reads: 7458
# 3x_repeat c-strand total: 26078
# 3x_repeat g-strand total: 319473
# G-strand mutations total: 30258
# C-strand mutations total: 2595
# G-strand normalizer (3x_repeat + mutations): 349731
# C-strand normalizer (3x_repeat + mutations): 28673
# Total mutations found: 32853
#
# Processing JH154.F77.NB01.fastq.gz:
# Age: 83
# Telomere Length: 5173
# Total Reads: 11875
# 3x_repeat c-strand total: 29880
# 3x_repeat g-strand total: 452627
# G-strand mutations total: 43479
# C-strand mutations total: 2629
# G-strand normalizer (3x_repeat + mutations): 496106
# C-strand normalizer (3x_repeat + mutations): 32509
# Total mutations found: 46108
#
# Processing JH155.F77.NB66.fastq.gz:
# Age: 82
# Telomere Length: 4286
# Total Reads: 9595
# 3x_repeat c-strand total: 24564
# 3x_repeat g-strand total: 361311
# G-strand mutations total: 35682
# C-strand mutations total: 2883
# G-strand normalizer (3x_repeat + mutations): 396993
# C-strand normalizer (3x_repeat + mutations): 27447
# Total mutations found: 38565
#
# Processing JH156.F77.NB15.fastq.gz:
# Age: 82
# Telomere Length: 5236
# Total Reads: 4595
# 3x_repeat c-strand total: 11675
# 3x_repeat g-strand total: 207924
# G-strand mutations total: 20597
# C-strand mutations total: 1496
# G-strand normalizer (3x_repeat + mutations): 228521
# C-strand normalizer (3x_repeat + mutations): 13171
# Total mutations found: 22093
#
# Processing JH157.F78.NB01.fastq.gz:
# Age: 82
# Telomere Length: 4375
# Total Reads: 7626
# 3x_repeat c-strand total: 24240
# 3x_repeat g-strand total: 344410
# G-strand mutations total: 34948
# C-strand mutations total: 2862
# G-strand normalizer (3x_repeat + mutations): 379358
# C-strand normalizer (3x_repeat + mutations): 27102
# Total mutations found: 37810
#
# Processing JH158.F78.NB66.fastq.gz:
# Age: 81
# Telomere Length: 4772
# Total Reads: 7509
# 3x_repeat c-strand total: 29567
# 3x_repeat g-strand total: 383623
# G-strand mutations total: 38454
# C-strand mutations total: 3289
# G-strand normalizer (3x_repeat + mutations): 422077
# C-strand normalizer (3x_repeat + mutations): 32856
# Total mutations found: 41743
#
# Processing JH159.F78.NB50.fastq.gz:
# Age: 81
# Telomere Length: 4697
# Total Reads: 18361
# 3x_repeat c-strand total: 65647
# 3x_repeat g-strand total: 639126
# G-strand mutations total: 61314
# C-strand mutations total: 5500
# G-strand normalizer (3x_repeat + mutations): 700440
# C-strand normalizer (3x_repeat + mutations): 71147
# Total mutations found: 66814
#
# Processing JH160.F78.NB15.fastq.gz:
# Age: 80
# Telomere Length: 4885
# Total Reads: 6899
# 3x_repeat c-strand total: 20994
# 3x_repeat g-strand total: 339187
# G-strand mutations total: 31854
# C-strand mutations total: 1919
# G-strand normalizer (3x_repeat + mutations): 371041
# C-strand normalizer (3x_repeat + mutations): 22913
# Total mutations found: 33773
#
# Processing JH161.F79.NB15.fastq.gz:
# Age: 79
# Telomere Length: 4568
# Total Reads: 8900
# 3x_repeat c-strand total: 36110
# 3x_repeat g-strand total: 412241
# G-strand mutations total: 34545
# C-strand mutations total: 2619
# G-strand normalizer (3x_repeat + mutations): 446786
# C-strand normalizer (3x_repeat + mutations): 38729
# Total mutations found: 37164
#
# Processing JH162.F79.NB66.fastq.gz:
# Age: 79
# Telomere Length: 4915
# Total Reads: 8354
# 3x_repeat c-strand total: 42433
# 3x_repeat g-strand total: 437636
# G-strand mutations total: 37248
# C-strand mutations total: 2978
# G-strand normalizer (3x_repeat + mutations): 474884
# C-strand normalizer (3x_repeat + mutations): 45411
# Total mutations found: 40226
#
# Processing JH163.F77.NB50.fastq.gz:
# Age: 79
# Telomere Length: 4562
# Total Reads: 11702
# 3x_repeat c-strand total: 46303
# 3x_repeat g-strand total: 416589
# G-strand mutations total: 41318
# C-strand mutations total: 4193
# G-strand normalizer (3x_repeat + mutations): 457907
# C-strand normalizer (3x_repeat + mutations): 50496
# Total mutations found: 45511
#
# Processing JH164.F80.NB15.fastq.gz:
# Age: 78
# Telomere Length: 4611
# Total Reads: 6383
# 3x_repeat c-strand total: 13943
# 3x_repeat g-strand total: 289376
# G-strand mutations total: 27596
# C-strand mutations total: 1413
# G-strand normalizer (3x_repeat + mutations): 316972
# C-strand normalizer (3x_repeat + mutations): 15356
# Total mutations found: 29009
#
# Processing JH165.F80.NB66.fastq.gz:
# Age: 78
# Telomere Length: 4382
# Total Reads: 7106
# 3x_repeat c-strand total: 18907
# 3x_repeat g-strand total: 293177
# G-strand mutations total: 29948
# C-strand mutations total: 2481
# G-strand normalizer (3x_repeat + mutations): 323125
# C-strand normalizer (3x_repeat + mutations): 21388
# Total mutations found: 32429
#
# Processing JH166.F80.NB68.fastq.gz:
# Age: 77
# Telomere Length: 4316
# Total Reads: 12214
# 3x_repeat c-strand total: 47637
# 3x_repeat g-strand total: 333909
# G-strand mutations total: 32758
# C-strand mutations total: 5780
# G-strand normalizer (3x_repeat + mutations): 366667
# C-strand normalizer (3x_repeat + mutations): 53417
# Total mutations found: 38538
#
# Processing JH167.F80.NB01.fastq.gz:
# Age: 76
# Telomere Length: 4506
# Total Reads: 12989
# 3x_repeat c-strand total: 30269
# 3x_repeat g-strand total: 656901
# G-strand mutations total: 64613
# C-strand mutations total: 4333
# G-strand normalizer (3x_repeat + mutations): 721514
# C-strand normalizer (3x_repeat + mutations): 34602
# Total mutations found: 68946
#
# Processing JH169.F80.NB20.fastq.gz:
# Age: 75
# Telomere Length: 4596
# Total Reads: 4195
# 3x_repeat c-strand total: 16841
# 3x_repeat g-strand total: 184717
# G-strand mutations total: 18246
# C-strand mutations total: 1789
# G-strand normalizer (3x_repeat + mutations): 202963
# C-strand normalizer (3x_repeat + mutations): 18630
# Total mutations found: 20035
#
# Processing JH170.F80.NB50.fastq.gz:
# Age: 75
# Telomere Length: 4600
# Total Reads: 12344
# 3x_repeat c-strand total: 43852
# 3x_repeat g-strand total: 498812
# G-strand mutations total: 47267
# C-strand mutations total: 4613
# G-strand normalizer (3x_repeat + mutations): 546079
# C-strand normalizer (3x_repeat + mutations): 48465
# Total mutations found: 51880
#
# Processing JH171.F79.NB01.fastq.gz:
# Age: 74
# Telomere Length: 4873
# Total Reads: 11818
# 3x_repeat c-strand total: 62519
# 3x_repeat g-strand total: 636388
# G-strand mutations total: 55514
# C-strand mutations total: 5159
# G-strand normalizer (3x_repeat + mutations): 691902
# C-strand normalizer (3x_repeat + mutations): 67678
# Total mutations found: 60673
#
# Processing JH172.F79.NB50.fastq.gz:
# Age: 74
# Telomere Length: 5300
# Total Reads: 25963
# 3x_repeat c-strand total: 128350
# 3x_repeat g-strand total: 834291
# G-strand mutations total: 67917
# C-strand mutations total: 11026
# G-strand normalizer (3x_repeat + mutations): 902208
# C-strand normalizer (3x_repeat + mutations): 139376
# Total mutations found: 78943
#
# Processing JH173.F93.NB68.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 2234
# 3x_repeat c-strand total: 17694
# 3x_repeat g-strand total: 93600
# G-strand mutations total: 10172
# C-strand mutations total: 2469
# G-strand normalizer (3x_repeat + mutations): 103772
# C-strand normalizer (3x_repeat + mutations): 20163
# Total mutations found: 12641
#
# Processing JH174.F93.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1457
# 3x_repeat c-strand total: 10117
# 3x_repeat g-strand total: 72953
# G-strand mutations total: 8120
# C-strand mutations total: 1508
# G-strand normalizer (3x_repeat + mutations): 81073
# C-strand normalizer (3x_repeat + mutations): 11625
# Total mutations found: 9628
#
# Processing JH176.F94.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1083
# 3x_repeat c-strand total: 7944
# 3x_repeat g-strand total: 68238
# G-strand mutations total: 6855
# C-strand mutations total: 805
# G-strand normalizer (3x_repeat + mutations): 75093
# C-strand normalizer (3x_repeat + mutations): 8749
# Total mutations found: 7660
#
# Processing JH177.F94.NB68.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1100
# 3x_repeat c-strand total: 9792
# 3x_repeat g-strand total: 57108
# G-strand mutations total: 5790
# C-strand mutations total: 1225
# G-strand normalizer (3x_repeat + mutations): 62898
# C-strand normalizer (3x_repeat + mutations): 11017
# Total mutations found: 7015
#
# Processing JH178.F94.NB50.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1165
# 3x_repeat c-strand total: 8198
# 3x_repeat g-strand total: 61152
# G-strand mutations total: 6454
# C-strand mutations total: 663
# G-strand normalizer (3x_repeat + mutations): 67606
# C-strand normalizer (3x_repeat + mutations): 8861
# Total mutations found: 7117
#
# Processing JH179.F95.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1070
# 3x_repeat c-strand total: 4078
# 3x_repeat g-strand total: 98754
# G-strand mutations total: 11216
# C-strand mutations total: 584
# G-strand normalizer (3x_repeat + mutations): 109970
# C-strand normalizer (3x_repeat + mutations): 4662
# Total mutations found: 11800
#
# Processing JH180.F95.NB68.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1310
# 3x_repeat c-strand total: 6967
# 3x_repeat g-strand total: 55805
# G-strand mutations total: 6554
# C-strand mutations total: 892
# G-strand normalizer (3x_repeat + mutations): 62359
# C-strand normalizer (3x_repeat + mutations): 7859
# Total mutations found: 7446
#
# Processing JH182.F96.NB50.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1759
# 3x_repeat c-strand total: 12708
# 3x_repeat g-strand total: 92812
# G-strand mutations total: 9990
# C-strand mutations total: 1461
# G-strand normalizer (3x_repeat + mutations): 102802
# C-strand normalizer (3x_repeat + mutations): 14169
# Total mutations found: 11451
#
# Processing JH183.F96.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1561
# 3x_repeat c-strand total: 9798
# 3x_repeat g-strand total: 93810
# G-strand mutations total: 10500
# C-strand mutations total: 1063
# G-strand normalizer (3x_repeat + mutations): 104310
# C-strand normalizer (3x_repeat + mutations): 10861
# Total mutations found: 11563
#
# Processing JH184.F96.NB68.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 2498
# 3x_repeat c-strand total: 19501
# 3x_repeat g-strand total: 138776
# G-strand mutations total: 14789
# C-strand mutations total: 2115
# G-strand normalizer (3x_repeat + mutations): 153565
# C-strand normalizer (3x_repeat + mutations): 21616
# Total mutations found: 16904
#
# Processing JH185.F97.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 931
# 3x_repeat c-strand total: 8253
# 3x_repeat g-strand total: 56961
# G-strand mutations total: 5589
# C-strand mutations total: 655
# G-strand normalizer (3x_repeat + mutations): 62550
# C-strand normalizer (3x_repeat + mutations): 8908
# Total mutations found: 6244
#
# Processing JH187.F98.NB50.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1248
# 3x_repeat c-strand total: 8964
# 3x_repeat g-strand total: 67505
# G-strand mutations total: 7285
# C-strand mutations total: 832
# G-strand normalizer (3x_repeat + mutations): 74790
# C-strand normalizer (3x_repeat + mutations): 9796
# Total mutations found: 8117
#
# Processing JH189.F70.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 8688
# 3x_repeat c-strand total: 92103
# 3x_repeat g-strand total: 801698
# G-strand mutations total: 64342
# C-strand mutations total: 7024
# G-strand normalizer (3x_repeat + mutations): 866040
# C-strand normalizer (3x_repeat + mutations): 99127
# Total mutations found: 71366
#
# Processing JH190.F69.NB01.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 9902
# 3x_repeat c-strand total: 106223
# 3x_repeat g-strand total: 408172
# G-strand mutations total: 39693
# C-strand mutations total: 11544
# G-strand normalizer (3x_repeat + mutations): 447865
# C-strand normalizer (3x_repeat + mutations): 117767
# Total mutations found: 51237
#
# Processing JH191.F81.NB50.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 7235
# 3x_repeat c-strand total: 52045
# 3x_repeat g-strand total: 411832
# G-strand mutations total: 37062
# C-strand mutations total: 3738
# G-strand normalizer (3x_repeat + mutations): 448894
# C-strand normalizer (3x_repeat + mutations): 55783
# Total mutations found: 40800
#
# Processing JH23.F89.NB20.fastq.gz:
# Age: 45
# Telomere Length: 5365
# Total Reads: 3873
# 3x_repeat c-strand total: 30018
# 3x_repeat g-strand total: 337687
# G-strand mutations total: 31343
# C-strand mutations total: 3349
# G-strand normalizer (3x_repeat + mutations): 369030
# C-strand normalizer (3x_repeat + mutations): 33367
# Total mutations found: 34692
#
# Processing JH27.F89.NB66.fastq.gz:
# Age: 50
# Telomere Length: 5347
# Total Reads: 4690
# 3x_repeat c-strand total: 28385
# 3x_repeat g-strand total: 452587
# G-strand mutations total: 40555
# C-strand mutations total: 2485
# G-strand normalizer (3x_repeat + mutations): 493142
# C-strand normalizer (3x_repeat + mutations): 30870
# Total mutations found: 43040
#
# Processing JH29.F92.NB66.fastq.gz:
# Age: 52
# Telomere Length: 5549
# Total Reads: 6642
# 3x_repeat c-strand total: 28282
# 3x_repeat g-strand total: 520762
# G-strand mutations total: 43142
# C-strand mutations total: 2762
# G-strand normalizer (3x_repeat + mutations): 563904
# C-strand normalizer (3x_repeat + mutations): 31044
# Total mutations found: 45904
#
# Processing JH30.F89.NB68.fastq.gz:
# Age: 55
# Telomere Length: 5715
# Total Reads: 10285
# 3x_repeat c-strand total: 59323
# 3x_repeat g-strand total: 528996
# G-strand mutations total: 48335
# C-strand mutations total: 6722
# G-strand normalizer (3x_repeat + mutations): 577331
# C-strand normalizer (3x_repeat + mutations): 66045
# Total mutations found: 55057
#
# Processing JH31.F89.NB50.fastq.gz:
# Age: 61
# Telomere Length: 4151
# Total Reads: 17305
# 3x_repeat c-strand total: 69601
# 3x_repeat g-strand total: 709819
# G-strand mutations total: 67167
# C-strand mutations total: 6666
# G-strand normalizer (3x_repeat + mutations): 776986
# C-strand normalizer (3x_repeat + mutations): 76267
# Total mutations found: 73833
#
# Processing JH32.F92.NB68.fastq.gz:
# Age: 62
# Telomere Length: 5112
# Total Reads: 8377
# 3x_repeat c-strand total: 52119
# 3x_repeat g-strand total: 487823
# G-strand mutations total: 42093
# C-strand mutations total: 5871
# G-strand normalizer (3x_repeat + mutations): 529916
# C-strand normalizer (3x_repeat + mutations): 57990
# Total mutations found: 47964
#
# Processing JH34.F92.NB20.fastq.gz:
# Age: 74
# Telomere Length: 4831
# Total Reads: 7132
# 3x_repeat c-strand total: 34673
# 3x_repeat g-strand total: 371140
# G-strand mutations total: 33403
# C-strand mutations total: 3597
# G-strand normalizer (3x_repeat + mutations): 404543
# C-strand normalizer (3x_repeat + mutations): 38270
# Total mutations found: 37000
#
# Processing JH35.F90.NB50.fastq.gz:
# Age: 75
# Telomere Length: 5841
# Total Reads: 7503
# 3x_repeat c-strand total: 48622
# 3x_repeat g-strand total: 672239
# G-strand mutations total: 63082
# C-strand mutations total: 6796
# G-strand normalizer (3x_repeat + mutations): 735321
# C-strand normalizer (3x_repeat + mutations): 55418
# Total mutations found: 69878
#
# Processing JH36.F90.NB66.fastq.gz:
# Age: 85
# Telomere Length: 6249
# Total Reads: 3015
# 3x_repeat c-strand total: 20949
# 3x_repeat g-strand total: 350459
# G-strand mutations total: 31590
# C-strand mutations total: 2547
# G-strand normalizer (3x_repeat + mutations): 382049
# C-strand normalizer (3x_repeat + mutations): 23496
# Total mutations found: 34137
#
# Processing JH37.F90.NB68.fastq.gz:
# Age: 90
# Telomere Length: 5759
# Total Reads: 4432
# 3x_repeat c-strand total: 38522
# 3x_repeat g-strand total: 359865
# G-strand mutations total: 31769
# C-strand mutations total: 3822
# G-strand normalizer (3x_repeat + mutations): 391634
# C-strand normalizer (3x_repeat + mutations): 42344
# Total mutations found: 35591
#
# Processing JH38.F90.NB20.fastq.gz:
# Age: 65
# Telomere Length: 4887
# Total Reads: 2460
# 3x_repeat c-strand total: 19126
# 3x_repeat g-strand total: 185806
# G-strand mutations total: 16713
# C-strand mutations total: 2121
# G-strand normalizer (3x_repeat + mutations): 202519
# C-strand normalizer (3x_repeat + mutations): 21247
# Total mutations found: 18834
#
# Processing JH40.F92.NB65.fastq.gz:
# Age: 51
# Telomere Length: 5274
# Total Reads: 2216
# 3x_repeat c-strand total: 9986
# 3x_repeat g-strand total: 84120
# G-strand mutations total: 7373
# C-strand mutations total: 998
# G-strand normalizer (3x_repeat + mutations): 91493
# C-strand normalizer (3x_repeat + mutations): 10984
# Total mutations found: 8371
#
# Processing JH41.F92.NB70.fastq.gz:
# Age: 39
# Telomere Length: 5597
# Total Reads: 1720
# 3x_repeat c-strand total: 10565
# 3x_repeat g-strand total: 125451
# G-strand mutations total: 10616
# C-strand mutations total: 1124
# G-strand normalizer (3x_repeat + mutations): 136067
# C-strand normalizer (3x_repeat + mutations): 11689
# Total mutations found: 11740
#
# Processing JH42.F86.NB50.fastq.gz:
# Age: 25
# Telomere Length: 5423
# Total Reads: 5006
# 3x_repeat c-strand total: 34627
# 3x_repeat g-strand total: 393750
# G-strand mutations total: 35922
# C-strand mutations total: 2982
# G-strand normalizer (3x_repeat + mutations): 429672
# C-strand normalizer (3x_repeat + mutations): 37609
# Total mutations found: 38904
#
# Processing JH43.F86.NB66.fastq.gz:
# Age: 61
# Telomere Length: 5097
# Total Reads: 1627
# 3x_repeat c-strand total: 9514
# 3x_repeat g-strand total: 153896
# G-strand mutations total: 13968
# C-strand mutations total: 1072
# G-strand normalizer (3x_repeat + mutations): 167864
# C-strand normalizer (3x_repeat + mutations): 10586
# Total mutations found: 15040
#
# Processing JH44.F86.NB68.fastq.gz:
# Age: 62
# Telomere Length: 4834
# Total Reads: 5196
# 3x_repeat c-strand total: 39636
# 3x_repeat g-strand total: 294081
# G-strand mutations total: 26733
# C-strand mutations total: 3752
# G-strand normalizer (3x_repeat + mutations): 320814
# C-strand normalizer (3x_repeat + mutations): 43388
# Total mutations found: 30485
#
# Processing JH45.F86.NB20.fastq.gz:
# Age: 50
# Telomere Length: 5363
# Total Reads: 1588
# 3x_repeat c-strand total: 10398
# 3x_repeat g-strand total: 131258
# G-strand mutations total: 11808
# C-strand mutations total: 924
# G-strand normalizer (3x_repeat + mutations): 143066
# C-strand normalizer (3x_repeat + mutations): 11322
# Total mutations found: 12732
#
# Processing JH46.F86.NB65.fastq.gz:
# Age: 43
# Telomere Length: 5948
# Total Reads: 1244
# 3x_repeat c-strand total: 8068
# 3x_repeat g-strand total: 91326
# G-strand mutations total: 8344
# C-strand mutations total: 782
# G-strand normalizer (3x_repeat + mutations): 99670
# C-strand normalizer (3x_repeat + mutations): 8850
# Total mutations found: 9126
#
# Processing JH47.F86.NB70.fastq.gz:
# Age: 3
# Telomere Length: 6598
# Total Reads: 1328
# 3x_repeat c-strand total: 8094
# 3x_repeat g-strand total: 126486
# G-strand mutations total: 10735
# C-strand mutations total: 811
# G-strand normalizer (3x_repeat + mutations): 137221
# C-strand normalizer (3x_repeat + mutations): 8905
# Total mutations found: 11546
#
# Processing JH50.F87.NB66.fastq.gz:
# Age: 57
# Telomere Length: 5040
# Total Reads: 2082
# 3x_repeat c-strand total: 12382
# 3x_repeat g-strand total: 210660
# G-strand mutations total: 16920
# C-strand mutations total: 994
# G-strand normalizer (3x_repeat + mutations): 227580
# C-strand normalizer (3x_repeat + mutations): 13376
# Total mutations found: 17914
#
# Processing JH52.F87.NB67.fastq.gz:
# Age: 73
# Telomere Length: 5295
# Total Reads: 1905
# 3x_repeat c-strand total: 14779
# 3x_repeat g-strand total: 195074
# G-strand mutations total: 16043
# C-strand mutations total: 1561
# G-strand normalizer (3x_repeat + mutations): 211117
# C-strand normalizer (3x_repeat + mutations): 16340
# Total mutations found: 17604
#
# Processing JH53.F87.NB65.fastq.gz:
# Age: 68
# Telomere Length: 3744
# Total Reads: 2028
# 3x_repeat c-strand total: 14517
# 3x_repeat g-strand total: 111976
# G-strand mutations total: 10149
# C-strand mutations total: 1845
# G-strand normalizer (3x_repeat + mutations): 122125
# C-strand normalizer (3x_repeat + mutations): 16362
# Total mutations found: 11994
#
# Processing JH54.F87.NB68.fastq.gz:
# Age: 72
# Telomere Length: 5025
# Total Reads: 2602
# 3x_repeat c-strand total: 24911
# 3x_repeat g-strand total: 177567
# G-strand mutations total: 14129
# C-strand mutations total: 2025
# G-strand normalizer (3x_repeat + mutations): 191696
# C-strand normalizer (3x_repeat + mutations): 26936
# Total mutations found: 16154
#
# Processing JH55.F87.NB70.fastq.gz:
# Age: 61
# Telomere Length: 6446
# Total Reads: 1309
# 3x_repeat c-strand total: 9998
# 3x_repeat g-strand total: 141200
# G-strand mutations total: 10323
# C-strand mutations total: 869
# G-strand normalizer (3x_repeat + mutations): 151523
# C-strand normalizer (3x_repeat + mutations): 10867
# Total mutations found: 11192
#
# Processing JH56.F87.NB69.fastq:
# Age: 52
# Telomere Length: 5625
# Total Reads: 1378
# 3x_repeat c-strand total: 10188
# 3x_repeat g-strand total: 137487
# G-strand mutations total: 11004
# C-strand mutations total: 1107
# G-strand normalizer (3x_repeat + mutations): 148491
# C-strand normalizer (3x_repeat + mutations): 11295
# Total mutations found: 12111
#
# Processing JH56.F87.NB69.fastq.gz:
# Age: 52
# Telomere Length: 5625
# Total Reads: 1378
# 3x_repeat c-strand total: 10188
# 3x_repeat g-strand total: 137487
# G-strand mutations total: 11004
# C-strand mutations total: 1107
# G-strand normalizer (3x_repeat + mutations): 148491
# C-strand normalizer (3x_repeat + mutations): 11295
# Total mutations found: 12111
#
# Processing JH58.F87.NB20.fastq.gz:
# Age: 52
# Telomere Length: 5182
# Total Reads: 1403
# 3x_repeat c-strand total: 10108
# 3x_repeat g-strand total: 135150
# G-strand mutations total: 11261
# C-strand mutations total: 980
# G-strand normalizer (3x_repeat + mutations): 146411
# C-strand normalizer (3x_repeat + mutations): 11088
# Total mutations found: 12241
#
# Processing JH59.F88.NB68.fastq.gz:
# Age: 25
# Telomere Length: 5527
# Total Reads: 3803
# 3x_repeat c-strand total: 42924
# 3x_repeat g-strand total: 322361
# G-strand mutations total: 24207
# C-strand mutations total: 2557
# G-strand normalizer (3x_repeat + mutations): 346568
# C-strand normalizer (3x_repeat + mutations): 45481
# Total mutations found: 26764
#
# Processing JH60.F88.NB20.fastq.gz:
# Age: 74
# Telomere Length: 4996
# Total Reads: 2074
# 3x_repeat c-strand total: 21642
# 3x_repeat g-strand total: 196617
# G-strand mutations total: 14643
# C-strand mutations total: 1677
# G-strand normalizer (3x_repeat + mutations): 211260
# C-strand normalizer (3x_repeat + mutations): 23319
# Total mutations found: 16320
#
# Processing JH61.F88.NB65.fastq.gz:
# Age: 54
# Telomere Length: 4845
# Total Reads: 3398
# 3x_repeat c-strand total: 32446
# 3x_repeat g-strand total: 218532
# G-strand mutations total: 17303
# C-strand mutations total: 3286
# G-strand normalizer (3x_repeat + mutations): 235835
# C-strand normalizer (3x_repeat + mutations): 35732
# Total mutations found: 20589
#
# Processing JH62.F88.NB70.fastq.gz:
# Age: 70
# Telomere Length: 3907
# Total Reads: 2644
# 3x_repeat c-strand total: 24307
# 3x_repeat g-strand total: 189375
# G-strand mutations total: 15900
# C-strand mutations total: 1835
# G-strand normalizer (3x_repeat + mutations): 205275
# C-strand normalizer (3x_repeat + mutations): 26142
# Total mutations found: 17735
#
# Processing JH63.F88.NB69.fastq.gz:
# Age: 33
# Telomere Length: 5084
# Total Reads: 2012
# 3x_repeat c-strand total: 18893
# 3x_repeat g-strand total: 178539
# G-strand mutations total: 13650
# C-strand mutations total: 1379
# G-strand normalizer (3x_repeat + mutations): 192189
# C-strand normalizer (3x_repeat + mutations): 20272
# Total mutations found: 15029
#
# Processing JH64.F88.NB72.fastq.gz:
# Age: 84
# Telomere Length: 4371
# Total Reads: 2403
# 3x_repeat c-strand total: 24479
# 3x_repeat g-strand total: 177354
# G-strand mutations total: 14610
# C-strand mutations total: 2133
# G-strand normalizer (3x_repeat + mutations): 191964
# C-strand normalizer (3x_repeat + mutations): 26612
# Total mutations found: 16743
#
# Processing JH65.F88.NB67.fastq.gz:
# Age: 90
# Telomere Length: 4561
# Total Reads: 2894
# 3x_repeat c-strand total: 24133
# 3x_repeat g-strand total: 255864
# G-strand mutations total: 20247
# C-strand mutations total: 2521
# G-strand normalizer (3x_repeat + mutations): 276111
# C-strand normalizer (3x_repeat + mutations): 26654
# Total mutations found: 22768
#
# Processing JH66.F88.NB15.fastq.gz:
# Age: 72
# Telomere Length: 4629
# Total Reads: 3319
# 3x_repeat c-strand total: 24203
# 3x_repeat g-strand total: 356773
# G-strand mutations total: 27784
# C-strand mutations total: 1577
# G-strand normalizer (3x_repeat + mutations): 384557
# C-strand normalizer (3x_repeat + mutations): 25780
# Total mutations found: 29361
#
# Processing JH67.F88.NB50.fastq.gz:
# Age: 29
# Telomere Length: 5104
# Total Reads: 7472
# 3x_repeat c-strand total: 53728
# 3x_repeat g-strand total: 750544
# G-strand mutations total: 59346
# C-strand mutations total: 3903
# G-strand normalizer (3x_repeat + mutations): 809890
# C-strand normalizer (3x_repeat + mutations): 57631
# Total mutations found: 63249
#
# Processing JH68.F88.NB66.fastq.gz:
# Age: 20
# Telomere Length: 5331
# Total Reads: 2679
# 3x_repeat c-strand total: 20731
# 3x_repeat g-strand total: 271743
# G-strand mutations total: 20410
# C-strand mutations total: 1556
# G-strand normalizer (3x_repeat + mutations): 292153
# C-strand normalizer (3x_repeat + mutations): 22287
# Total mutations found: 21966
#
# Processing JH69.F88.NB19.fastq.gz:
# Age: 59
# Telomere Length: 5012
# Total Reads: 2154
# 3x_repeat c-strand total: 20209
# 3x_repeat g-strand total: 193846
# G-strand mutations total: 14566
# C-strand mutations total: 1568
# G-strand normalizer (3x_repeat + mutations): 208412
# C-strand normalizer (3x_repeat + mutations): 21777
# Total mutations found: 16134
#
# Processing JH70.F33.NB01.fastq.gz:
# Age: 19
# Telomere Length: 5316
# Total Reads: 4825
# 3x_repeat c-strand total: 12103
# 3x_repeat g-strand total: 203794
# G-strand mutations total: 19230
# C-strand mutations total: 1344
# G-strand normalizer (3x_repeat + mutations): 223024
# C-strand normalizer (3x_repeat + mutations): 13447
# Total mutations found: 20574
#
# Processing JH71.F33.NB72.fastq.gz:
# Age: 57
# Telomere Length: 4248
# Total Reads: 3483
# 3x_repeat c-strand total: 11426
# 3x_repeat g-strand total: 114888
# G-strand mutations total: 11243
# C-strand mutations total: 1417
# G-strand normalizer (3x_repeat + mutations): 126131
# C-strand normalizer (3x_repeat + mutations): 12843
# Total mutations found: 12660
#
# Processing JH76.F40.NB01.fastq.gz:
# Age: 43
# Telomere Length: 5581
# Total Reads: 8393
# 3x_repeat c-strand total: 54269
# 3x_repeat g-strand total: 560661
# G-strand mutations total: 40110
# C-strand mutations total: 3390
# G-strand normalizer (3x_repeat + mutations): 600771
# C-strand normalizer (3x_repeat + mutations): 57659
# Total mutations found: 43500
#
# Processing JH76.UCSC.A24Mix3.NB88uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 3428
# 3x_repeat c-strand total: 47414
# 3x_repeat g-strand total: 263740
# G-strand mutations total: 18844
# C-strand mutations total: 3571
# G-strand normalizer (3x_repeat + mutations): 282584
# C-strand normalizer (3x_repeat + mutations): 50985
# Total mutations found: 22415
#
# Processing JH77.F40.NB15.fastq.gz:
# Age: 33
# Telomere Length: 5586
# Total Reads: 7821
# 3x_repeat c-strand total: 47463
# 3x_repeat g-strand total: 513958
# G-strand mutations total: 34881
# C-strand mutations total: 2467
# G-strand normalizer (3x_repeat + mutations): 548839
# C-strand normalizer (3x_repeat + mutations): 49930
# Total mutations found: 37348
#
# Processing JH77.UCSC.A24Mix3.NB50uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 9187
# 3x_repeat c-strand total: 117123
# 3x_repeat g-strand total: 932962
# G-strand mutations total: 63291
# C-strand mutations total: 7341
# G-strand normalizer (3x_repeat + mutations): 996253
# C-strand normalizer (3x_repeat + mutations): 124464
# Total mutations found: 70632
#
# Processing JH78.F35.NB01.fastq.gz:
# Age: 37
# Telomere Length: 5279
# Total Reads: 8039
# 3x_repeat c-strand total: 86767
# 3x_repeat g-strand total: 898365
# G-strand mutations total: 75392
# C-strand mutations total: 6299
# G-strand normalizer (3x_repeat + mutations): 973757
# C-strand normalizer (3x_repeat + mutations): 93066
# Total mutations found: 81691
#
# Processing JH80.F41.NB50.fastq.gz:
# Age: 63
# Telomere Length: 5570
# Total Reads: 8048
# 3x_repeat c-strand total: 42872
# 3x_repeat g-strand total: 951765
# G-strand mutations total: 88975
# C-strand mutations total: 4751
# G-strand normalizer (3x_repeat + mutations): 1040740
# C-strand normalizer (3x_repeat + mutations): 47623
# Total mutations found: 93726
#
# Processing JH81.F41.NB65.fastq.gz:
# Age: 40
# Telomere Length: 5435
# Total Reads: 7883
# 3x_repeat c-strand total: 31924
# 3x_repeat g-strand total: 806706
# G-strand mutations total: 75725
# C-strand mutations total: 2865
# G-strand normalizer (3x_repeat + mutations): 882431
# C-strand normalizer (3x_repeat + mutations): 34789
# Total mutations found: 78590
#
# Processing JH81.UCSC.A24Mix3.NB68uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 4606
# 3x_repeat c-strand total: 61204
# 3x_repeat g-strand total: 377959
# G-strand mutations total: 25909
# C-strand mutations total: 4048
# G-strand normalizer (3x_repeat + mutations): 403868
# C-strand normalizer (3x_repeat + mutations): 65252
# Total mutations found: 29957
#
# Processing JH82.F42.NB67.fastq.gz:
# Age: 49
# Telomere Length: 5407
# Total Reads: 7560
# 3x_repeat c-strand total: 89377
# 3x_repeat g-strand total: 843979
# G-strand mutations total: 57965
# C-strand mutations total: 4601
# G-strand normalizer (3x_repeat + mutations): 901944
# C-strand normalizer (3x_repeat + mutations): 93978
# Total mutations found: 62566
#
# Processing JH82.UCSC.A24Mix4.NB50uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 6284
# 3x_repeat c-strand total: 108139
# 3x_repeat g-strand total: 624722
# G-strand mutations total: 40438
# C-strand mutations total: 6517
# G-strand normalizer (3x_repeat + mutations): 665160
# C-strand normalizer (3x_repeat + mutations): 114656
# Total mutations found: 46955
#
# Processing JH83.F35.NB15.fastq.gz:
# Age: 29
# Telomere Length: 5217
# Total Reads: 5725
# 3x_repeat c-strand total: 66226
# 3x_repeat g-strand total: 658929
# G-strand mutations total: 54895
# C-strand mutations total: 4272
# G-strand normalizer (3x_repeat + mutations): 713824
# C-strand normalizer (3x_repeat + mutations): 70498
# Total mutations found: 59167
#
# Processing JH84.F36.NB19.fastq.gz:
# Age: 41
# Telomere Length: 6028
# Total Reads: 3765
# 3x_repeat c-strand total: 41640
# 3x_repeat g-strand total: 312406
# G-strand mutations total: 25919
# C-strand mutations total: 3596
# G-strand normalizer (3x_repeat + mutations): 338325
# C-strand normalizer (3x_repeat + mutations): 45236
# Total mutations found: 29515
#
# Processing JH85.F36.NB50.fastq.gz:
# Age: 20
# Telomere Length: 6262
# Total Reads: 6674
# 3x_repeat c-strand total: 59436
# 3x_repeat g-strand total: 874529
# G-strand mutations total: 69622
# C-strand mutations total: 4024
# G-strand normalizer (3x_repeat + mutations): 944151
# C-strand normalizer (3x_repeat + mutations): 63460
# Total mutations found: 73646
#
# Processing JH86.F37.NB65.fastq.gz:
# Age: 25
# Telomere Length: 5435
# Total Reads: 8398
# 3x_repeat c-strand total: 37060
# 3x_repeat g-strand total: 705193
# G-strand mutations total: 70334
# C-strand mutations total: 4113
# G-strand normalizer (3x_repeat + mutations): 775527
# C-strand normalizer (3x_repeat + mutations): 41173
# Total mutations found: 74447
#
# Processing JH87.F37.NB67.fastq.gz:
# Age: 38
# Telomere Length: 5157
# Total Reads: 6212
# 3x_repeat c-strand total: 37765
# 3x_repeat g-strand total: 594704
# G-strand mutations total: 59979
# C-strand mutations total: 2663
# G-strand normalizer (3x_repeat + mutations): 654683
# C-strand normalizer (3x_repeat + mutations): 40428
# Total mutations found: 62642
#
# Processing JH88.F42.NB69.fastq.gz:
# Age: 22
# Telomere Length: 5650
# Total Reads: 7909
# 3x_repeat c-strand total: 78884
# 3x_repeat g-strand total: 877612
# G-strand mutations total: 62101
# C-strand mutations total: 7272
# G-strand normalizer (3x_repeat + mutations): 939713
# C-strand normalizer (3x_repeat + mutations): 86156
# Total mutations found: 69373
#
# Processing JH88.UCSC.A24Mix4.NB88uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 1631
# 3x_repeat c-strand total: 29257
# 3x_repeat g-strand total: 128952
# G-strand mutations total: 8401
# C-strand mutations total: 2571
# G-strand normalizer (3x_repeat + mutations): 137353
# C-strand normalizer (3x_repeat + mutations): 31828
# Total mutations found: 10972
#
# Processing JH89.F43.NB70.fastq.gz:
# Age: 20
# Telomere Length: 7272
# Total Reads: 6941
# 3x_repeat c-strand total: 53914
# 3x_repeat g-strand total: 1041113
# G-strand mutations total: 76648
# C-strand mutations total: 4523
# G-strand normalizer (3x_repeat + mutations): 1117761
# C-strand normalizer (3x_repeat + mutations): 58437
# Total mutations found: 81171
#
# Processing JH90.F43.NB69.fastq.gz:
# Age: 26
# Telomere Length: 6405
# Total Reads: 8749
# 3x_repeat c-strand total: 48384
# 3x_repeat g-strand total: 1240819
# G-strand mutations total: 92402
# C-strand mutations total: 3971
# G-strand normalizer (3x_repeat + mutations): 1333221
# C-strand normalizer (3x_repeat + mutations): 52355
# Total mutations found: 96373
#
# Processing JH91.F44.NB72.fastq.gz:
# Age: 44
# Telomere Length: 4696
# Total Reads: 5917
# 3x_repeat c-strand total: 30094
# 3x_repeat g-strand total: 245453
# G-strand mutations total: 16805
# C-strand mutations total: 2036
# G-strand normalizer (3x_repeat + mutations): 262258
# C-strand normalizer (3x_repeat + mutations): 32130
# Total mutations found: 18841
#
# Processing JH93.F44.NB01.fastq.gz:
# Age: 22
# Telomere Length: 5331
# Total Reads: 7686
# 3x_repeat c-strand total: 33581
# 3x_repeat g-strand total: 303675
# G-strand mutations total: 19867
# C-strand mutations total: 2002
# G-strand normalizer (3x_repeat + mutations): 323542
# C-strand normalizer (3x_repeat + mutations): 35583
# Total mutations found: 21869
#
# Processing JH93.UCSC.A24Mix4.NB68uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 2871
# 3x_repeat c-strand total: 50399
# 3x_repeat g-strand total: 237859
# G-strand mutations total: 14958
# C-strand mutations total: 3621
# G-strand normalizer (3x_repeat + mutations): 252817
# C-strand normalizer (3x_repeat + mutations): 54020
# Total mutations found: 18579
#
# Processing JH94.F45.NB15.fastq.gz:
# Age: 51
# Telomere Length: 5861
# Total Reads: 4331
# 3x_repeat c-strand total: 43740
# 3x_repeat g-strand total: 574403
# G-strand mutations total: 39201
# C-strand mutations total: 2739
# G-strand normalizer (3x_repeat + mutations): 613604
# C-strand normalizer (3x_repeat + mutations): 46479
# Total mutations found: 41940
#
# Processing JH95.F45.NB19.fastq.gz:
# Age: 39
# Telomere Length: 5537
# Total Reads: 4214
# 3x_repeat c-strand total: 43377
# 3x_repeat g-strand total: 474858
# G-strand mutations total: 31562
# C-strand mutations total: 2752
# G-strand normalizer (3x_repeat + mutations): 506420
# C-strand normalizer (3x_repeat + mutations): 46129
# Total mutations found: 34314
#
# Processing JH95.UCSC.A24Mix4.NB69uq.fastq.gz:
# Age:
# Telomere Length:
# Total Reads: 2189
# 3x_repeat c-strand total: 40057
# 3x_repeat g-strand total: 139962
# G-strand mutations total: 9469
# C-strand mutations total: 3039
# G-strand normalizer (3x_repeat + mutations): 149431
# C-strand normalizer (3x_repeat + mutations): 43096
# Total mutations found: 12508
#
# Processing JH96.F46.NB70.fastq.gz:
# Age: 56
# Telomere Length: 5044
# Total Reads: 5115
# 3x_repeat c-strand total: 19567
# 3x_repeat g-strand total: 485153
# G-strand mutations total: 55818
# C-strand mutations total: 3174
# G-strand normalizer (3x_repeat + mutations): 540971
# C-strand normalizer (3x_repeat + mutations): 22741
# Total mutations found: 58992
#
# Processing JH97.F46.NB72.fastq.gz:
# Age: 29
# Telomere Length: 5548
# Total Reads: 5070
# 3x_repeat c-strand total: 16093
# 3x_repeat g-strand total: 551607
# G-strand mutations total: 64047
# C-strand mutations total: 2385
# G-strand normalizer (3x_repeat + mutations): 615654
# C-strand normalizer (3x_repeat + mutations): 18478
# Total mutations found: 66432
#
# Processing JH98.F49.NB50.fastq.gz:
# Age: 25
# Telomere Length: 7411
# Total Reads: 4861
# 3x_repeat c-strand total: 61273
# 3x_repeat g-strand total: 784261
# G-strand mutations total: 48335
# C-strand mutations total: 2650
# G-strand normalizer (3x_repeat + mutations): 832596
# C-strand normalizer (3x_repeat + mutations): 63923
# Total mutations found: 50985
# CSV written to: /Users/akhilpeddikuppa/FieldLab/GreiderCodeSearch/analysis/telomere_analysis_3x_repeat.csv

# %% [markdown]
# ## Plotting (from plotting.py)
#
# Run all plotting pipelines. Uses `csv_path` from the generate step above. If you already have a CSV, set `csv_path` manually and run the plot cells.

# %%
def _get_patterns_version(patterns_file_path):
    """Read version string from patterns JSON."""
    try:
        with open(patterns_file_path) as f:
            return json.load(f).get('version', 'unknown')
    except Exception:
        return 'unknown'

def _default_csv_path_from_patterns(patterns_file_path):
    """Construct the default telomere_analysis CSV path based on patterns version."""
    with open(patterns_file_path) as f:
        version = json.load(f).get('version', 'unknown')
    safe_version = str(version).replace(' ', '_')
    return os.path.join(_ANALYSIS_DIR, f'telomere_analysis_{safe_version}.csv')

# Ensure csv_path is available (use from generate step, or resolve from patterns)
try:
    csv_path
except NameError:
    csv_path = _default_csv_path_from_patterns(PATTERNS_PATH)

# %%
def _plot_histograms_by_age_group(data, output_path):
    """Plot boxplots of mutation rate variables in 10-year age bins (2x2 grid)."""
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    fig, axes = plt.subplots(2, 2, figsize=(20, 12))
    fig.suptitle('Mutation Rates by Age Groups (10-year bins)', fontsize=16, fontweight='bold')
    variables = ['total_mutations_over_total_g_strand_per_1k', 'g_strand_A>G_sum_per_1k', 'g_strand_T>G_sum_per_1k', 'g_strand_T>C_sum_per_1k']
    titles = ['Total Mutations Normalized', 'G > A Mutation Rate Normalized', 'T > G Mutation Rate Normalized', 'T > C Mutation Rate Normalized']
    for i, (var, title) in enumerate(zip(variables, titles)):
        row, col = i // 2, i % 2
        ax = axes[row, col]
        plot_data = data.dropna(subset=['Age', var])
        if len(plot_data) > 0:
            age_bins = np.arange(0, plot_data['Age'].max() + 10, 10)
            age_labels = [f'{int(b)}-{int(b+9)}' for b in age_bins[:-1]]
            plot_data = plot_data.copy()
            plot_data['Age_Group'] = pd.cut(plot_data['Age'], bins=age_bins, labels=age_labels, include_lowest=True)
            sns.boxplot(data=plot_data, x='Age_Group', y=var, ax=ax)
            ax.set_xlabel('Age Group (years)')
            ax.set_ylabel('Mutations per 1000bp')
            plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
        else:
            ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes, fontsize=12)
        ax.set_title(title, fontweight='bold')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def _plot_mutations_per_file(data, output_path):
    """Bar plot of total mutations per file."""
    sns.set_style("whitegrid")
    mutation_columns = [col for col in data.columns if 'mutations' in col and 'per_1k' not in col]
    data_with_totals = data.copy()
    data_with_totals['Total_Mutations'] = data[mutation_columns].sum(axis=1)
    plot_data = data_with_totals.dropna(subset=['FileName', 'Total_Mutations'])
    plt.figure(figsize=(16, 10))
    if len(plot_data) > 0:
        plot_data = plot_data.sort_values('Total_Mutations', ascending=True)
        bars = plt.bar(range(len(plot_data)), plot_data['Total_Mutations'], color='steelblue', alpha=0.7, edgecolor='black', linewidth=0.5)
        plt.title('Total Number of Mutations per File', fontsize=16, fontweight='bold', pad=20)
        plt.xlabel('Files'); plt.ylabel('Total Number of Mutations')
        plt.xticks(range(len(plot_data)), plot_data['FileName'], rotation=45, ha='right')
        max_val = plot_data['Total_Mutations'].max()
        for bar in bars:
            plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + max_val*0.01, f'{int(bar.get_height())}', ha='center', va='bottom', fontsize=8)
        stats_text = f"Mean: {plot_data['Total_Mutations'].mean():.0f}\nMedian: {plot_data['Total_Mutations'].median():.0f}\nMin: {plot_data['Total_Mutations'].min():.0f}\nMax: {max_val:.0f}"
        plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
        plt.grid(axis='y', alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)
        plt.title('Total Number of Mutations per File', fontweight='bold')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()
    return len(plot_data)

def plot_histograms_from_csv(csv_path, output_dir=None):
    """Reproduce histogram-style plots given a telomere analysis CSV path."""
    if output_dir is None:
        output_dir = os.path.dirname(csv_path) or '.'
    os.makedirs(output_dir, exist_ok=True)
    data = pd.read_csv(csv_path)
    hist_path = os.path.join(output_dir, "histogram.png")
    per_file_path = os.path.join(output_dir, "mutations_per_file_histogram.png")
    _plot_histograms_by_age_group(data, hist_path)
    num_files = _plot_mutations_per_file(data, per_file_path)
    print(f"Histogram plot saved as '{hist_path}'")
    print(f"Mutations per file histogram saved as '{per_file_path}'")
    print(f"Processed {num_files} files")

# %%
def plot_trendlines(data, output_path, variables, titles, version):
    """Plot linear trendlines of mutation rate variables vs Age in 2x2 grid."""
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    fig, axes = plt.subplots(2, 2, figsize=(20, 12))
    fig.suptitle(f'Mutation Rates vs Age [{version}]', fontsize=16, fontweight='bold')
    for i, (var, title) in enumerate(zip(variables, titles)):
        row, col = i // 2, i % 2
        ax = axes[row, col]
        plot_data = data.dropna(subset=['Age', var])
        if len(plot_data) > 0:
            sns.scatterplot(data=plot_data, x='Age', y=var, ax=ax, alpha=0.6)
            if len(plot_data) > 1:
                sns.regplot(data=plot_data, x='Age', y=var, ax=ax, scatter=False, line_kws={'color': 'blue', 'linestyle': '--'})
                slope, intercept, r_value, p_value, std_err = linregress(plot_data['Age'], plot_data[var])
                ax.set_title(f"{title}\nR² = {(r_value**2):.3f}", fontweight='bold')
            else:
                ax.set_title(title, fontweight='bold')
            ax.set_xlabel('Age'); ax.set_ylabel('Mutations per 1000bp')
        else:
            ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes, fontsize=12)
            ax.set_title(title, fontweight='bold')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def plot_spearman_trendlines(data, output_path, variables, titles, version):
    """Plot Spearman correlation scatterplots vs Age in 2x2 grid."""
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    fig, axes = plt.subplots(2, 2, figsize=(20, 12))
    fig.suptitle(f"Spearman's Rank Correlation: Mutation Rates vs Age [{version}]", fontsize=16, fontweight='bold')
    for i, (var, title) in enumerate(zip(variables, titles)):
        row, col = i // 2, i % 2
        ax = axes[row, col]
        plot_data = data.dropna(subset=['Age', var])
        if len(plot_data) > 1:
            corr, pval = spearmanr(plot_data['Age'], plot_data[var])
            sns.scatterplot(data=plot_data, x='Age', y=var, ax=ax, alpha=0.6)
            ax.set_title(f"{title}\nSpearman r = {corr:.2f}, p = {pval:.2g}", fontweight='bold')
        else:
            ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes, fontsize=12)
            ax.set_title(title, fontweight='bold')
        ax.set_xlabel('Age'); ax.set_ylabel('Mutations per 1000bp')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def plot_trendlines_main(csv_path, trendline_output_path, spearman_output_path, variables, titles, patterns_file_path):
    """Main entry for 2x2 trendline and Spearman plots."""
    version = _get_patterns_version(patterns_file_path)
    data = pd.read_csv(csv_path)
    plot_trendlines(data, trendline_output_path, variables, titles, version)
    plot_spearman_trendlines(data, spearman_output_path, variables, titles, version)
    print(f"Trendline plot saved as '{trendline_output_path}'")
    print(f"Spearman correlation plot saved as '{spearman_output_path}'")

# %%
def plot_mutational_signature_row(row, mutation_types, mutation_columns, output_path, version):
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    bar_heights, bar_colors, bar_labels = [], [], []
    all_columns = []
    for mut_type, contexts in mutation_columns.items():
        for context, cols in contexts.items():
            existing_cols = [col for col in cols if col in row.index]
            all_columns.extend(existing_cols)
    if not all_columns:
        print(f"Warning: No valid mutation columns found for {row.get('FileName', 'unknown')}")
        return
    total_mutations = row[all_columns].sum()
    for mut_label, color in mutation_types:
        contexts = mutation_columns[mut_label]
        for context_name, cols in contexts.items():
            for i, col in enumerate(cols):
                if col in row.index:
                    value = row[col]
                    percentage = (value / total_mutations) * 100 if total_mutations > 0 else 0
                    bar_heights.append(percentage)
                    bar_colors.append(color)
                    bar_labels.append(f"{mut_label} {context_name} pos{i+1}")
    if not bar_heights:
        print(f"Warning: No valid data found for {row.get('FileName', 'unknown')}")
        return
    x = np.arange(len(bar_heights))
    fig, ax = plt.subplots(figsize=(16, 10))
    sns.barplot(x=x, y=bar_heights, palette=bar_colors, ax=ax, edgecolor='black', linewidth=0.5)
    for i, label in enumerate(bar_labels):
        ax.text(i, -max(bar_heights)*0.02, label, ha='center', va='center', color='black', fontsize=9, fontweight='normal', rotation=45)
    ax.set_xticks([])
    ax.set_yticks(np.linspace(0, max(bar_heights), 6))
    ax.set_xlim(-0.5, len(bar_heights) - 0.5)
    ax.set_ylim(-max(bar_heights)*0.1, max(bar_heights) + max(bar_heights)*0.2)
    ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False); ax.spines['left'].set_visible(False)
    ax.yaxis.grid(True, linestyle='--', alpha=0.3)
    ax.set_axisbelow(True)
    ax.set_ylabel('Percentage of Single Base Modifications', fontsize=14, fontweight='bold')
    age = row['Age'] if 'Age' in row else 'N/A'
    filename = row['FileName'] if 'FileName' in row else 'sample'
    ax.set_title(f"Mutational Signatures by Position and Strand Context [{version}]\nFile: {filename} | Age: {age} years", fontsize=18, fontweight='bold', pad=30)
    plt.tight_layout(rect=[0, 0.15, 1, 0.95])
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def plot_mutational_signatures(csv_path, patterns_file_path):
    sns.set_theme(style="whitegrid", font_scale=1.1)
    version = _get_patterns_version(patterns_file_path)
    df = pd.read_csv(csv_path)
    mutation_types = [('C>A','blue'),('C>G','black'),('C>T','red'),('G>A','gray'),('G>C','green'),('G>T','pink')]
    mutation_columns = {
        'C>A': {'C-strand': ['c_strand_mutations_C>A_c1','c_strand_mutations_C>A_c2','c_strand_mutations_C>A_c3'], 'G-strand': ['g_strand_mutations_G>T_g1','g_strand_mutations_G>T_g2','g_strand_mutations_G>T_g3']},
        'C>G': {'C-strand': ['c_strand_mutations_C>G_c1','c_strand_mutations_C>G_c2','c_strand_mutations_C>G_c3'], 'G-strand': ['g_strand_mutations_G>C_g1','g_strand_mutations_G>C_g2','g_strand_mutations_G>C_g3']},
        'C>T': {'C-strand': ['c_strand_mutations_C>T_c1','c_strand_mutations_C>T_c2','c_strand_mutations_C>T_c3'], 'G-strand': ['g_strand_mutations_G>A_g1','g_strand_mutations_G>A_g2','g_strand_mutations_G>A_g3']},
        'G>A': {'G-strand': ['g_strand_mutations_G>A_g1','g_strand_mutations_G>A_g2','g_strand_mutations_G>A_g3'], 'C-strand': ['c_strand_mutations_C>G_c1','c_strand_mutations_C>G_c2','c_strand_mutations_C>G_c3']},
        'G>C': {'G-strand': ['g_strand_mutations_G>C_g1','g_strand_mutations_G>C_g2','g_strand_mutations_G>C_g3'], 'C-strand': ['c_strand_mutations_C>T_c1','c_strand_mutations_C>T_c2','c_strand_mutations_C>T_c3']},
        'G>T': {'G-strand': ['g_strand_mutations_G>T_g1','g_strand_mutations_G>T_g2','g_strand_mutations_G>T_g3'], 'C-strand': ['c_strand_mutations_C>A_c1','c_strand_mutations_C>A_c2','c_strand_mutations_C>A_c3']},
    }
    os.makedirs('plots', exist_ok=True)
    for idx, row in df.iterrows():
        filename = str(row['FileName']) if 'FileName' in row else f'sample_{idx}'
        filename_base = os.path.splitext(filename)[0]
        output_path = os.path.join('plots', f'{filename_base}.png')
        plot_mutational_signature_row(row, mutation_types, mutation_columns, output_path, version)

def plot_mutational_signatures_main(patterns_file_path):
    csv_path = _default_csv_path_from_patterns(patterns_file_path)
    plot_mutational_signatures(csv_path, patterns_file_path)
    print("Mutational signature plots saved in 'plots/' directory")

# %%
def plot_spearman_with_age(csv_path, patterns_file_path):
    """Plot scatter of each numeric column vs Age with Spearman correlation."""
    sns.set_theme(style="whitegrid", font_scale=1.1)
    df = pd.read_csv(csv_path)
    output_dir = "spearman's plots"
    os.makedirs(output_dir, exist_ok=True)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if 'Age' not in numeric_cols:
        print("No 'Age' column found.")
        return
    numeric_cols = [c for c in numeric_cols if c != 'Age']
    df = df.dropna(subset=['Age'])
    spearman_results = []
    version = _get_patterns_version(patterns_file_path)
    for col in numeric_cols:
        sub_df = df.dropna(subset=[col])
        if sub_df.shape[0] < 2:
            continue
        x, y = sub_df['Age'], sub_df[col]
        corr, pval = stats.spearmanr(x, y)
        spearman_results.append({'Column': col, 'Spearman_r': corr, 'p_value': pval})
        plt.figure(figsize=(8, 6))
        ax = sns.scatterplot(x=x, y=y)
        if len(x) > 1:
            sns.regplot(x=x, y=y, scatter=False, ci=None, line_kws={'color': 'red', 'linestyle': '--'}, ax=ax)
        ax.set_xlabel('Age (years)'); ax.set_ylabel(col)
        ax.set_title(f"Spearman's ρ = {corr:.2f} (p={pval:.2g})\n{col} vs Age [{version}]", fontsize=14)
        plt.tight_layout()
        safe_col = col.replace('/', '_').replace(' ', '_').replace('>', 'to').replace('<', 'lt').replace(':', '_')
        plt.savefig(os.path.join(output_dir, f"{safe_col}_vs_Age.png"), dpi=200)
        plt.close()
    pd.DataFrame(spearman_results).to_csv(os.path.join(output_dir, "spearman_results.csv"), index=False)

def plot_spearman_with_age_main(patterns_file_path):
    csv_path = _default_csv_path_from_patterns(patterns_file_path)
    plot_spearman_with_age(csv_path, patterns_file_path)
    print("Spearman plots saved in \"spearman's plots/\" directory")

def plot_mutation_r_heatmap(csv_path, target_col='Age', patterns_file_path=None):
    """Heatmap of Spearman r values between per_1k mutation columns and target."""
    df = pd.read_csv(csv_path)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if target_col not in numeric_cols:
        print(f"No '{target_col}' column found.")
        return
    mutation_cols = [c for c in numeric_cols if 'per_1k' in c or 'per1k' in c]
    if 'total_mutations_per_1k_reads' in df.columns and 'total_mutations_per_1k_reads' not in mutation_cols:
        mutation_cols.append('total_mutations_per_1k_reads')
    total_mut_col = next((c for c in numeric_cols if 'total_mutation' in c and c not in mutation_cols), None)
    if total_mut_col:
        mutation_cols.append(total_mut_col)
    frameshift_cols = [c for c in numeric_cols if 'frameshift' in c.lower() and 'per_1k' in c]
    mutation_cols.extend([c for c in frameshift_cols if c not in mutation_cols])
    if not mutation_cols:
        print("No per_1k mutation columns found.")
        return
    df = df.dropna(subset=[target_col])
    r_values = []
    for col in mutation_cols:
        sub_df = df.dropna(subset=[col])
        r_values.append(stats.spearmanr(sub_df[col], sub_df[target_col])[0] if sub_df.shape[0] >= 2 else float('nan'))
    r_df = pd.DataFrame({'Mutation': mutation_cols, 'Spearman_r': r_values}).set_index('Mutation')
    plt.figure(figsize=(max(8, len(mutation_cols)*0.4), 2.5))
    sns.heatmap(r_df.T, annot=True, cmap='coolwarm', center=0, cbar_kws={'label': "Spearman's r"})
    version = _get_patterns_version(patterns_file_path) if patterns_file_path else 'unknown'
    plt.title(f"Spearman r values: Normalized Mutations vs {target_col} [{version}]")
    plt.yticks(rotation=0)
    plt.tight_layout()
    output_dir = "spearman's plots"
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, f"mutation_r_heatmap_vs_{target_col}.png")
    plt.savefig(output_path, dpi=200)
    plt.close()
    print(f"Mutation r heatmap saved as {output_path}")

def plot_pairwise_r_heatmap(csv_path, patterns_file_path=None):
    """Pairwise Spearman r heatmap between per_1k, Age, telomere columns."""
    df = pd.read_csv(csv_path)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    mutation_cols = [c for c in numeric_cols if 'per_1k' in c or 'per1k' in c]
    if 'total_mutations_per_1k_reads' in df.columns and 'total_mutations_per_1k_reads' not in mutation_cols:
        mutation_cols.append('total_mutations_per_1k_reads')
    total_mut_col = next((c for c in numeric_cols if 'total_mutation' in c and c not in mutation_cols), None)
    if total_mut_col:
        mutation_cols.append(total_mut_col)
    frameshift_cols = [c for c in numeric_cols if 'frameshift' in c.lower() and 'per_1k' in c]
    mutation_cols.extend([c for c in frameshift_cols if c not in mutation_cols])
    if 'Total_Reads' in df.columns and 'Total_Reads' in numeric_cols and 'Total_Reads' not in mutation_cols:
        mutation_cols.append('Total_Reads')
    if 'Age' in df.columns and 'Age' in numeric_cols and 'Age' not in mutation_cols:
        mutation_cols.append('Age')
    telomere_cols = [c for c in df.columns if 'telomere' in c.lower() and c in numeric_cols and c not in mutation_cols]
    mutation_cols.extend(telomere_cols)
    if not mutation_cols:
        print("No relevant columns for pairwise heatmap.")
        return
    n = len(mutation_cols)
    r_matrix = np.zeros((n, n))
    for i, col1 in enumerate(mutation_cols):
        for j, col2 in enumerate(mutation_cols):
            sub_df = df[[col1, col2]].dropna()
            r_val = stats.spearmanr(sub_df[col1], sub_df[col2])[0] if sub_df.shape[0] >= 2 else np.nan
            r_matrix[i, j] = float(r_val) if isinstance(r_val, numbers.Number) and not isinstance(r_val, (list, tuple, np.ndarray)) else np.nan
    mask = np.eye(n, dtype=bool)
    fig_width, fig_height = max(10, n*0.7), max(8, n*0.7)
    plt.figure(figsize=(fig_width, fig_height))
    ax = sns.heatmap(r_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0, mask=mask,
                     xticklabels=mutation_cols, yticklabels=mutation_cols, cbar_kws={'label': "Spearman's r"}, annot_kws={"size": 8})
    for i in range(n):
        ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False, edgecolor='black', lw=2, hatch='xx'))
    version = _get_patterns_version(patterns_file_path) if patterns_file_path else 'unknown'
    plt.title(f"Pairwise Spearman r Heatmap (Normalized Mutations, Age, Telomere) [{version}]", fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=9)
    plt.yticks(fontsize=9)
    plt.tight_layout()
    output_dir = "spearman's plots"
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, "pairwise_mutation_r_heatmap.png")
    plt.savefig(output_path, dpi=200)
    plt.close()
    print(f"Pairwise mutation r heatmap saved as {output_path}")

def plot_pairwise_r_heatmap_main(patterns_file_path):
    csv_path = _default_csv_path_from_patterns(patterns_file_path)
    plot_pairwise_r_heatmap(csv_path, patterns_file_path=patterns_file_path)

# %% [markdown]
# ## Run All Plots (equivalent to: main.py run / main.py plot)
#
# Run the cell below to execute the full plotting pipeline: histograms, mutational signatures, Spearman correlations, pairwise heatmap, trendlines, and curve fitting.

# %%
# Run full plotting pipeline (equivalent to main.py run after generate, or main.py plot)
print("[2/2] Running plots ...")
os.makedirs(_HISTOGRAM_DIR, exist_ok=True)
plot_histograms_from_csv(csv_path, output_dir=_HISTOGRAM_DIR)
# plot_mutational_signatures_main(PATTERNS_PATH)
plot_spearman_with_age_main(PATTERNS_PATH)
plot_pairwise_r_heatmap_main(PATTERNS_PATH)
# Trendlines
def _unique_output_path(directory, base_name, ext):
    os.makedirs(directory, exist_ok=True)
    timestamp = datetime.now().strftime('%Y-%m-%d_%H%M%S')
    return os.path.join(directory, f"{base_name}_{timestamp}.{ext}")
_TRENDLINE_VARIABLES = ["total_mutations_over_total_g_strand_per_1k", "g_strand_T>C_sum_per_1k", "g_strand_G>T_sum_per_1k", "g_strand_T>G_sum_per_1k"]
_TRENDLINE_TITLES = ["Total Mutations Normalized", "T > C Mutation Rate Normalized", "G > T Mutation Rate Normalized", "T > G Mutation Rate Normalized"]
trendline_output = _unique_output_path(_TRENDLINES_DIR, "trendline", "png")
spearman_output = _unique_output_path(_SPEARMAN_CORRELATIONS_DIR, "spearman_correlation", "png")
plot_trendlines_main(csv_path, trendline_output, spearman_output, _TRENDLINE_VARIABLES, _TRENDLINE_TITLES, PATTERNS_PATH)

print("\nAll plotting complete.")
# Out:
# [2/2] Running plots ...
# Histogram plot saved as '/Users/akhilpeddikuppa/FieldLab/GreiderCodeSearch/analysis/histograms/histogram.png'
# Mutations per file histogram saved as '/Users/akhilpeddikuppa/FieldLab/GreiderCodeSearch/analysis/histograms/mutations_per_file_histogram.png'
# Processed 153 files
# Spearman plots saved in "spearman's plots/" directory
# Pairwise mutation r heatmap saved as spearman's plots/pairwise_mutation_r_heatmap.png
# Trendline plot saved as '/Users/akhilpeddikuppa/FieldLab/GreiderCodeSearch/analysis/trendlines/trendline_2026-02-18_140130.png'
# Spearman correlation plot saved as '/Users/akhilpeddikuppa/FieldLab/GreiderCodeSearch/analysis/spearman_correlations/spearman_correlation_2026-02-18_140130.png'
#
# All plotting complete.
