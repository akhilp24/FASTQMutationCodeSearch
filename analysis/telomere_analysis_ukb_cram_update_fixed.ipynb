# %% [markdown]
# # Telomere Analysis Pipeline
#
# **Workflow:**
# 1. **Generate** - Build telomere_analysis CSV from CRAM files (FASTQ/FASTA accepted as fallback)
# 2. **Plot** - Run histograms, mutational signatures, Spearman correlations, pairwise heatmap, trendlines, and curve fitting
#
# **Key parameters (Cell 5):**
# - `REPEAT_K` — number of GGGTTA repeats (e.g. 3 → 18-base pattern). Single-base modifications are always counted in the **2nd repeat**.
# - `CRAM_DIR` — directory containing one CRAM file per sample (no R1/R2 split).
# - `REFERENCE_FASTA` — optional path to reference FASTA for CRAM decoding (set `None` for reference-free CRAMs).
# - `OUTPUT_TXT` — plain-text summary written after the generate step.

# %%
# Install required packages (run once in UKB JupyterLab)
import subprocess, sys

packages = ['pysam', 'seaborn', 'scipy', 'matplotlib', 'pandas', 'numpy']
for pkg in packages:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--quiet', pkg])
print('All packages installed.')
# Out:
# All packages installed.

# %%
# Imports
import gzip
import json
from collections import defaultdict
import csv
import os
import sys
import numpy as np
import glob
import pysam
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.optimize import curve_fit
from scipy import stats
from scipy.stats import spearmanr, linregress
import numbers
from datetime import datetime

# %% [markdown]
# ## Configuration
#
# Set these paths to match your setup. Run from the **analysis** directory or adjust paths accordingly.

# %%
# Load your data
df = pd.read_csv("/mnt/project/Telomere/Telomere_length_age.csv")

# 1. Take user input for the Participant ID
# We use int() because ID numbers in your CSV are likely stored as integers
target_id = int(input("Enter the Participant ID: "))

# 2. Filter the DataFrame for that ID
result = df[df['Participant ID'] == target_id]

# 3. Check if the ID was found and print the age
if not result.empty:
    age = result['Age at recruitment'].values[0]
    print(f"The age for Participant ID {target_id} is: {age}")
else:
    print(f"Participant ID {target_id} not found in the dataset.")

# %%
# UKB Configuration
import os

# Input: can be a single CRAM file OR a directory
# CRAM_INPUT = "/project-J0J4VJ8J7pf8gJKjjZgYjkzJ:/Bulk/GATK and GraphTyper WGS/Whole genome GATK CRAM files and indices [500k release]/10/1000052_23372_0_0.cram"
CRAM_INPUT = "/mnt/project/Bulk/GATK and GraphTyper WGS/Whole genome GATK CRAM files and indices [500k release]/10/1000052_23372_0_0.cram"
# Output directory (must be a directory, not a .cram path)
OUTPUT_DIR = "/opt/notebooks"

_ANALYSIS_DIR = OUTPUT_DIR

# Number of GGGTTA / CCCTAA repeat units
REPEAT_K = 3

# Optional reference FASTA for CRAM decoding
REFERENCE_FASTA = "/mnt/project/Bulk/Exome sequences/Exome OQFE CRAM files/helper_files/GRCh38_full_analysis_set_plus_decoy_hla.fa"
METADATA_PATH = None

# Outputs
CSV_OUT = os.path.join(OUTPUT_DIR, "telomere_analysis_ukb.csv")
OUTPUT_TXT = os.path.join(OUTPUT_DIR, "output.txt")
_TRENDLINES_DIR = os.path.join(OUTPUT_DIR, "trendlines")
_SPEARMAN_CORRELATIONS_DIR = os.path.join(OUTPUT_DIR, "spearman_correlations")
_HISTOGRAM_DIR = os.path.join(OUTPUT_DIR, "histograms")

print("Configuration complete")
print(f"Repeat k            : {REPEAT_K}")
print(f"Input path          : {CRAM_INPUT}")
print(f"Reference FASTA     : {REFERENCE_FASTA or 'None (reference-free CRAM)'}")
print(f"Output CSV          : {CSV_OUT}")
print(f"Output summary TXT  : {OUTPUT_TXT}")
# Out:
# Configuration complete
# Repeat k            : 3
# Input path          : /mnt/project/Bulk/GATK and GraphTyper WGS/Whole genome GATK CRAM files and indices [500k release]/10/1000052_23372_0_0.cram
# Reference FASTA     : /mnt/project/Bulk/Exome sequences/Exome OQFE CRAM files/helper_files/GRCh38_full_analysis_set_plus_decoy_hla.fa
# Output CSV          : /opt/notebooks/telomere_analysis_ukb.csv
# Output summary TXT  : /opt/notebooks/output.txt

# %%
# Load UKB telomere length + age data to annotate samples after CSV generation
# This reads the Telomere_length_age.csv already in /mnt/project/Telomere/
import pandas as pd

ukb_df = pd.read_csv("/mnt/project/Telomere/Telomere_length_age.csv")
print("UKB metadata loaded:", ukb_df.shape)
print(ukb_df.head())

# %% [markdown]
# ## Generate CSV
#
# Programmatically build telomere patterns from `REPEAT_K`, scan CRAM files (one per sample),
# count canonical and mutant telomere reads, and write the combined CSV + `output.txt` summary.
#
# Single-base modifications are always the variants of the **2nd** GGGTTA/CCCTAA repeat within each k-repeat pattern.
# No JSON patterns file is needed; no R1/R2 file pairing is required.

# %%
# ---------------------------------------------------------------------------
# Pattern generation — k-repeat patterns, all 6 phases
# ---------------------------------------------------------------------------
# The telomeric repeat (GGGTTA / CCCTAA) can start at any of 6 offsets in a
# sequencing read. The original code searched only one phase (GGGTTA×k),
# missing ~75-85 % of telomeric signal because TTAGGG is the dominant phase.
#
# Searching individual hexamers across all rotations fixes detection but
# creates a false-positive problem for mutations: 216 mutant hexamers match
# random genomic sequence in ~5.6 % of all 6-mers, producing more spurious
# mutation hits than real canonical hits.
#
# Solution: keep the k-repeat (18-mer for k=3) pattern length for both
# canonical and mutant patterns — this virtually eliminates false positives
# from random sequence — but generate each pattern in all 6 phases so every
# telomeric read is counted regardless of its starting offset.
#
# For telomeric READ DETECTION (pre-screen) we still use single hexamers
# across all rotations, which is intentionally permissive. Quantification
# then uses the strict 18-mer matching.
# ---------------------------------------------------------------------------

G_REPEAT_UNIT = "GGGTTA"
C_REPEAT_UNIT = "CCCTAA"


def _hexamer_rotations(hexamer: str):
    """Return all 6 circular rotations of a hexamer."""
    return [hexamer[i:] + hexamer[:i] for i in range(len(hexamer))]


def _make_kmer_phases(canonical_hex: str, k: int = 3,
                      mut_pos: int = None, mut_base: str = None):
    """Generate all 6 phase variants of a k-repeat pattern (length 6*k).

    If mut_pos and mut_base are given, the mutation is placed in the 2nd
    repeat unit (positions 6..11 in the phase-0 frame).  Phase-shifting then
    naturally moves the mutation to the correct relative position.
    """
    # Build k+1 repeats so we can extract 6 phases of length 6*k
    long_seq = list(canonical_hex * (k + 1))
    if mut_pos is not None and mut_base is not None:
        long_seq[len(canonical_hex) + mut_pos] = mut_base   # mutate in 2nd repeat
    long_seq = "".join(long_seq)
    return [long_seq[phase: phase + len(canonical_hex) * k] for phase in range(len(canonical_hex))]


# Pre-compute canonical rotation sets for the telomeric pre-screen
G_HEX_ROTATIONS = _hexamer_rotations(G_REPEAT_UNIT)
C_HEX_ROTATIONS = _hexamer_rotations(C_REPEAT_UNIT)
_TELOMERE_ANCHORS = frozenset(G_HEX_ROTATIONS + C_HEX_ROTATIONS)


def _is_telomeric(sequence: str) -> bool:
    """Return True if the sequence contains any canonical telomere hexamer (any phase)."""
    return any(anchor in sequence for anchor in _TELOMERE_ANCHORS)


def _count_canonical_hexamers(sequence: str) -> tuple:
    """Quick hexamer count for the telomeric threshold check.

    Returns (g_hex_hits, c_hex_hits) across all 6 rotations.
    """
    g = sum(sequence.count(r) for r in G_HEX_ROTATIONS)
    c = sum(sequence.count(r) for r in C_HEX_ROTATIONS)
    return g, c


# ----- Mutation specifications (labels & positions unchanged) -----
_G_STRAND_MUT_SPEC = {
    "G>A_g1": (0, "G", "A"), "G>A_g2": (1, "G", "A"), "G>A_g3": (2, "G", "A"),
    "G>C_g1": (0, "G", "C"), "G>C_g2": (1, "G", "C"), "G>C_g3": (2, "G", "C"),
    "G>T_g1": (0, "G", "T"), "G>T_g2": (1, "G", "T"), "G>T_g3": (2, "G", "T"),
    "T>A_t1": (3, "T", "A"), "T>A_t2": (4, "T", "A"),
    "T>C_t1": (3, "T", "C"), "T>C_t2": (4, "T", "C"),
    "T>G_t1": (3, "T", "G"), "T>G_t2": (4, "T", "G"),
    "A>T_a1": (5, "A", "T"), "A>G_a1": (5, "A", "G"), "A>C_a1": (5, "A", "C"),
}
_C_STRAND_MUT_SPEC = {
    "C>A_c1": (0, "C", "A"), "C>A_c2": (1, "C", "A"), "C>A_c3": (2, "C", "A"),
    "C>G_c1": (0, "C", "G"), "C>G_c2": (1, "C", "G"), "C>G_c3": (2, "C", "G"),
    "C>T_c1": (0, "C", "T"), "C>T_c2": (1, "C", "T"), "C>T_c3": (2, "C", "T"),
    "T>A_t1": (3, "T", "A"), "T>C_t1": (3, "T", "C"), "T>G_t1": (3, "T", "G"),
    "A>T_a1": (4, "A", "T"), "A>T_a2": (5, "A", "T"),
    "A>G_a1": (4, "A", "G"), "A>G_a2": (5, "A", "G"),
    "A>C_a1": (4, "A", "C"), "A>C_a2": (5, "A", "C"),
}

GENERAL_MUTATION_MAP = {
    "g_strand": {
        "G>A": ["G>A_g1", "G>A_g2", "G>A_g3"],
        "G>C": ["G>C_g1", "G>C_g2", "G>C_g3"],
        "G>T": ["G>T_g1", "G>T_g2", "G>T_g3"],
        "T>A": ["T>A_t1", "T>A_t2"], "T>C": ["T>C_t1", "T>C_t2"], "T>G": ["T>G_t1", "T>G_t2"],
        "A>T": ["A>T_a1"], "A>G": ["A>G_a1"], "A>C": ["A>C_a1"],
    },
    "c_strand": {
        "C>A": ["C>A_c1", "C>A_c2", "C>A_c3"],
        "C>G": ["C>G_c1", "C>G_c2", "C>G_c3"],
        "C>T": ["C>T_c1", "C>T_c2", "C>T_c3"],
        "T>A": ["T>A_t1"], "T>C": ["T>C_t1"], "T>G": ["T>G_t1"],
        "A>T": ["A>T_a1", "A>T_a2"], "A>G": ["A>G_a1", "A>G_a2"], "A>C": ["A>C_a1", "A>C_a2"],
    },
}


def generate_patterns(k: int):
    """Generate telomere patterns: k-repeat sequences in all 6 phases.

    Returns the same dict structure as before — each pattern value is now a
    **list of 6 strings** (one per phase) instead of a single string.
    Downstream counting sums hits across all 6 phases.
    """
    if k < 2:
        raise ValueError(f"k must be >= 2; got {k}")

    g_can_phases = _make_kmer_phases(G_REPEAT_UNIT, k)
    c_can_phases = _make_kmer_phases(C_REPEAT_UNIT, k)

    g_mut_patterns = {}
    for subkey, (pos, _orig, new_base) in _G_STRAND_MUT_SPEC.items():
        g_mut_patterns[subkey] = _make_kmer_phases(G_REPEAT_UNIT, k,
                                                    mut_pos=pos, mut_base=new_base)

    c_mut_patterns = {}
    for subkey, (pos, _orig, new_base) in _C_STRAND_MUT_SPEC.items():
        c_mut_patterns[subkey] = _make_kmer_phases(C_REPEAT_UNIT, k,
                                                    mut_pos=pos, mut_base=new_base)

    patterns = {
        "g_strand": g_can_phases,
        "c_strand": c_can_phases,
        "g_strand_mutations": g_mut_patterns,
        "c_strand_mutations": c_mut_patterns,
    }
    return patterns, GENERAL_MUTATION_MAP, f"{k}x_repeat"


def count_pattern_phases(sequence: str, phase_list: list) -> int:
    """Count total occurrences of a pattern across all 6 phase variants."""
    return sum(sequence.count(p) for p in phase_list)


# ---------------------------------------------------------------------------
# CRAM file reading — yields ALL reads (no pre-filter)
# ---------------------------------------------------------------------------

def verify_cram_index(file_path: str) -> bool:
    crai_path = file_path + ".crai"
    alt_crai_path = file_path.replace(".cram", ".crai")
    if os.path.exists(crai_path) or os.path.exists(alt_crai_path):
        return True
    print(f"  WARNING: No .crai index found for {os.path.basename(file_path)}.")
    return False


def read_cram_file(file_path: str, reference_fasta: str = None):
    """Read a CRAM file and yield ALL query sequences.

    No pre-filter — total_reads in the main loop will reflect the true
    number of reads.  Telomeric classification is done in generate_csv().
    """
    kwargs = {}
    if reference_fasta:
        kwargs["reference_filename"] = reference_fasta
    verify_cram_index(file_path)
    with pysam.AlignmentFile(file_path, "rc", **kwargs) as af:
        for read in af.fetch(until_eof=True):
            if read.query_sequence:
                yield read.query_sequence


def count_cram_reads(file_path: str, reference_fasta: str = None) -> int:
    kwargs = {}
    if reference_fasta:
        kwargs["reference_filename"] = reference_fasta
    count = 0
    with pysam.AlignmentFile(file_path, "rc", **kwargs) as af:
        for read in af.fetch(until_eof=True):
            if read.query_sequence:
                count += 1
    return count


def get_cram_files(directory: str):
    return sorted(glob.glob(os.path.join(directory, "*.cram")))


def resolve_input_files(input_path: str):
    p = str(input_path).strip()
    low = p.lower()
    if low.endswith(".cram"):
        return [p], "CRAM(single-file)"
    if low.endswith((".fastq", ".fastq.gz", ".fasta", ".fasta.gz",
                     ".fa", ".fa.gz", ".fas", ".fas.gz")):
        return [p], "FASTQ/FASTA(single-file)"
    cram_files = get_cram_files(p)
    if cram_files:
        return cram_files, "CRAM"
    seq_files = get_sequence_files(p)
    if seq_files:
        return seq_files, "FASTQ/FASTA"
    return [], "unknown"


# ---------------------------------------------------------------------------
# FASTQ / FASTA reading (fallback)
# ---------------------------------------------------------------------------

def read_sequence_file(file_path: str):
    open_func = gzip.open if file_path.endswith(".gz") else open
    is_fasta = any(ext in file_path.lower() for ext in [".fasta", ".fa", ".fas"])
    with open_func(file_path, "rt") as f:
        if is_fasta:
            current_sequence = ""
            for line in f:
                line = line.strip()
                if line.startswith(">"):
                    if current_sequence:
                        yield current_sequence
                    current_sequence = ""
                else:
                    current_sequence += line
            if current_sequence:
                yield current_sequence
        else:
            while True:
                header = f.readline().strip()
                if not header:
                    break
                sequence = f.readline().strip()
                _ = f.readline()
                _ = f.readline()
                yield sequence


def get_sequence_files(directory: str):
    files = []
    for ext in ["*.fastq", "*.fastq.gz", "*.fasta", "*.fasta.gz",
                "*.fa", "*.fa.gz", "*.fas", "*.fas.gz"]:
        files.extend(glob.glob(os.path.join(directory, ext)))
    return sorted(files)


def count_total_reads(file_path: str, reference_fasta: str = None) -> int:
    if file_path.endswith(".cram"):
        return count_cram_reads(file_path, reference_fasta)
    open_func = gzip.open if file_path.endswith(".gz") else open
    count = 0
    with open_func(file_path, "rt") as f:
        for _ in f:
            count += 1
    is_fasta = any(ext in file_path.lower() for ext in [".fasta", ".fa", ".fas"])
    return count // 2 if is_fasta else count // 4


# ---------------------------------------------------------------------------
# Metadata helpers (unchanged)
# ---------------------------------------------------------------------------

def load_age_data(metadata_file_path=None):
    age_data = {}
    if metadata_file_path is None:
        for candidate in [
            "greider_methods_table_s2_outliers_removed.csv",
            "../analysis/greider_methods_table_s2_outliers_removed.csv",
            "analysis/greider_methods_table_s2_outliers_removed.csv",
        ]:
            if os.path.exists(candidate):
                metadata_file_path = candidate
                break
        else:
            return age_data
    with open(metadata_file_path, "r") as f:
        reader = csv.DictReader(f)
        for row in reader:
            name = row["fastq file name"].replace("_", ".")
            age_data[name] = row["Age (Years)"]
    return age_data


def load_length_data(metadata_file_path=None):
    length_data = {}
    if metadata_file_path is None:
        for candidate in [
            "greider_methods_table_s2_outliers_removed.csv",
            "../analysis/greider_methods_table_s2_outliers_removed.csv",
            "analysis/greider_methods_table_s2_outliers_removed.csv",
        ]:
            if os.path.exists(candidate):
                metadata_file_path = candidate
                break
        else:
            return length_data
    with open(metadata_file_path, "r") as f:
        reader = csv.DictReader(f)
        for row in reader:
            name = row["fastq file name"].replace("_", ".")
            length_data[name] = row["Mean Telomere Length (bps)"]
    return length_data

print("Cell 8 loaded: k-repeat patterns with all 6 phases")
p, _, v = generate_patterns(3)
print(f"  G-strand canonical phases: {p['g_strand']}")
print(f"  C-strand canonical phases: {p['c_strand']}")
print(f"  G-strand mutation keys: {len(p['g_strand_mutations'])}")
print(f"  C-strand mutation keys: {len(p['c_strand_mutations'])}")
print(f"  Example G>A_g1 phases: {p['g_strand_mutations']['G>A_g1']}")
# Out:
# Cell 8 loaded: k-repeat patterns with all 6 phases
#   G-strand canonical phases: ['GGGTTAGGGTTAGGGTTA', 'GGTTAGGGTTAGGGTTAG', 'GTTAGGGTTAGGGTTAGG', 'TTAGGGTTAGGGTTAGGG', 'TAGGGTTAGGGTTAGGGT', 'AGGGTTAGGGTTAGGGTT']
#   C-strand canonical phases: ['CCCTAACCCTAACCCTAA', 'CCTAACCCTAACCCTAAC', 'CTAACCCTAACCCTAACC', 'TAACCCTAACCCTAACCC', 'AACCCTAACCCTAACCCT', 'ACCCTAACCCTAACCCTA']
#   G-strand mutation keys: 18
#   C-strand mutation keys: 18
#   Example G>A_g1 phases: ['GGGTTAAGGTTAGGGTTA', 'GGTTAAGGTTAGGGTTAG', 'GTTAAGGTTAGGGTTAGG', 'TTAAGGTTAGGGTTAGGG', 'TAAGGTTAGGGTTAGGGT', 'AAGGTTAGGGTTAGGGTT']

# %%
def _write_output_summary(txt_path, summary_rows, version, k, data_dir, csv_path,
                           file_type, patterns, general_mutation_map):
    """Write a human-readable plain-text summary of the analysis run."""
    total_reads = sum(r["total_reads"] for r in summary_rows)
    total_c = sum(r["c_strand"] for r in summary_rows)
    total_g = sum(r["g_strand"] for r in summary_rows)
    total_telomere = total_c + total_g
    total_mutations = sum(r["total_mutations"] for r in summary_rows)
    total_telomeric_reads = sum(r.get("telomeric_reads", 0) for r in summary_rows)

    with open(txt_path, "w") as f:
        f.write("=" * 72 + "\n")
        f.write("TELOMERE ANALYSIS — OUTPUT SUMMARY (phase-aware k-mer counting)\n")
        f.write("=" * 72 + "\n")
        f.write(f"Run date/time       : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write(f"Pattern version     : {version}  (k={k} repeats × 6 phases)\n")
        f.write(f"Input directory     : {data_dir}\n")
        f.write(f"Input file type     : {file_type}\n")
        f.write(f"Output CSV          : {csv_path}\n")
        f.write(f"Output TXT          : {txt_path}\n")
        f.write("\n")
        f.write("CANONICAL PATTERNS (all 6 phases searched)\n")
        f.write(f"  G-strand phases: {', '.join(patterns['g_strand'])}\n")
        f.write(f"  C-strand phases: {', '.join(patterns['c_strand'])}\n")
        f.write(f"  G-strand variants : {len(patterns['g_strand_mutations'])}\n")
        f.write(f"  C-strand variants : {len(patterns['c_strand_mutations'])}\n")
        f.write("\n")
        f.write("SINGLE-BASE MODIFICATION VARIANTS — G-strand\n")
        for subkey, phases in patterns["g_strand_mutations"].items():
            f.write(f"  {subkey:<12}: {phases[0]}  (+ 5 phase variants)\n")
        f.write("\n")
        f.write("SINGLE-BASE MODIFICATION VARIANTS — C-strand\n")
        for subkey, phases in patterns["c_strand_mutations"].items():
            f.write(f"  {subkey:<12}: {phases[0]}  (+ 5 phase variants)\n")
        f.write("\n")
        f.write("=" * 72 + "\n")
        f.write("RUN SUMMARY\n")
        f.write("=" * 72 + "\n")
        f.write(f"Samples processed       : {len(summary_rows)}\n")
        f.write(f"Total reads             : {total_reads:,}\n")
        f.write(f"Telomeric reads         : {total_telomeric_reads:,}\n")
        f.write(f"Total k-mer hits        : {total_telomere:,}  (c-strand + g-strand)\n")
        f.write(f"  C-strand hits         : {total_c:,}\n")
        f.write(f"  G-strand hits         : {total_g:,}\n")
        f.write(f"Total mutations found   : {total_mutations:,}\n")
        if total_reads > 0:
            f.write(f"Telomeric read fraction : {total_telomeric_reads / total_reads:.6f}\n")
        f.write("\n")
        f.write("PER-SAMPLE RESULTS\n")
        f.write("-" * 72 + "\n")
        f.write(f"{'Sample':<22} {'Total Reads':>13} {'C-strand':>10} {'G-strand':>10} {'Mutations':>10}\n")
        f.write("-" * 72 + "\n")
        for r in summary_rows:
            f.write(
                f"{r['sample_id']:<22} {r['total_reads']:>13,} "
                f"{r['c_strand']:>10} {r['g_strand']:>10} {r['total_mutations']:>10}\n"
            )
        f.write("-" * 72 + "\n")
        f.write(
            f"{'TOTAL':<22} {total_reads:>13,} {total_c:>10} {total_g:>10} {total_mutations:>10}\n"
        )
        f.write("\n")
        f.write("MUTATION TYPE GROUPINGS\n")
        f.write("-" * 72 + "\n")
        for strand, mutmap in general_mutation_map.items():
            f.write(f"\n{strand}:\n")
            for mut_type, subkeys in mutmap.items():
                f.write(f"  {mut_type}: {', '.join(subkeys)}\n")
        f.write("\n")
        f.write("=" * 72 + "\n")
        f.write("END OF SUMMARY\n")
        f.write("=" * 72 + "\n")


def generate_csv(
    data_dir: str,
    k: int = 3,
    reference_fasta: str = None,
    output_callback=None,
    metadata_file_path=None,
    output_csv_path=None,
    output_txt_path=None,
):
    """
    Generate a single CSV file from CRAM (or FASTQ/FASTA) telomere data.

    Phase-aware rewrite: every canonical and mutant pattern is searched in
    all 6 phase variants of the k-repeat k-mer.  Telomeric reads are
    identified by a permissive hexamer pre-screen, then quantified with
    strict k-mer matching that has virtually zero false-positive rate on
    random genomic sequence.

    total_reads reflects ALL reads in the file (not pre-filtered).
    """
    patterns, general_mutation_map, version = generate_patterns(k)

    if output_csv_path is None:
        safe_version = version.replace(" ", "_")
        csv_path = f"telomere_analysis_{safe_version}.csv"
    else:
        csv_path = output_csv_path
        parent = os.path.dirname(csv_path)
        if parent:
            os.makedirs(parent, exist_ok=True)

    input_files, file_type = resolve_input_files(data_dir)

    if not input_files:
        msg = f"No CRAM or FASTQ/FASTA files found in: {data_dir}"
        print(msg)
        if output_callback:
            output_callback(msg)
        return None

    msg = f"Found {len(input_files)} {file_type} file(s) in {data_dir}"
    print(msg)
    if output_callback:
        output_callback(msg)

    age_data = load_age_data(metadata_file_path)
    length_data = load_length_data(metadata_file_path)

    mutation_keys = []
    for group in ["g_strand_mutations", "c_strand_mutations"]:
        for subkey in patterns[group].keys():
            mutation_keys.append(f"{group}_{subkey}")

    fieldnames = ["FileName", "Age", "Telomere_Length", "Total_Reads",
                  "Telomeric_Reads", "c_strand", "g_strand"]
    fieldnames.extend(mutation_keys)
    fieldnames.extend([f"{mk}_per_1k" for mk in mutation_keys])
    general_mutation_headers = []
    for strand, mutmap in general_mutation_map.items():
        for mut in mutmap:
            general_mutation_headers.append(f"{strand}_{mut}_per_1k")
    fieldnames.extend(general_mutation_headers)
    fieldnames.extend([
        "composite_transition_per_1k", "composite_transversion_per_1k",
        "g_strand_mutations_sum_per_1k", "c_strand_mutations_sum_per_1k",
        "log_telomere_length", "telomere_length_bin", "mutation_rate_normalized_by_length",
    ])
    for strand, mutmap in general_mutation_map.items():
        for mut in mutmap:
            fieldnames.append(f"{strand}_{mut}_sum_per_1k")
    fieldnames.append("total_mutations_per_1k_strand_specific")
    fieldnames.extend([
        "total_mutations_over_total_g_strand_per_1k",
        "total_mutations_over_total_c_strand_per_1k",
    ])

    summary_rows = []

    # Minimum total canonical hexamer hits (across all rotations) to
    # classify a read as telomeric before running the full k-mer search.
    _TELOMERIC_HEX_THRESHOLD = 4

    with open(csv_path, "w", newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for file_path in input_files:
            filename = os.path.basename(file_path)

            if any(ref in filename for ref in ["GRCh38", "hg38", "reference"]):
                continue

            sample_id = filename
            for ext in [".cram", ".fastq.gz", ".fastq", ".fasta.gz", ".fasta",
                        ".fa.gz", ".fa", ".fas.gz", ".fas"]:
                if sample_id.endswith(ext):
                    sample_id = sample_id[: -len(ext)]
                    break

            counts = defaultdict(int)
            total_reads = 0
            telomeric_reads = 0
            _PROGRESS_INTERVAL = 1_000_000
            _loop_start = time.time()

            seq_iter = (
                read_cram_file(file_path, reference_fasta)
                if file_path.endswith(".cram")
                else read_sequence_file(file_path)
            )

            for sequence in seq_iter:
                total_reads += 1

                # ----- Fast pre-screen (single hexamers, any rotation) -----
                if not _is_telomeric(sequence):
                    if total_reads % _PROGRESS_INTERVAL == 0:
                        _elapsed = time.time() - _loop_start
                        _rate = total_reads / _elapsed if _elapsed > 0 else 0
                        print(
                            f"  [progress] {total_reads:>12,} reads scanned  "
                            f"| {telomeric_reads:,} telomeric  "
                            f"| {_rate:,.0f} reads/sec  "
                            f"| elapsed {int(_elapsed // 60)}m {int(_elapsed % 60):02d}s",
                            flush=True,
                        )
                    continue

                # ----- Hexamer threshold check -----
                g_hex, c_hex = _count_canonical_hexamers(sequence)
                if (g_hex + c_hex) < _TELOMERIC_HEX_THRESHOLD:
                    if total_reads % _PROGRESS_INTERVAL == 0:
                        _elapsed = time.time() - _loop_start
                        _rate = total_reads / _elapsed if _elapsed > 0 else 0
                        print(
                            f"  [progress] {total_reads:>12,} reads scanned  "
                            f"| {telomeric_reads:,} telomeric  "
                            f"| {_rate:,.0f} reads/sec  "
                            f"| elapsed {int(_elapsed // 60)}m {int(_elapsed % 60):02d}s",
                            flush=True,
                        )
                    continue

                telomeric_reads += 1

                # ----- Strict k-mer counting (all 6 phases) -----
                counts["g_strand"] += count_pattern_phases(sequence, patterns["g_strand"])
                counts["c_strand"] += count_pattern_phases(sequence, patterns["c_strand"])

                for group in ["g_strand_mutations", "c_strand_mutations"]:
                    for subkey, phase_list in patterns[group].items():
                        counts[f"{group}_{subkey}"] += count_pattern_phases(
                            sequence, phase_list
                        )

                if total_reads % _PROGRESS_INTERVAL == 0:
                    _elapsed = time.time() - _loop_start
                    _rate = total_reads / _elapsed if _elapsed > 0 else 0
                    print(
                        f"  [progress] {total_reads:>12,} reads scanned  "
                        f"| {telomeric_reads:,} telomeric  "
                        f"| {_rate:,.0f} reads/sec  "
                        f"| elapsed {int(_elapsed // 60)}m {int(_elapsed % 60):02d}s",
                        flush=True,
                    )

            # ---------- Per-sample summary & CSV row ----------
            age = age_data.get(sample_id, "")
            length = length_data.get(sample_id, "")
            g_strand_total = counts["g_strand"]
            c_strand_total = counts["c_strand"]
            g_strand_mutations_total = sum(
                counts[mk] for mk in counts if mk.startswith("g_strand_mutations_")
            )
            c_strand_mutations_total = sum(
                counts[mk] for mk in counts if mk.startswith("c_strand_mutations_")
            )
            g_strand_normalizer = g_strand_total + g_strand_mutations_total
            c_strand_normalizer = c_strand_total + c_strand_mutations_total

            def per_1k_ss(val, norm):
                return (val / norm) * 1000 if norm > 0 else 0

            row = {
                "FileName": sample_id,
                "Age": age,
                "Telomere_Length": length,
                "Total_Reads": total_reads,
                "Telomeric_Reads": telomeric_reads,
                "c_strand": c_strand_total,
                "g_strand": g_strand_total,
            }
            for mk in mutation_keys:
                row[mk] = counts.get(mk, 0)
                norm = (
                    g_strand_normalizer
                    if mk.startswith("g_strand_mutations_")
                    else c_strand_normalizer
                )
                row[f"{mk}_per_1k"] = per_1k_ss(counts.get(mk, 0), norm)
            for strand, mutmap in general_mutation_map.items():
                norm = (
                    g_strand_normalizer if strand == "g_strand" else c_strand_normalizer
                )
                for mut, subtypes in mutmap.items():
                    total = sum(
                        counts.get(f"{strand}_mutations_{st}", 0) for st in subtypes
                    )
                    row[f"{strand}_{mut}_per_1k"] = per_1k_ss(total, norm)
            for strand, mutmap in general_mutation_map.items():
                for mut, subtypes in mutmap.items():
                    row[f"{strand}_{mut}_sum_per_1k"] = sum(
                        row.get(f"{strand}_mutations_{st}_per_1k", 0) for st in subtypes
                    )
            total_mutations = sum(counts[mk] for mk in mutation_keys)
            if total_mutations > 0 and (
                g_strand_normalizer > 0 or c_strand_normalizer > 0
            ):
                g_w = g_strand_mutations_total / total_mutations
                c_w = c_strand_mutations_total / total_mutations
                w_norm = g_w * g_strand_normalizer + c_w * c_strand_normalizer
                row["total_mutations_per_1k_strand_specific"] = per_1k_ss(
                    total_mutations, w_norm
                )
            else:
                row["total_mutations_per_1k_strand_specific"] = 0
            row["total_mutations_over_total_g_strand_per_1k"] = per_1k_ss(
                total_mutations, g_strand_normalizer
            )
            row["total_mutations_over_total_c_strand_per_1k"] = per_1k_ss(
                total_mutations, c_strand_normalizer
            )
            row["g_strand_mutations_sum_per_1k"] = sum(
                v
                for rk, v in row.items()
                if rk.startswith("g_strand_mutations") and rk.endswith("_per_1k")
            )
            row["c_strand_mutations_sum_per_1k"] = sum(
                v
                for rk, v in row.items()
                if rk.startswith("c_strand_mutations") and rk.endswith("_per_1k")
            )
            try:
                row["log_telomere_length"] = np.log1p(float(length)) if length else 0
            except Exception:
                row["log_telomere_length"] = 0
            try:
                lv = float(length)
                row["telomere_length_bin"] = (
                    "short" if lv < 5000 else ("medium" if lv < 8000 else "long")
                )
            except Exception:
                row["telomere_length_bin"] = "unknown"
            try:
                lv = float(length)
                row["mutation_rate_normalized_by_length"] = (
                    row["g_strand_mutations_sum_per_1k"] / lv if lv > 0 else 0
                )
            except Exception:
                row["mutation_rate_normalized_by_length"] = 0

            writer.writerow(row)

            messages = [
                f"\nSample  : {sample_id}  ({file_type}: {filename})",
                f"  Age              : {age}",
                f"  Telomere Length  : {length}",
                f"  Total Reads      : {total_reads:,}",
                f"  Telomeric Reads  : {telomeric_reads:,}",
                f"  Telomeric Frac   : {telomeric_reads / total_reads:.6f}" if total_reads > 0 else "  Telomeric Frac   : N/A",
                f"  {version} c-strand: {c_strand_total}",
                f"  {version} g-strand: {g_strand_total}",
                f"  G-strand mutations: {g_strand_mutations_total}",
                f"  C-strand mutations: {c_strand_mutations_total}",
                f"  G-strand normalizer: {g_strand_normalizer}",
                f"  C-strand normalizer: {c_strand_normalizer}",
                f"  Total mutations  : {total_mutations}",
            ]
            if g_strand_total == 0 and c_strand_total == 0:
                messages.append(
                    f"  WARNING: No telomere sequences found in {sample_id}"
                )
            for msg in messages:
                print(msg)
                if output_callback:
                    output_callback(msg)

            summary_rows.append(
                {
                    "sample_id": sample_id,
                    "file": filename,
                    "total_reads": total_reads,
                    "telomeric_reads": telomeric_reads,
                    "c_strand": c_strand_total,
                    "g_strand": g_strand_total,
                    "g_strand_mutations": g_strand_mutations_total,
                    "c_strand_mutations": c_strand_mutations_total,
                    "total_mutations": total_mutations,
                    "age": age,
                    "telomere_length": length,
                }
            )

    if output_txt_path and summary_rows:
        _write_output_summary(
            output_txt_path,
            summary_rows,
            version,
            k,
            data_dir,
            csv_path,
            file_type,
            patterns,
            general_mutation_map,
        )
        print(f"\nSummary written to: {output_txt_path}")

    return csv_path

# %%
### Quick Check

p = CRAM_INPUT
print("CRAM_INPUT:", p)
print("exists:", os.path.exists(p))
print("isfile:", os.path.isfile(p))
print("isdir :", os.path.isdir(p))
if os.path.isdir(p):
    print("Directory contents sample:")
    print(glob.glob(os.path.join(p, "*"))[:20])
    
    
print("REFERENCE_FASTA:", REFERENCE_FASTA)
print("exists:", os.path.exists(REFERENCE_FASTA))
print("isfile:", os.path.isfile(REFERENCE_FASTA))
fai = REFERENCE_FASTA + ".fai"
print("FAI exists:", os.path.exists(fai), fai)
# Out:
# CRAM_INPUT: /mnt/project/Bulk/GATK and GraphTyper WGS/Whole genome GATK CRAM files and indices [500k release]/10/1000052_23372_0_0.cram
# exists: True
# isfile: True
# isdir : False
# REFERENCE_FASTA: /mnt/project/Bulk/Exome sequences/Exome OQFE CRAM files/helper_files/GRCh38_full_analysis_set_plus_decoy_hla.fa
# exists: True
# isfile: True
# FAI exists: True /mnt/project/Bulk/Exome sequences/Exome OQFE CRAM files/helper_files/GRCh38_full_analysis_set_plus_decoy_hla.fa.fai

# %%
import time
import threading
import sys

print('[1/2] Generating telomere_analysis CSV from UKB CRAM files...')
print(f'  Repeat k            : {REPEAT_K}')
print(f'  Input directory     : {CRAM_INPUT}')
print(f'  Reference FASTA     : {REFERENCE_FASTA or "None (reference-free)"}')
print()

# Live elapsed-time ticker printed on a single updating line
_stop_ticker = threading.Event()

def _ticker(start):
    while not _stop_ticker.is_set():
        elapsed = time.time() - start
        m, s = divmod(int(elapsed), 60)
        h, m = divmod(m, 60)
        print(f'  Elapsed: {h:02d}:{m:02d}:{s:02d}', end='\r', flush=True)
        time.sleep(1)

start_time = time.time()
_ticker_thread = threading.Thread(target=_ticker, args=(start_time,), daemon=True)
_ticker_thread.start()

try:
    csv_path_result = generate_csv(
        data_dir=CRAM_INPUT,
        k=REPEAT_K,
        reference_fasta=REFERENCE_FASTA,
        metadata_file_path=METADATA_PATH,
        output_csv_path=CSV_OUT,
        output_txt_path=OUTPUT_TXT,
    )
finally:
    _stop_ticker.set()
    _ticker_thread.join()

elapsed = time.time() - start_time
h, rem = divmod(int(elapsed), 3600)
m, s = divmod(rem, 60)
print(f'  Elapsed: {h:02d}:{m:02d}:{s:02d}  (done)')  # overwrite ticker line
print(f'\nTotal runtime: {h:02d}:{m:02d}:{s:02d}')

csv_path = csv_path_result if csv_path_result else CSV_OUT
print(f'CSV written to    : {csv_path}')
print(f'Summary written to: {OUTPUT_TXT}')
# Out:
# [1/2] Generating telomere_analysis CSV from UKB CRAM files...
#   Repeat k            : 3
#   Input directory     : /mnt/project/Bulk/GATK and GraphTyper WGS/Whole genome GATK CRAM files and indices [500k release]/10/1000052_23372_0_0.cram
#   Reference FASTA     : /mnt/project/Bulk/Exome sequences/Exome OQFE CRAM files/helper_files/GRCh38_full_analysis_set_plus_decoy_hla.fa
#
# Found 1 CRAM(single-file) file(s) in /mnt/project/Bulk/GATK and GraphTyper WGS/Whole genome GATK CRAM files and indices [500k release]/10/1000052_23372_0_0.cram
#   [progress]    1,000,000 reads scanned  | 9,224 telomeric  | 85,702 reads/sec  | elapsed 0m 11s
#   [progress]    2,000,000 reads scanned  | 16,963 telomeric  | 104,645 reads/sec  | elapsed 0m 19s
#   [progress]    3,000,000 reads scanned  | 23,148 telomeric  | 113,219 reads/sec  | elapsed 0m 26s
#   [progress]    4,000,000 reads scanned  | 30,446 telomeric  | 117,595 reads/sec  | elapsed 0m 34s
#   [progress]    5,000,000 reads scanned  | 38,749 telomeric  | 120,570 reads/sec  | elapsed 0m 41s
#   [progress]    6,000,000 reads scanned  | 45,617 telomeric  | 122,668 reads/sec  | elapsed 0m 48s
#   [progress]    7,000,000 reads scanned  | 53,026 telomeric  | 124,007 reads/sec  | elapsed 0m 56s
#   [progress]    8,000,000 reads scanned  | 59,698 telomeric  | 125,238 reads/sec  | elapsed 1m 03s
#   [progress]    9,000,000 reads scanned  | 66,993 telomeric  | 126,119 reads/sec  | elapsed 1m 11s
#   [progress]   10,000,000 reads scanned  | 74,060 telomeric  | 126,884 reads/sec  | elapsed 1m 18s
#   [progress]   11,000,000 reads scanned  | 81,938 telomeric  | 127,422 reads/sec  | elapsed 1m 26s
#   [progress]   12,000,000 reads scanned  | 89,474 telomeric  | 127,838 reads/sec  | elapsed 1m 33s
#   [progress]   13,000,000 reads scanned  | 97,427 telomeric  | 128,097 reads/sec  | elapsed 1m 41s
#   [progress]   14,000,000 reads scanned  | 105,358 telomeric  | 128,419 reads/sec  | elapsed 1m 49s
#   [progress]   15,000,000 reads scanned  | 112,801 telomeric  | 128,733 reads/sec  | elapsed 1m 56s
#   [progress]   16,000,000 reads scanned  | 119,537 telomeric  | 129,109 reads/sec  | elapsed 2m 03s
#   [progress]   17,000,000 reads scanned  | 125,789 telomeric  | 129,459 reads/sec  | elapsed 2m 11s
#   [progress]   18,000,000 reads scanned  | 131,996 telomeric  | 129,833 reads/sec  | elapsed 2m 18s
#   [progress]   19,000,000 reads scanned  | 137,942 telomeric  | 130,157 reads/sec  | elapsed 2m 25s
#   [progress]   20,000,000 reads scanned  | 144,542 telomeric  | 130,415 reads/sec  | elapsed 2m 33s
#   [progress]   21,000,000 reads scanned  | 151,589 telomeric  | 130,605 reads/sec  | elapsed 2m 40s
#   [progress]   22,000,000 reads scanned  | 158,299 telomeric  | 130,791 reads/sec  | elapsed 2m 48s
#   [progress]   23,000,000 reads scanned  | 164,927 telomeric  | 130,940 reads/sec  | elapsed 2m 55s
#   [progress]   24,000,000 reads scanned  | 171,466 telomeric  | 131,095 reads/sec  | elapsed 3m 03s
#   [progress]   25,000,000 reads scanned  | 176,895 telomeric  | 131,360 reads/sec  | elapsed 3m 10s
#   [progress]   26,000,000 reads scanned  | 183,478 telomeric  | 131,344 reads/sec  | elapsed 3m 17s
#   [progress]   27,000,000 reads scanned  | 188,407 telomeric  | 131,482 reads/sec  | elapsed 3m 25s
#   [progress]   28,000,000 reads scanned  | 196,077 telomeric  | 131,506 reads/sec  | elapsed 3m 32s
#   [progress]   29,000,000 reads scanned  | 203,090 telomeric  | 131,582 reads/sec  | elapsed 3m 40s
#   [progress]   30,000,000 reads scanned  | 210,711 telomeric  | 131,640 reads/sec  | elapsed 3m 47s
#   [progress]   31,000,000 reads scanned  | 214,186 telomeric  | 131,854 reads/sec  | elapsed 3m 55s
#   [progress]   32,000,000 reads scanned  | 214,440 telomeric  | 132,358 reads/sec  | elapsed 4m 01s
#   [progress]   33,000,000 reads scanned  | 214,679 telomeric  | 132,935 reads/sec  | elapsed 4m 08s
#   [progress]   34,000,000 reads scanned  | 215,035 telomeric  | 133,536 reads/sec  | elapsed 4m 14s
#   [progress]   35,000,000 reads scanned  | 215,175 telomeric  | 134,380 reads/sec  | elapsed 4m 20s
#   [progress]   36,000,000 reads scanned  | 215,306 telomeric  | 135,117 reads/sec  | elapsed 4m 26s
#   [progress]   37,000,000 reads scanned  | 219,966 telomeric  | 135,226 reads/sec  | elapsed 4m 33s
#   [progress]   38,000,000 reads scanned  | 228,511 telomeric  | 135,030 reads/sec  | elapsed 4m 41s
#   [progress]   39,000,000 reads scanned  | 236,779 telomeric  | 134,903 reads/sec  | elapsed 4m 49s
#   [progress]   40,000,000 reads scanned  | 244,342 telomeric  | 134,817 reads/sec  | elapsed 4m 56s
#   [progress]   41,000,000 reads scanned  | 252,512 telomeric  | 134,754 reads/sec  | elapsed 5m 04s
#   [progress]   42,000,000 reads scanned  | 260,057 telomeric  | 134,716 reads/sec  | elapsed 5m 11s
#   [progress]   43,000,000 reads scanned  | 266,890 telomeric  | 134,717 reads/sec  | elapsed 5m 19s
#   [progress]   44,000,000 reads scanned  | 273,373 telomeric  | 134,668 reads/sec  | elapsed 5m 26s
#   [progress]   45,000,000 reads scanned  | 280,722 telomeric  | 134,644 reads/sec  | elapsed 5m 34s
#   [progress]   46,000,000 reads scanned  | 287,368 telomeric  | 134,644 reads/sec  | elapsed 5m 41s
#   [progress]   47,000,000 reads scanned  | 294,921 telomeric  | 134,624 reads/sec  | elapsed 5m 49s
#   [progress]   48,000,000 reads scanned  | 300,152 telomeric  | 134,704 reads/sec  | elapsed 5m 56s
#   [progress]   49,000,000 reads scanned  | 305,754 telomeric  | 134,784 reads/sec  | elapsed 6m 03s
#   [progress]   50,000,000 reads scanned  | 311,295 telomeric  | 134,865 reads/sec  | elapsed 6m 10s
#   [progress]   51,000,000 reads scanned  | 318,032 telomeric  | 134,869 reads/sec  | elapsed 6m 18s
#   [progress]   52,000,000 reads scanned  | 326,684 telomeric  | 134,782 reads/sec  | elapsed 6m 25s
#   [progress]   53,000,000 reads scanned  | 334,414 telomeric  | 134,741 reads/sec  | elapsed 6m 33s
#   [progress]   54,000,000 reads scanned  | 341,663 telomeric  | 134,721 reads/sec  | elapsed 6m 40s
#   [progress]   55,000,000 reads scanned  | 348,286 telomeric  | 134,739 reads/sec  | elapsed 6m 48s
#   [progress]   56,000,000 reads scanned  | 354,532 telomeric  | 134,777 reads/sec  | elapsed 6m 55s
#   [progress]   57,000,000 reads scanned  | 361,634 telomeric  | 134,725 reads/sec  | elapsed 7m 03s
#   [progress]   58,000,000 reads scanned  | 369,346 telomeric  | 134,706 reads/sec  | elapsed 7m 10s
#   [progress]   59,000,000 reads scanned  | 376,148 telomeric  | 134,716 reads/sec  | elapsed 7m 17s
#   [progress]   60,000,000 reads scanned  | 382,662 telomeric  | 134,703 reads/sec  | elapsed 7m 25s
#   [progress]   61,000,000 reads scanned  | 388,163 telomeric  | 134,750 reads/sec  | elapsed 7m 32s
#   [progress]   62,000,000 reads scanned  | 394,556 telomeric  | 134,740 reads/sec  | elapsed 7m 40s
#   [progress]   63,000,000 reads scanned  | 402,841 telomeric  | 134,686 reads/sec  | elapsed 7m 47s
#   [progress]   64,000,000 reads scanned  | 409,740 telomeric  | 134,693 reads/sec  | elapsed 7m 55s
#   [progress]   65,000,000 reads scanned  | 416,222 telomeric  | 134,715 reads/sec  | elapsed 8m 02s
#   [progress]   66,000,000 reads scanned  | 422,972 telomeric  | 134,725 reads/sec  | elapsed 8m 09s
#   [progress]   67,000,000 reads scanned  | 428,492 telomeric  | 134,755 reads/sec  | elapsed 8m 17s
#   [progress]   68,000,000 reads scanned  | 435,267 telomeric  | 134,764 reads/sec  | elapsed 8m 24s
#   [progress]   69,000,000 reads scanned  | 441,897 telomeric  | 134,773 reads/sec  | elapsed 8m 31s
#   [progress]   70,000,000 reads scanned  | 448,479 telomeric  | 134,783 reads/sec  | elapsed 8m 39s
#   [progress]   71,000,000 reads scanned  | 455,309 telomeric  | 134,781 reads/sec  | elapsed 8m 46s
#   [progress]   72,000,000 reads scanned  | 461,003 telomeric  | 134,704 reads/sec  | elapsed 8m 54s
#   [progress]   73,000,000 reads scanned  | 467,877 telomeric  | 134,655 reads/sec  | elapsed 9m 02s
#   [progress]   74,000,000 reads scanned  | 474,014 telomeric  | 134,667 reads/sec  | elapsed 9m 09s
#   [progress]   75,000,000 reads scanned  | 480,762 telomeric  | 134,644 reads/sec  | elapsed 9m 17s
#   [progress]   76,000,000 reads scanned  | 487,912 telomeric  | 134,623 reads/sec  | elapsed 9m 24s
#   [progress]   77,000,000 reads scanned  | 494,455 telomeric  | 134,634 reads/sec  | elapsed 9m 31s
#   [progress]   78,000,000 reads scanned  | 500,821 telomeric  | 134,647 reads/sec  | elapsed 9m 39s
#   [progress]   79,000,000 reads scanned  | 507,310 telomeric  | 134,666 reads/sec  | elapsed 9m 46s
#   [progress]   80,000,000 reads scanned  | 514,294 telomeric  | 134,642 reads/sec  | elapsed 9m 54s
#   [progress]   81,000,000 reads scanned  | 521,398 telomeric  | 134,633 reads/sec  | elapsed 10m 01s
#   [progress]   82,000,000 reads scanned  | 528,524 telomeric  | 134,622 reads/sec  | elapsed 10m 09s
#   [progress]   83,000,000 reads scanned  | 536,264 telomeric  | 134,602 reads/sec  | elapsed 10m 16s
#   [progress]   84,000,000 reads scanned  | 542,114 telomeric  | 134,629 reads/sec  | elapsed 10m 23s
#   [progress]   85,000,000 reads scanned  | 548,104 telomeric  | 134,659 reads/sec  | elapsed 10m 31s
#   [progress]   86,000,000 reads scanned  | 554,701 telomeric  | 134,641 reads/sec  | elapsed 10m 38s
#   [progress]   87,000,000 reads scanned  | 559,761 telomeric  | 134,530 reads/sec  | elapsed 10m 46s
#   [progress]   88,000,000 reads scanned  | 561,739 telomeric  | 134,649 reads/sec  | elapsed 10m 53s
#   [progress]   89,000,000 reads scanned  | 567,511 telomeric  | 134,659 reads/sec  | elapsed 11m 00s
#   [progress]   90,000,000 reads scanned  | 575,146 telomeric  | 134,639 reads/sec  | elapsed 11m 08s
#   [progress]   91,000,000 reads scanned  | 581,464 telomeric  | 134,653 reads/sec  | elapsed 11m 15s
#   [progress]   92,000,000 reads scanned  | 588,378 telomeric  | 134,639 reads/sec  | elapsed 11m 23s
#   [progress]   93,000,000 reads scanned  | 596,729 telomeric  | 134,598 reads/sec  | elapsed 11m 30s
#   [progress]   94,000,000 reads scanned  | 602,373 telomeric  | 134,620 reads/sec  | elapsed 11m 38s
#   [progress]   95,000,000 reads scanned  | 609,774 telomeric  | 134,599 reads/sec  | elapsed 11m 45s
#   [progress]   96,000,000 reads scanned  | 616,150 telomeric  | 134,618 reads/sec  | elapsed 11m 53s
#   [progress]   97,000,000 reads scanned  | 622,659 telomeric  | 134,630 reads/sec  | elapsed 12m 00s
#   [progress]   98,000,000 reads scanned  | 629,204 telomeric  | 134,617 reads/sec  | elapsed 12m 07s
#   [progress]   99,000,000 reads scanned  | 636,169 telomeric  | 134,602 reads/sec  | elapsed 12m 15s
#   [progress]  100,000,000 reads scanned  | 641,631 telomeric  | 134,635 reads/sec  | elapsed 12m 22s
#   [progress]  101,000,000 reads scanned  | 647,600 telomeric  | 134,654 reads/sec  | elapsed 12m 30s
#   [progress]  102,000,000 reads scanned  | 653,519 telomeric  | 134,671 reads/sec  | elapsed 12m 37s
#   [progress]  103,000,000 reads scanned  | 660,506 telomeric  | 134,664 reads/sec  | elapsed 12m 44s
#   [progress]  104,000,000 reads scanned  | 666,924 telomeric  | 134,683 reads/sec  | elapsed 12m 52s
#   [progress]  105,000,000 reads scanned  | 674,621 telomeric  | 134,661 reads/sec  | elapsed 12m 59s
#   [progress]  106,000,000 reads scanned  | 680,199 telomeric  | 134,693 reads/sec  | elapsed 13m 06s
#   [progress]  107,000,000 reads scanned  | 686,830 telomeric  | 134,702 reads/sec  | elapsed 13m 14s
#   [progress]  108,000,000 reads scanned  | 693,324 telomeric  | 134,704 reads/sec  | elapsed 13m 21s
#   [progress]  109,000,000 reads scanned  | 700,736 telomeric  | 134,696 reads/sec  | elapsed 13m 29s
#   [progress]  110,000,000 reads scanned  | 707,267 telomeric  | 134,706 reads/sec  | elapsed 13m 36s
#   [progress]  111,000,000 reads scanned  | 712,921 telomeric  | 134,732 reads/sec  | elapsed 13m 43s
#   [progress]  112,000,000 reads scanned  | 718,950 telomeric  | 134,754 reads/sec  | elapsed 13m 51s
#   [progress]  113,000,000 reads scanned  | 725,621 telomeric  | 134,767 reads/sec  | elapsed 13m 58s
#   [progress]  114,000,000 reads scanned  | 732,142 telomeric  | 134,779 reads/sec  | elapsed 14m 05s
#   [progress]  115,000,000 reads scanned  | 739,526 telomeric  | 134,768 reads/sec  | elapsed 14m 13s
#   [progress]  116,000,000 reads scanned  | 746,643 telomeric  | 134,764 reads/sec  | elapsed 14m 20s
#   [progress]  117,000,000 reads scanned  | 752,774 telomeric  | 134,767 reads/sec  | elapsed 14m 28s
#   [progress]  118,000,000 reads scanned  | 758,861 telomeric  | 134,779 reads/sec  | elapsed 14m 35s
#   [progress]  119,000,000 reads scanned  | 765,698 telomeric  | 134,769 reads/sec  | elapsed 14m 42s
#   [progress]  120,000,000 reads scanned  | 774,661 telomeric  | 134,741 reads/sec  | elapsed 14m 50s
#   [progress]  121,000,000 reads scanned  | 781,498 telomeric  | 134,743 reads/sec  | elapsed 14m 58s
#   [progress]  122,000,000 reads scanned  | 788,163 telomeric  | 134,755 reads/sec  | elapsed 15m 05s
#   [progress]  123,000,000 reads scanned  | 799,493 telomeric  | 134,692 reads/sec  | elapsed 15m 13s
#   [progress]  124,000,000 reads scanned  | 807,351 telomeric  | 134,674 reads/sec  | elapsed 15m 20s
#   [progress]  125,000,000 reads scanned  | 813,756 telomeric  | 134,691 reads/sec  | elapsed 15m 28s
#   [progress]  126,000,000 reads scanned  | 821,270 telomeric  | 134,680 reads/sec  | elapsed 15m 35s
#   [progress]  127,000,000 reads scanned  | 828,805 telomeric  | 134,669 reads/sec  | elapsed 15m 43s
#   [progress]  128,000,000 reads scanned  | 835,895 telomeric  | 134,669 reads/sec  | elapsed 15m 50s
#   [progress]  129,000,000 reads scanned  | 842,832 telomeric  | 134,677 reads/sec  | elapsed 15m 57s
#   [progress]  130,000,000 reads scanned  | 849,649 telomeric  | 134,670 reads/sec  | elapsed 16m 05s
#   [progress]  131,000,000 reads scanned  | 856,580 telomeric  | 134,676 reads/sec  | elapsed 16m 12s
#   [progress]  132,000,000 reads scanned  | 863,064 telomeric  | 134,679 reads/sec  | elapsed 16m 20s
#   [progress]  133,000,000 reads scanned  | 869,566 telomeric  | 134,683 reads/sec  | elapsed 16m 27s
#   [progress]  134,000,000 reads scanned  | 876,224 telomeric  | 134,689 reads/sec  | elapsed 16m 34s
#   [progress]  135,000,000 reads scanned  | 883,180 telomeric  | 134,693 reads/sec  | elapsed 16m 42s
#   [progress]  136,000,000 reads scanned  | 890,618 telomeric  | 134,681 reads/sec  | elapsed 16m 49s
#   [progress]  137,000,000 reads scanned  | 898,605 telomeric  | 134,669 reads/sec  | elapsed 16m 57s
#   [progress]  138,000,000 reads scanned  | 906,094 telomeric  | 134,661 reads/sec  | elapsed 17m 04s
#   [progress]  139,000,000 reads scanned  | 913,451 telomeric  | 134,659 reads/sec  | elapsed 17m 12s
#   [progress]  140,000,000 reads scanned  | 920,302 telomeric  | 134,657 reads/sec  | elapsed 17m 19s
#   [progress]  141,000,000 reads scanned  | 927,313 telomeric  | 134,653 reads/sec  | elapsed 17m 27s
#   [progress]  142,000,000 reads scanned  | 935,292 telomeric  | 134,642 reads/sec  | elapsed 17m 34s
#   [progress]  143,000,000 reads scanned  | 941,611 telomeric  | 134,650 reads/sec  | elapsed 17m 42s
#   [progress]  144,000,000 reads scanned  | 948,979 telomeric  | 134,646 reads/sec  | elapsed 17m 49s
#   [progress]  145,000,000 reads scanned  | 954,625 telomeric  | 134,662 reads/sec  | elapsed 17m 56s
#   [progress]  146,000,000 reads scanned  | 960,225 telomeric  | 134,690 reads/sec  | elapsed 18m 03s
#   [progress]  147,000,000 reads scanned  | 966,259 telomeric  | 134,715 reads/sec  | elapsed 18m 11s
#   [progress]  148,000,000 reads scanned  | 971,889 telomeric  | 134,739 reads/sec  | elapsed 18m 18s
#   [progress]  149,000,000 reads scanned  | 973,743 telomeric  | 134,804 reads/sec  | elapsed 18m 25s
#   [progress]  150,000,000 reads scanned  | 973,805 telomeric  | 134,880 reads/sec  | elapsed 18m 32s
#   [progress]  151,000,000 reads scanned  | 973,899 telomeric  | 135,006 reads/sec  | elapsed 18m 38s
#   [progress]  152,000,000 reads scanned  | 976,600 telomeric  | 135,056 reads/sec  | elapsed 18m 45s
#   [progress]  153,000,000 reads scanned  | 982,903 telomeric  | 135,062 reads/sec  | elapsed 18m 52s
#   [progress]  154,000,000 reads scanned  | 989,521 telomeric  | 135,061 reads/sec  | elapsed 19m 00s
#   [progress]  155,000,000 reads scanned  | 995,502 telomeric  | 135,073 reads/sec  | elapsed 19m 07s
#   [progress]  156,000,000 reads scanned  | 1,002,689 telomeric  | 135,068 reads/sec  | elapsed 19m 14s
#   [progress]  157,000,000 reads scanned  | 1,009,870 telomeric  | 135,059 reads/sec  | elapsed 19m 22s
#   [progress]  158,000,000 reads scanned  | 1,016,915 telomeric  | 135,055 reads/sec  | elapsed 19m 29s
#   [progress]  159,000,000 reads scanned  | 1,024,330 telomeric  | 135,044 reads/sec  | elapsed 19m 37s
#   [progress]  160,000,000 reads scanned  | 1,032,221 telomeric  | 135,029 reads/sec  | elapsed 19m 44s
#   [progress]  161,000,000 reads scanned  | 1,039,163 telomeric  | 135,029 reads/sec  | elapsed 19m 52s
#   [progress]  162,000,000 reads scanned  | 1,047,159 telomeric  | 135,010 reads/sec  | elapsed 19m 59s
#   [progress]  163,000,000 reads scanned  | 1,053,423 telomeric  | 135,013 reads/sec  | elapsed 20m 07s
#   [progress]  164,000,000 reads scanned  | 1,059,967 telomeric  | 135,014 reads/sec  | elapsed 20m 14s
#   [progress]  165,000,000 reads scanned  | 1,066,488 telomeric  | 135,025 reads/sec  | elapsed 20m 21s
#   [progress]  166,000,000 reads scanned  | 1,073,472 telomeric  | 135,030 reads/sec  | elapsed 20m 29s
#   [progress]  167,000,000 reads scanned  | 1,080,636 telomeric  | 135,027 reads/sec  | elapsed 20m 36s
#   [progress]  168,000,000 reads scanned  | 1,087,857 telomeric  | 135,022 reads/sec  | elapsed 20m 44s
#   [progress]  169,000,000 reads scanned  | 1,095,171 telomeric  | 135,020 reads/sec  | elapsed 20m 51s
#   [progress]  170,000,000 reads scanned  | 1,100,140 telomeric  | 135,047 reads/sec  | elapsed 20m 58s
#   [progress]  171,000,000 reads scanned  | 1,106,766 telomeric  | 135,050 reads/sec  | elapsed 21m 06s
#   [progress]  172,000,000 reads scanned  | 1,112,966 telomeric  | 135,061 reads/sec  | elapsed 21m 13s
#   [progress]  173,000,000 reads scanned  | 1,119,218 telomeric  | 135,071 reads/sec  | elapsed 21m 20s
#   [progress]  174,000,000 reads scanned  | 1,125,209 telomeric  | 135,082 reads/sec  | elapsed 21m 28s
#   [progress]  175,000,000 reads scanned  | 1,131,600 telomeric  | 135,082 reads/sec  | elapsed 21m 35s
#   [progress]  176,000,000 reads scanned  | 1,137,564 telomeric  | 135,090 reads/sec  | elapsed 21m 42s
#   [progress]  177,000,000 reads scanned  | 1,144,104 telomeric  | 135,096 reads/sec  | elapsed 21m 50s
#   [progress]  178,000,000 reads scanned  | 1,153,700 telomeric  | 135,054 reads/sec  | elapsed 21m 57s
#   [progress]  179,000,000 reads scanned  | 1,160,596 telomeric  | 135,060 reads/sec  | elapsed 22m 05s
#   [progress]  180,000,000 reads scanned  | 1,168,286 telomeric  | 135,054 reads/sec  | elapsed 22m 12s
#   [progress]  181,000,000 reads scanned  | 1,175,337 telomeric  | 135,051 reads/sec  | elapsed 22m 20s
#   [progress]  182,000,000 reads scanned  | 1,182,716 telomeric  | 135,044 reads/sec  | elapsed 22m 27s
#   [progress]  183,000,000 reads scanned  | 1,189,765 telomeric  | 135,042 reads/sec  | elapsed 22m 35s
#   [progress]  184,000,000 reads scanned  | 1,196,421 telomeric  | 135,043 reads/sec  | elapsed 22m 42s
#   [progress]  185,000,000 reads scanned  | 1,204,339 telomeric  | 135,024 reads/sec  | elapsed 22m 50s
#   [progress]  186,000,000 reads scanned  | 1,209,558 telomeric  | 135,048 reads/sec  | elapsed 22m 57s
#   [progress]  187,000,000 reads scanned  | 1,214,391 telomeric  | 135,077 reads/sec  | elapsed 23m 04s
#   [progress]  188,000,000 reads scanned  | 1,220,981 telomeric  | 135,079 reads/sec  | elapsed 23m 11s
#   [progress]  189,000,000 reads scanned  | 1,227,450 telomeric  | 135,078 reads/sec  | elapsed 23m 19s
#   [progress]  190,000,000 reads scanned  | 1,233,241 telomeric  | 135,088 reads/sec  | elapsed 23m 26s
#   [progress]  191,000,000 reads scanned  | 1,237,248 telomeric  | 134,969 reads/sec  | elapsed 23m 35s
#   [progress]  192,000,000 reads scanned  | 1,240,136 telomeric  | 134,769 reads/sec  | elapsed 23m 44s
#   [progress]  193,000,000 reads scanned  | 1,242,655 telomeric  | 134,687 reads/sec  | elapsed 23m 52s
#   [progress]  194,000,000 reads scanned  | 1,244,971 telomeric  | 134,767 reads/sec  | elapsed 23m 59s
#   [progress]  195,000,000 reads scanned  | 1,251,661 telomeric  | 134,760 reads/sec  | elapsed 24m 07s
#   [progress]  196,000,000 reads scanned  | 1,257,259 telomeric  | 134,773 reads/sec  | elapsed 24m 14s
#   [progress]  197,000,000 reads scanned  | 1,263,133 telomeric  | 134,789 reads/sec  | elapsed 24m 21s
#   [progress]  198,000,000 reads scanned  | 1,268,507 telomeric  | 134,802 reads/sec  | elapsed 24m 28s
#   [progress]  199,000,000 reads scanned  | 1,274,328 telomeric  | 134,810 reads/sec  | elapsed 24m 36s
#   [progress]  200,000,000 reads scanned  | 1,281,706 telomeric  | 134,805 reads/sec  | elapsed 24m 43s
#   [progress]  201,000,000 reads scanned  | 1,288,813 telomeric  | 134,799 reads/sec  | elapsed 24m 51s
#   [progress]  202,000,000 reads scanned  | 1,295,065 telomeric  | 134,801 reads/sec  | elapsed 24m 58s
#   [progress]  203,000,000 reads scanned  | 1,301,241 telomeric  | 134,806 reads/sec  | elapsed 25m 05s
#   [progress]  204,000,000 reads scanned  | 1,306,736 telomeric  | 134,823 reads/sec  | elapsed 25m 13s
#   [progress]  205,000,000 reads scanned  | 1,313,061 telomeric  | 134,832 reads/sec  | elapsed 25m 20s
#   [progress]  206,000,000 reads scanned  | 1,319,738 telomeric  | 134,834 reads/sec  | elapsed 25m 27s
#   [progress]  207,000,000 reads scanned  | 1,326,577 telomeric  | 134,837 reads/sec  | elapsed 25m 35s
#   [progress]  208,000,000 reads scanned  | 1,333,345 telomeric  | 134,838 reads/sec  | elapsed 25m 42s
#   [progress]  209,000,000 reads scanned  | 1,339,523 telomeric  | 134,845 reads/sec  | elapsed 25m 49s
#   [progress]  210,000,000 reads scanned  | 1,345,619 telomeric  | 134,858 reads/sec  | elapsed 25m 57s
#   [progress]  211,000,000 reads scanned  | 1,351,200 telomeric  | 134,868 reads/sec  | elapsed 26m 04s
#   [progress]  212,000,000 reads scanned  | 1,357,484 telomeric  | 134,873 reads/sec  | elapsed 26m 11s
#   [progress]  213,000,000 reads scanned  | 1,363,460 telomeric  | 134,885 reads/sec  | elapsed 26m 19s
#   [progress]  214,000,000 reads scanned  | 1,369,633 telomeric  | 134,888 reads/sec  | elapsed 26m 26s
#   [progress]  215,000,000 reads scanned  | 1,375,289 telomeric  | 134,906 reads/sec  | elapsed 26m 33s
#   [progress]  216,000,000 reads scanned  | 1,381,037 telomeric  | 134,921 reads/sec  | elapsed 26m 40s
#   [progress]  217,000,000 reads scanned  | 1,388,219 telomeric  | 134,920 reads/sec  | elapsed 26m 48s
#   [progress]  218,000,000 reads scanned  | 1,394,923 telomeric  | 134,919 reads/sec  | elapsed 26m 55s
#   [progress]  219,000,000 reads scanned  | 1,401,191 telomeric  | 134,926 reads/sec  | elapsed 27m 03s
#   [progress]  220,000,000 reads scanned  | 1,408,313 telomeric  | 134,918 reads/sec  | elapsed 27m 10s
#   [progress]  221,000,000 reads scanned  | 1,414,454 telomeric  | 134,925 reads/sec  | elapsed 27m 17s
#   [progress]  222,000,000 reads scanned  | 1,419,796 telomeric  | 134,933 reads/sec  | elapsed 27m 25s
#   [progress]  223,000,000 reads scanned  | 1,425,527 telomeric  | 134,942 reads/sec  | elapsed 27m 32s
#   [progress]  224,000,000 reads scanned  | 1,431,652 telomeric  | 134,946 reads/sec  | elapsed 27m 39s
#   [progress]  225,000,000 reads scanned  | 1,438,174 telomeric  | 134,954 reads/sec  | elapsed 27m 47s
#   [progress]  226,000,000 reads scanned  | 1,444,045 telomeric  | 134,967 reads/sec  | elapsed 27m 54s
#   [progress]  227,000,000 reads scanned  | 1,450,023 telomeric  | 134,977 reads/sec  | elapsed 28m 01s
#   [progress]  228,000,000 reads scanned  | 1,456,900 telomeric  | 134,976 reads/sec  | elapsed 28m 09s
#   [progress]  229,000,000 reads scanned  | 1,463,880 telomeric  | 134,944 reads/sec  | elapsed 28m 16s
#   [progress]  230,000,000 reads scanned  | 1,483,118 telomeric  | 134,840 reads/sec  | elapsed 28m 25s
#   [progress]  231,000,000 reads scanned  | 1,489,783 telomeric  | 134,845 reads/sec  | elapsed 28m 33s
#   [progress]  232,000,000 reads scanned  | 1,496,656 telomeric  | 134,846 reads/sec  | elapsed 28m 40s
#   [progress]  233,000,000 reads scanned  | 1,503,184 telomeric  | 134,855 reads/sec  | elapsed 28m 47s
#   [progress]  234,000,000 reads scanned  | 1,509,060 telomeric  | 134,859 reads/sec  | elapsed 28m 55s
#   [progress]  235,000,000 reads scanned  | 1,514,664 telomeric  | 134,831 reads/sec  | elapsed 29m 02s
#   [progress]  236,000,000 reads scanned  | 1,520,354 telomeric  | 134,826 reads/sec  | elapsed 29m 10s
#   [progress]  237,000,000 reads scanned  | 1,525,010 telomeric  | 134,803 reads/sec  | elapsed 29m 18s
#   [progress]  238,000,000 reads scanned  | 1,531,257 telomeric  | 134,782 reads/sec  | elapsed 29m 25s
#   [progress]  239,000,000 reads scanned  | 1,538,649 telomeric  | 134,776 reads/sec  | elapsed 29m 33s
#   [progress]  240,000,000 reads scanned  | 1,545,494 telomeric  | 134,775 reads/sec  | elapsed 29m 40s
#   [progress]  241,000,000 reads scanned  | 1,551,476 telomeric  | 134,784 reads/sec  | elapsed 29m 48s
#   [progress]  242,000,000 reads scanned  | 1,553,622 telomeric  | 134,720 reads/sec  | elapsed 29m 56s
#   [progress]  243,000,000 reads scanned  | 1,556,482 telomeric  | 134,722 reads/sec  | elapsed 30m 03s
#   [progress]  244,000,000 reads scanned  | 1,562,706 telomeric  | 134,726 reads/sec  | elapsed 30m 11s
#   [progress]  245,000,000 reads scanned  | 1,569,459 telomeric  | 134,727 reads/sec  | elapsed 30m 18s
#   [progress]  246,000,000 reads scanned  | 1,576,189 telomeric  | 134,729 reads/sec  | elapsed 30m 25s
#   [progress]  247,000,000 reads scanned  | 1,582,771 telomeric  | 134,729 reads/sec  | elapsed 30m 33s
#   [progress]  248,000,000 reads scanned  | 1,589,712 telomeric  | 134,692 reads/sec  | elapsed 30m 41s
#   [progress]  249,000,000 reads scanned  | 1,596,914 telomeric  | 134,689 reads/sec  | elapsed 30m 48s
#   [progress]  250,000,000 reads scanned  | 1,604,183 telomeric  | 134,685 reads/sec  | elapsed 30m 56s
#   [progress]  251,000,000 reads scanned  | 1,610,829 telomeric  | 134,687 reads/sec  | elapsed 31m 03s
#   [progress]  252,000,000 reads scanned  | 1,616,711 telomeric  | 134,697 reads/sec  | elapsed 31m 10s
#   [progress]  253,000,000 reads scanned  | 1,623,230 telomeric  | 134,702 reads/sec  | elapsed 31m 18s
#   [progress]  254,000,000 reads scanned  | 1,629,552 telomeric  | 134,708 reads/sec  | elapsed 31m 25s
#   [progress]  255,000,000 reads scanned  | 1,635,583 telomeric  | 134,714 reads/sec  | elapsed 31m 32s
#   [progress]  256,000,000 reads scanned  | 1,641,331 telomeric  | 134,724 reads/sec  | elapsed 31m 40s
#   [progress]  257,000,000 reads scanned  | 1,647,356 telomeric  | 134,731 reads/sec  | elapsed 31m 47s
#   [progress]  258,000,000 reads scanned  | 1,653,733 telomeric  | 134,735 reads/sec  | elapsed 31m 54s
#   [progress]  259,000,000 reads scanned  | 1,661,547 telomeric  | 134,728 reads/sec  | elapsed 32m 02s
#   [progress]  260,000,000 reads scanned  | 1,668,388 telomeric  | 134,730 reads/sec  | elapsed 32m 09s
#   [progress]  261,000,000 reads scanned  | 1,674,277 telomeric  | 134,738 reads/sec  | elapsed 32m 17s
#   [progress]  262,000,000 reads scanned  | 1,682,208 telomeric  | 134,731 reads/sec  | elapsed 32m 24s
#   [progress]  263,000,000 reads scanned  | 1,688,069 telomeric  | 134,736 reads/sec  | elapsed 32m 31s
#   [progress]  264,000,000 reads scanned  | 1,694,332 telomeric  | 134,736 reads/sec  | elapsed 32m 39s
#   [progress]  265,000,000 reads scanned  | 1,701,547 telomeric  | 134,730 reads/sec  | elapsed 32m 46s
#   [progress]  266,000,000 reads scanned  | 1,709,423 telomeric  | 134,723 reads/sec  | elapsed 32m 54s
#   [progress]  267,000,000 reads scanned  | 1,716,558 telomeric  | 134,721 reads/sec  | elapsed 33m 01s
#   [progress]  268,000,000 reads scanned  | 1,724,416 telomeric  | 134,715 reads/sec  | elapsed 33m 09s
#   [progress]  269,000,000 reads scanned  | 1,731,881 telomeric  | 134,706 reads/sec  | elapsed 33m 16s
#   [progress]  270,000,000 reads scanned  | 1,738,681 telomeric  | 134,704 reads/sec  | elapsed 33m 24s
#   [progress]  271,000,000 reads scanned  | 1,745,110 telomeric  | 134,707 reads/sec  | elapsed 33m 31s
#   [progress]  272,000,000 reads scanned  | 1,750,940 telomeric  | 134,711 reads/sec  | elapsed 33m 39s
#   [progress]  273,000,000 reads scanned  | 1,758,216 telomeric  | 134,707 reads/sec  | elapsed 33m 46s
#   [progress]  274,000,000 reads scanned  | 1,766,129 telomeric  | 134,700 reads/sec  | elapsed 33m 54s
#   [progress]  275,000,000 reads scanned  | 1,773,537 telomeric  | 134,694 reads/sec  | elapsed 34m 01s
#   [progress]  276,000,000 reads scanned  | 1,780,249 telomeric  | 134,698 reads/sec  | elapsed 34m 09s
#   [progress]  277,000,000 reads scanned  | 1,786,674 telomeric  | 134,702 reads/sec  | elapsed 34m 16s
#   [progress]  278,000,000 reads scanned  | 1,793,221 telomeric  | 134,705 reads/sec  | elapsed 34m 23s
#   [progress]  279,000,000 reads scanned  | 1,800,012 telomeric  | 134,705 reads/sec  | elapsed 34m 31s
#   [progress]  280,000,000 reads scanned  | 1,807,348 telomeric  | 134,699 reads/sec  | elapsed 34m 38s
#   [progress]  281,000,000 reads scanned  | 1,813,944 telomeric  | 134,699 reads/sec  | elapsed 34m 46s
#   [progress]  282,000,000 reads scanned  | 1,820,094 telomeric  | 134,703 reads/sec  | elapsed 34m 53s
#   [progress]  283,000,000 reads scanned  | 1,827,196 telomeric  | 134,688 reads/sec  | elapsed 35m 01s
#   [progress]  284,000,000 reads scanned  | 1,835,252 telomeric  | 134,637 reads/sec  | elapsed 35m 09s
#   [progress]  285,000,000 reads scanned  | 1,842,271 telomeric  | 134,636 reads/sec  | elapsed 35m 16s
#   [progress]  286,000,000 reads scanned  | 1,851,327 telomeric  | 134,623 reads/sec  | elapsed 35m 24s
#   [progress]  287,000,000 reads scanned  | 1,860,307 telomeric  | 134,608 reads/sec  | elapsed 35m 32s
#   [progress]  288,000,000 reads scanned  | 1,866,306 telomeric  | 134,614 reads/sec  | elapsed 35m 39s
#   [progress]  289,000,000 reads scanned  | 1,873,532 telomeric  | 134,611 reads/sec  | elapsed 35m 46s
#   [progress]  290,000,000 reads scanned  | 1,880,234 telomeric  | 134,609 reads/sec  | elapsed 35m 54s
#   [progress]  291,000,000 reads scanned  | 1,892,677 telomeric  | 134,604 reads/sec  | elapsed 36m 01s
#   [progress]  292,000,000 reads scanned  | 1,897,751 telomeric  | 134,609 reads/sec  | elapsed 36m 09s
#   [progress]  293,000,000 reads scanned  | 1,902,895 telomeric  | 134,623 reads/sec  | elapsed 36m 16s
#   [progress]  294,000,000 reads scanned  | 1,909,294 telomeric  | 134,627 reads/sec  | elapsed 36m 23s
#   [progress]  295,000,000 reads scanned  | 1,916,073 telomeric  | 134,629 reads/sec  | elapsed 36m 31s
#   [progress]  296,000,000 reads scanned  | 1,922,379 telomeric  | 134,633 reads/sec  | elapsed 36m 38s
#   [progress]  297,000,000 reads scanned  | 1,928,802 telomeric  | 134,636 reads/sec  | elapsed 36m 45s
#   [progress]  298,000,000 reads scanned  | 1,936,281 telomeric  | 134,632 reads/sec  | elapsed 36m 53s
#   [progress]  299,000,000 reads scanned  | 1,942,989 telomeric  | 134,634 reads/sec  | elapsed 37m 00s
#   [progress]  300,000,000 reads scanned  | 1,948,445 telomeric  | 134,648 reads/sec  | elapsed 37m 08s
#   [progress]  301,000,000 reads scanned  | 1,954,823 telomeric  | 134,653 reads/sec  | elapsed 37m 15s
#   [progress]  302,000,000 reads scanned  | 1,960,400 telomeric  | 134,666 reads/sec  | elapsed 37m 22s
#   [progress]  303,000,000 reads scanned  | 1,967,639 telomeric  | 134,663 reads/sec  | elapsed 37m 30s
#   [progress]  304,000,000 reads scanned  | 1,973,856 telomeric  | 134,667 reads/sec  | elapsed 37m 37s
#   [progress]  305,000,000 reads scanned  | 1,980,288 telomeric  | 134,664 reads/sec  | elapsed 37m 44s
#   [progress]  306,000,000 reads scanned  | 1,987,799 telomeric  | 134,661 reads/sec  | elapsed 37m 52s
#   [progress]  307,000,000 reads scanned  | 1,993,615 telomeric  | 134,670 reads/sec  | elapsed 37m 59s
#   [progress]  308,000,000 reads scanned  | 1,998,974 telomeric  | 134,680 reads/sec  | elapsed 38m 06s
#   [progress]  309,000,000 reads scanned  | 2,004,667 telomeric  | 134,688 reads/sec  | elapsed 38m 14s
#   [progress]  310,000,000 reads scanned  | 2,012,033 telomeric  | 134,689 reads/sec  | elapsed 38m 21s
#   [progress]  311,000,000 reads scanned  | 2,018,379 telomeric  | 134,691 reads/sec  | elapsed 38m 28s
#   [progress]  312,000,000 reads scanned  | 2,024,995 telomeric  | 134,698 reads/sec  | elapsed 38m 36s
#   [progress]  313,000,000 reads scanned  | 2,031,613 telomeric  | 134,702 reads/sec  | elapsed 38m 43s
#   [progress]  314,000,000 reads scanned  | 2,037,735 telomeric  | 134,708 reads/sec  | elapsed 38m 50s
#   [progress]  315,000,000 reads scanned  | 2,044,380 telomeric  | 134,714 reads/sec  | elapsed 38m 58s
#   [progress]  316,000,000 reads scanned  | 2,051,503 telomeric  | 134,714 reads/sec  | elapsed 39m 05s
#   [progress]  317,000,000 reads scanned  | 2,057,863 telomeric  | 134,718 reads/sec  | elapsed 39m 13s
#   [progress]  318,000,000 reads scanned  | 2,065,133 telomeric  | 134,717 reads/sec  | elapsed 39m 20s
#   [progress]  319,000,000 reads scanned  | 2,073,011 telomeric  | 134,711 reads/sec  | elapsed 39m 28s
#   [progress]  320,000,000 reads scanned  | 2,078,775 telomeric  | 134,720 reads/sec  | elapsed 39m 35s
#   [progress]  321,000,000 reads scanned  | 2,085,003 telomeric  | 134,722 reads/sec  | elapsed 39m 42s
#   Elapsed: 00:39:50  [progress]  322,000,000 reads scanned  | 2,091,336 telomeric  | 134,728 reads/sec  | elapsed 39m 50s
#   [progress]  323,000,000 reads scanned  | 2,096,834 telomeric  | 134,739 reads/sec  | elapsed 39m 57s
#   [progress]  324,000,000 reads scanned  | 2,102,729 telomeric  | 134,747 reads/sec  | elapsed 40m 04s
#   [progress]  325,000,000 reads scanned  | 2,108,951 telomeric  | 134,748 reads/sec  | elapsed 40m 11s
#   [progress]  326,000,000 reads scanned  | 2,116,271 telomeric  | 134,745 reads/sec  | elapsed 40m 19s
#   [progress]  327,000,000 reads scanned  | 2,123,861 telomeric  | 134,742 reads/sec  | elapsed 40m 26s
#   [progress]  328,000,000 reads scanned  | 2,130,535 telomeric  | 134,740 reads/sec  | elapsed 40m 34s
#   [progress]  329,000,000 reads scanned  | 2,138,248 telomeric  | 134,736 reads/sec  | elapsed 40m 41s
#   [progress]  330,000,000 reads scanned  | 2,146,706 telomeric  | 134,729 reads/sec  | elapsed 40m 49s
#   [progress]  331,000,000 reads scanned  | 2,154,916 telomeric  | 134,724 reads/sec  | elapsed 40m 56s
#   [progress]  332,000,000 reads scanned  | 2,161,077 telomeric  | 134,730 reads/sec  | elapsed 41m 04s
#   [progress]  333,000,000 reads scanned  | 2,166,548 telomeric  | 134,742 reads/sec  | elapsed 41m 11s
#   [progress]  334,000,000 reads scanned  | 2,169,664 telomeric  | 134,767 reads/sec  | elapsed 41m 18s
#   [progress]  335,000,000 reads scanned  | 2,173,266 telomeric  | 134,782 reads/sec  | elapsed 41m 25s
#   [progress]  336,000,000 reads scanned  | 2,179,387 telomeric  | 134,779 reads/sec  | elapsed 41m 32s
#   [progress]  337,000,000 reads scanned  | 2,186,464 telomeric  | 134,778 reads/sec  | elapsed 41m 40s
#   [progress]  338,000,000 reads scanned  | 2,191,520 telomeric  | 134,780 reads/sec  | elapsed 41m 47s
#   [progress]  339,000,000 reads scanned  | 2,197,745 telomeric  | 134,785 reads/sec  | elapsed 41m 55s
#   [progress]  340,000,000 reads scanned  | 2,202,319 telomeric  | 134,800 reads/sec  | elapsed 42m 02s
#   [progress]  341,000,000 reads scanned  | 2,208,285 telomeric  | 134,807 reads/sec  | elapsed 42m 09s
#   [progress]  342,000,000 reads scanned  | 2,214,806 telomeric  | 134,807 reads/sec  | elapsed 42m 16s
#   [progress]  343,000,000 reads scanned  | 2,221,544 telomeric  | 134,808 reads/sec  | elapsed 42m 24s
#   [progress]  344,000,000 reads scanned  | 2,227,889 telomeric  | 134,808 reads/sec  | elapsed 42m 31s
#   [progress]  345,000,000 reads scanned  | 2,233,039 telomeric  | 134,814 reads/sec  | elapsed 42m 39s
#   [progress]  346,000,000 reads scanned  | 2,239,998 telomeric  | 134,807 reads/sec  | elapsed 42m 46s
#   [progress]  347,000,000 reads scanned  | 2,246,554 telomeric  | 134,807 reads/sec  | elapsed 42m 54s
#   [progress]  348,000,000 reads scanned  | 2,252,299 telomeric  | 134,816 reads/sec  | elapsed 43m 01s
#   [progress]  349,000,000 reads scanned  | 2,258,302 telomeric  | 134,823 reads/sec  | elapsed 43m 08s
#   [progress]  350,000,000 reads scanned  | 2,264,208 telomeric  | 134,829 reads/sec  | elapsed 43m 15s
#   [progress]  351,000,000 reads scanned  | 2,269,805 telomeric  | 134,838 reads/sec  | elapsed 43m 23s
#   [progress]  352,000,000 reads scanned  | 2,276,328 telomeric  | 134,837 reads/sec  | elapsed 43m 30s
#   [progress]  353,000,000 reads scanned  | 2,283,123 telomeric  | 134,836 reads/sec  | elapsed 43m 37s
#   [progress]  354,000,000 reads scanned  | 2,290,368 telomeric  | 134,832 reads/sec  | elapsed 43m 45s
#   [progress]  355,000,000 reads scanned  | 2,298,332 telomeric  | 134,824 reads/sec  | elapsed 43m 53s
#   [progress]  356,000,000 reads scanned  | 2,303,807 telomeric  | 134,831 reads/sec  | elapsed 44m 00s
#   [progress]  357,000,000 reads scanned  | 2,311,362 telomeric  | 134,827 reads/sec  | elapsed 44m 07s
#   [progress]  358,000,000 reads scanned  | 2,318,892 telomeric  | 134,824 reads/sec  | elapsed 44m 15s
#   [progress]  359,000,000 reads scanned  | 2,326,764 telomeric  | 134,818 reads/sec  | elapsed 44m 22s
#   [progress]  360,000,000 reads scanned  | 2,333,177 telomeric  | 134,814 reads/sec  | elapsed 44m 30s
#   [progress]  361,000,000 reads scanned  | 2,339,914 telomeric  | 134,809 reads/sec  | elapsed 44m 37s
#   [progress]  362,000,000 reads scanned  | 2,347,922 telomeric  | 134,802 reads/sec  | elapsed 44m 45s
#   [progress]  363,000,000 reads scanned  | 2,353,842 telomeric  | 134,806 reads/sec  | elapsed 44m 52s
#   [progress]  364,000,000 reads scanned  | 2,361,101 telomeric  | 134,804 reads/sec  | elapsed 45m 00s
#   [progress]  365,000,000 reads scanned  | 2,369,017 telomeric  | 134,800 reads/sec  | elapsed 45m 07s
#   [progress]  366,000,000 reads scanned  | 2,376,002 telomeric  | 134,795 reads/sec  | elapsed 45m 15s
#   [progress]  367,000,000 reads scanned  | 2,382,348 telomeric  | 134,796 reads/sec  | elapsed 45m 22s
#   [progress]  368,000,000 reads scanned  | 2,388,822 telomeric  | 134,797 reads/sec  | elapsed 45m 30s
#   [progress]  369,000,000 reads scanned  | 2,395,265 telomeric  | 134,797 reads/sec  | elapsed 45m 37s
#   [progress]  370,000,000 reads scanned  | 2,399,773 telomeric  | 134,808 reads/sec  | elapsed 45m 44s
#   [progress]  371,000,000 reads scanned  | 2,402,738 telomeric  | 134,826 reads/sec  | elapsed 45m 51s
#   [progress]  372,000,000 reads scanned  | 2,408,822 telomeric  | 134,831 reads/sec  | elapsed 45m 59s
#   [progress]  373,000,000 reads scanned  | 2,415,443 telomeric  | 134,832 reads/sec  | elapsed 46m 06s
#   [progress]  374,000,000 reads scanned  | 2,421,733 telomeric  | 134,836 reads/sec  | elapsed 46m 13s
#   [progress]  375,000,000 reads scanned  | 2,428,553 telomeric  | 134,837 reads/sec  | elapsed 46m 21s
#   [progress]  376,000,000 reads scanned  | 2,435,243 telomeric  | 134,838 reads/sec  | elapsed 46m 28s
#   [progress]  377,000,000 reads scanned  | 2,440,945 telomeric  | 134,842 reads/sec  | elapsed 46m 35s
#   [progress]  378,000,000 reads scanned  | 2,447,180 telomeric  | 134,845 reads/sec  | elapsed 46m 43s
#   [progress]  379,000,000 reads scanned  | 2,453,042 telomeric  | 134,853 reads/sec  | elapsed 46m 50s
#   [progress]  380,000,000 reads scanned  | 2,459,015 telomeric  | 134,859 reads/sec  | elapsed 46m 57s
#   [progress]  381,000,000 reads scanned  | 2,464,131 telomeric  | 134,880 reads/sec  | elapsed 47m 04s
#   [progress]  382,000,000 reads scanned  | 2,470,452 telomeric  | 134,884 reads/sec  | elapsed 47m 12s
#   [progress]  383,000,000 reads scanned  | 2,477,023 telomeric  | 134,884 reads/sec  | elapsed 47m 19s
#   [progress]  384,000,000 reads scanned  | 2,484,255 telomeric  | 134,881 reads/sec  | elapsed 47m 26s
#   [progress]  385,000,000 reads scanned  | 2,491,240 telomeric  | 134,876 reads/sec  | elapsed 47m 34s
#   [progress]  386,000,000 reads scanned  | 2,498,199 telomeric  | 134,869 reads/sec  | elapsed 47m 42s
#   [progress]  387,000,000 reads scanned  | 2,504,719 telomeric  | 134,871 reads/sec  | elapsed 47m 49s
#   [progress]  388,000,000 reads scanned  | 2,510,058 telomeric  | 134,882 reads/sec  | elapsed 47m 56s
#   [progress]  389,000,000 reads scanned  | 2,515,992 telomeric  | 134,887 reads/sec  | elapsed 48m 03s
#   [progress]  390,000,000 reads scanned  | 2,523,332 telomeric  | 134,884 reads/sec  | elapsed 48m 11s
#   [progress]  391,000,000 reads scanned  | 2,531,262 telomeric  | 134,879 reads/sec  | elapsed 48m 18s
#   [progress]  392,000,000 reads scanned  | 2,538,864 telomeric  | 134,873 reads/sec  | elapsed 48m 26s
#   [progress]  393,000,000 reads scanned  | 2,547,304 telomeric  | 134,865 reads/sec  | elapsed 48m 34s
#   [progress]  394,000,000 reads scanned  | 2,554,256 telomeric  | 134,866 reads/sec  | elapsed 48m 41s
#   [progress]  395,000,000 reads scanned  | 2,561,529 telomeric  | 134,865 reads/sec  | elapsed 48m 48s
#   [progress]  396,000,000 reads scanned  | 2,569,840 telomeric  | 134,862 reads/sec  | elapsed 48m 56s
#   [progress]  397,000,000 reads scanned  | 2,576,544 telomeric  | 134,859 reads/sec  | elapsed 49m 03s
#   [progress]  398,000,000 reads scanned  | 2,583,617 telomeric  | 134,857 reads/sec  | elapsed 49m 11s
#   [progress]  399,000,000 reads scanned  | 2,588,712 telomeric  | 134,866 reads/sec  | elapsed 49m 18s
#   [progress]  400,000,000 reads scanned  | 2,595,773 telomeric  | 134,866 reads/sec  | elapsed 49m 25s
#   [progress]  401,000,000 reads scanned  | 2,602,456 telomeric  | 134,865 reads/sec  | elapsed 49m 33s
#   [progress]  402,000,000 reads scanned  | 2,608,473 telomeric  | 134,870 reads/sec  | elapsed 49m 40s
#   [progress]  403,000,000 reads scanned  | 2,615,341 telomeric  | 134,870 reads/sec  | elapsed 49m 48s
#   [progress]  404,000,000 reads scanned  | 2,620,902 telomeric  | 134,877 reads/sec  | elapsed 49m 55s
#   [progress]  405,000,000 reads scanned  | 2,628,554 telomeric  | 134,869 reads/sec  | elapsed 50m 02s
#   [progress]  406,000,000 reads scanned  | 2,634,866 telomeric  | 134,867 reads/sec  | elapsed 50m 10s
#   [progress]  407,000,000 reads scanned  | 2,640,047 telomeric  | 134,872 reads/sec  | elapsed 50m 17s
#   [progress]  408,000,000 reads scanned  | 2,642,437 telomeric  | 134,900 reads/sec  | elapsed 50m 24s
#   [progress]  409,000,000 reads scanned  | 2,649,464 telomeric  | 134,889 reads/sec  | elapsed 50m 32s
#   [progress]  410,000,000 reads scanned  | 2,655,576 telomeric  | 134,886 reads/sec  | elapsed 50m 39s
#   [progress]  411,000,000 reads scanned  | 2,661,598 telomeric  | 134,891 reads/sec  | elapsed 50m 46s
#   [progress]  412,000,000 reads scanned  | 2,668,893 telomeric  | 134,887 reads/sec  | elapsed 50m 54s
#   [progress]  413,000,000 reads scanned  | 2,675,322 telomeric  | 134,888 reads/sec  | elapsed 51m 01s
#   [progress]  414,000,000 reads scanned  | 2,682,155 telomeric  | 134,887 reads/sec  | elapsed 51m 09s
#   [progress]  415,000,000 reads scanned  | 2,688,795 telomeric  | 134,885 reads/sec  | elapsed 51m 16s
#   [progress]  416,000,000 reads scanned  | 2,694,728 telomeric  | 134,889 reads/sec  | elapsed 51m 24s
#   [progress]  417,000,000 reads scanned  | 2,701,772 telomeric  | 134,888 reads/sec  | elapsed 51m 31s
#   [progress]  418,000,000 reads scanned  | 2,708,310 telomeric  | 134,885 reads/sec  | elapsed 51m 38s
#   [progress]  419,000,000 reads scanned  | 2,714,513 telomeric  | 134,884 reads/sec  | elapsed 51m 46s
#   [progress]  420,000,000 reads scanned  | 2,722,199 telomeric  | 134,878 reads/sec  | elapsed 51m 53s
#   [progress]  421,000,000 reads scanned  | 2,729,370 telomeric  | 134,875 reads/sec  | elapsed 52m 01s
#   [progress]  422,000,000 reads scanned  | 2,736,279 telomeric  | 134,876 reads/sec  | elapsed 52m 08s
#   [progress]  423,000,000 reads scanned  | 2,743,561 telomeric  | 134,872 reads/sec  | elapsed 52m 16s
#   [progress]  424,000,000 reads scanned  | 2,750,453 telomeric  | 134,873 reads/sec  | elapsed 52m 23s
#   [progress]  425,000,000 reads scanned  | 2,756,351 telomeric  | 134,877 reads/sec  | elapsed 52m 31s
#   [progress]  426,000,000 reads scanned  | 2,762,722 telomeric  | 134,882 reads/sec  | elapsed 52m 38s
#   [progress]  427,000,000 reads scanned  | 2,770,663 telomeric  | 134,879 reads/sec  | elapsed 52m 45s
#   [progress]  428,000,000 reads scanned  | 2,777,909 telomeric  | 134,880 reads/sec  | elapsed 52m 53s
#   [progress]  429,000,000 reads scanned  | 2,784,577 telomeric  | 134,879 reads/sec  | elapsed 53m 00s
#   [progress]  430,000,000 reads scanned  | 2,790,809 telomeric  | 134,880 reads/sec  | elapsed 53m 08s
#   [progress]  431,000,000 reads scanned  | 2,798,542 telomeric  | 134,874 reads/sec  | elapsed 53m 15s
#   [progress]  432,000,000 reads scanned  | 2,804,894 telomeric  | 134,870 reads/sec  | elapsed 53m 23s
#   [progress]  433,000,000 reads scanned  | 2,811,923 telomeric  | 134,868 reads/sec  | elapsed 53m 30s
#   [progress]  434,000,000 reads scanned  | 2,817,835 telomeric  | 134,871 reads/sec  | elapsed 53m 37s
#   [progress]  435,000,000 reads scanned  | 2,824,906 telomeric  | 134,866 reads/sec  | elapsed 53m 45s
#   [progress]  436,000,000 reads scanned  | 2,830,753 telomeric  | 134,871 reads/sec  | elapsed 53m 52s
#   [progress]  437,000,000 reads scanned  | 2,834,222 telomeric  | 134,872 reads/sec  | elapsed 54m 00s
#   [progress]  438,000,000 reads scanned  | 2,835,199 telomeric  | 134,891 reads/sec  | elapsed 54m 07s
#   [progress]  439,000,000 reads scanned  | 2,838,564 telomeric  | 134,856 reads/sec  | elapsed 54m 15s
#   [progress]  440,000,000 reads scanned  | 2,846,315 telomeric  | 134,853 reads/sec  | elapsed 54m 22s
#   [progress]  441,000,000 reads scanned  | 2,853,515 telomeric  | 134,851 reads/sec  | elapsed 54m 30s
#   [progress]  442,000,000 reads scanned  | 2,860,128 telomeric  | 134,853 reads/sec  | elapsed 54m 37s
#   [progress]  443,000,000 reads scanned  | 2,866,307 telomeric  | 134,858 reads/sec  | elapsed 54m 44s
#   [progress]  444,000,000 reads scanned  | 2,873,830 telomeric  | 134,856 reads/sec  | elapsed 54m 52s
#   [progress]  445,000,000 reads scanned  | 2,880,324 telomeric  | 134,855 reads/sec  | elapsed 54m 59s
#   [progress]  446,000,000 reads scanned  | 2,886,360 telomeric  | 134,858 reads/sec  | elapsed 55m 07s
#   [progress]  447,000,000 reads scanned  | 2,893,198 telomeric  | 134,857 reads/sec  | elapsed 55m 14s
#   [progress]  448,000,000 reads scanned  | 2,900,087 telomeric  | 134,855 reads/sec  | elapsed 55m 22s
#   [progress]  449,000,000 reads scanned  | 2,907,667 telomeric  | 134,854 reads/sec  | elapsed 55m 29s
#   [progress]  450,000,000 reads scanned  | 2,914,642 telomeric  | 134,854 reads/sec  | elapsed 55m 36s
#   [progress]  451,000,000 reads scanned  | 2,921,383 telomeric  | 134,854 reads/sec  | elapsed 55m 44s
#   [progress]  452,000,000 reads scanned  | 2,929,048 telomeric  | 134,846 reads/sec  | elapsed 55m 51s
#   [progress]  453,000,000 reads scanned  | 2,936,612 telomeric  | 134,842 reads/sec  | elapsed 55m 59s
#   [progress]  454,000,000 reads scanned  | 2,943,831 telomeric  | 134,837 reads/sec  | elapsed 56m 07s
#   [progress]  455,000,000 reads scanned  | 2,950,336 telomeric  | 134,835 reads/sec  | elapsed 56m 14s
#   [progress]  456,000,000 reads scanned  | 2,956,859 telomeric  | 134,837 reads/sec  | elapsed 56m 21s
#   [progress]  457,000,000 reads scanned  | 2,964,329 telomeric  | 134,834 reads/sec  | elapsed 56m 29s
#   [progress]  458,000,000 reads scanned  | 2,971,109 telomeric  | 134,835 reads/sec  | elapsed 56m 36s
#   [progress]  459,000,000 reads scanned  | 2,978,377 telomeric  | 134,834 reads/sec  | elapsed 56m 44s
#   [progress]  460,000,000 reads scanned  | 2,985,864 telomeric  | 134,832 reads/sec  | elapsed 56m 51s
#   [progress]  461,000,000 reads scanned  | 2,993,124 telomeric  | 134,834 reads/sec  | elapsed 56m 59s
#   [progress]  462,000,000 reads scanned  | 3,000,170 telomeric  | 134,829 reads/sec  | elapsed 57m 06s
#   [progress]  463,000,000 reads scanned  | 3,008,234 telomeric  | 134,817 reads/sec  | elapsed 57m 14s
#   [progress]  464,000,000 reads scanned  | 3,014,449 telomeric  | 134,817 reads/sec  | elapsed 57m 21s
# ...
#   [progress]  628,000,000 reads scanned  | 4,062,239 telomeric  | 135,066 reads/sec  | elapsed 77m 29s
#   [progress]  629,000,000 reads scanned  | 4,067,054 telomeric  | 135,053 reads/sec  | elapsed 77m 37s
#   [progress]  630,000,000 reads scanned  | 4,067,894 telomeric  | 135,069 reads/sec  | elapsed 77m 44s
#   [progress]  631,000,000 reads scanned  | 4,075,362 telomeric  | 135,067 reads/sec  | elapsed 77m 51s
#   [progress]  632,000,000 reads scanned  | 4,082,627 telomeric  | 135,061 reads/sec  | elapsed 77m 59s
#   [progress]  633,000,000 reads scanned  | 4,088,366 telomeric  | 135,055 reads/sec  | elapsed 78m 06s
#   [progress]  634,000,000 reads scanned  | 4,097,369 telomeric  | 135,050 reads/sec  | elapsed 78m 14s
#   [progress]  635,000,000 reads scanned  | 4,104,575 telomeric  | 135,043 reads/sec  | elapsed 78m 22s
#   [progress]  636,000,000 reads scanned  | 4,111,832 telomeric  | 135,040 reads/sec  | elapsed 78m 29s
#   [progress]  637,000,000 reads scanned  | 4,118,625 telomeric  | 135,040 reads/sec  | elapsed 78m 37s
#   [progress]  638,000,000 reads scanned  | 4,125,705 telomeric  | 135,038 reads/sec  | elapsed 78m 44s
#   [progress]  639,000,000 reads scanned  | 4,131,252 telomeric  | 135,040 reads/sec  | elapsed 78m 51s
#   [progress]  640,000,000 reads scanned  | 4,137,924 telomeric  | 135,038 reads/sec  | elapsed 78m 59s
#   [progress]  641,000,000 reads scanned  | 4,143,255 telomeric  | 135,042 reads/sec  | elapsed 79m 06s
#   [progress]  642,000,000 reads scanned  | 4,151,152 telomeric  | 135,040 reads/sec  | elapsed 79m 14s
#   [progress]  643,000,000 reads scanned  | 4,158,504 telomeric  | 135,039 reads/sec  | elapsed 79m 21s
#   [progress]  644,000,000 reads scanned  | 4,165,650 telomeric  | 135,031 reads/sec  | elapsed 79m 29s
#   [progress]  645,000,000 reads scanned  | 4,171,621 telomeric  | 135,026 reads/sec  | elapsed 79m 36s
#   [progress]  646,000,000 reads scanned  | 4,177,562 telomeric  | 135,028 reads/sec  | elapsed 79m 44s
#   [progress]  647,000,000 reads scanned  | 4,183,937 telomeric  | 135,029 reads/sec  | elapsed 79m 51s
#   [progress]  648,000,000 reads scanned  | 4,189,833 telomeric  | 135,029 reads/sec  | elapsed 79m 58s
#   [progress]  649,000,000 reads scanned  | 4,189,999 telomeric  | 135,065 reads/sec  | elapsed 80m 05s
#   [progress]  650,000,000 reads scanned  | 4,193,133 telomeric  | 135,080 reads/sec  | elapsed 80m 11s
#   [progress]  651,000,000 reads scanned  | 4,200,637 telomeric  | 135,078 reads/sec  | elapsed 80m 19s
#   [progress]  652,000,000 reads scanned  | 4,206,704 telomeric  | 135,082 reads/sec  | elapsed 80m 26s
#   [progress]  653,000,000 reads scanned  | 4,213,324 telomeric  | 135,082 reads/sec  | elapsed 80m 34s
#   [progress]  654,000,000 reads scanned  | 4,219,491 telomeric  | 135,084 reads/sec  | elapsed 80m 41s
#   [progress]  655,000,000 reads scanned  | 4,225,808 telomeric  | 135,085 reads/sec  | elapsed 80m 48s
#   [progress]  656,000,000 reads scanned  | 4,232,827 telomeric  | 135,080 reads/sec  | elapsed 80m 56s
#   [progress]  657,000,000 reads scanned  | 4,240,204 telomeric  | 135,077 reads/sec  | elapsed 81m 03s
#   [progress]  658,000,000 reads scanned  | 4,246,655 telomeric  | 135,078 reads/sec  | elapsed 81m 11s
#   [progress]  659,000,000 reads scanned  | 4,253,780 telomeric  | 135,077 reads/sec  | elapsed 81m 18s
#   [progress]  660,000,000 reads scanned  | 4,261,103 telomeric  | 135,075 reads/sec  | elapsed 81m 26s
#   [progress]  661,000,000 reads scanned  | 4,267,041 telomeric  | 135,079 reads/sec  | elapsed 81m 33s
#   [progress]  662,000,000 reads scanned  | 4,273,182 telomeric  | 135,082 reads/sec  | elapsed 81m 40s
#   [progress]  663,000,000 reads scanned  | 4,279,380 telomeric  | 135,085 reads/sec  | elapsed 81m 48s
#   [progress]  664,000,000 reads scanned  | 4,285,487 telomeric  | 135,087 reads/sec  | elapsed 81m 55s
#   [progress]  665,000,000 reads scanned  | 4,293,985 telomeric  | 135,083 reads/sec  | elapsed 82m 02s
#   [progress]  666,000,000 reads scanned  | 4,299,815 telomeric  | 135,085 reads/sec  | elapsed 82m 10s
#   [progress]  667,000,000 reads scanned  | 4,306,508 telomeric  | 135,083 reads/sec  | elapsed 82m 17s
#   [progress]  668,000,000 reads scanned  | 4,313,694 telomeric  | 135,081 reads/sec  | elapsed 82m 25s
#   [progress]  669,000,000 reads scanned  | 4,319,906 telomeric  | 135,082 reads/sec  | elapsed 82m 32s
#   [progress]  670,000,000 reads scanned  | 4,329,946 telomeric  | 135,071 reads/sec  | elapsed 82m 40s
#   [progress]  671,000,000 reads scanned  | 4,336,558 telomeric  | 135,072 reads/sec  | elapsed 82m 47s
#   [progress]  672,000,000 reads scanned  | 4,342,827 telomeric  | 135,074 reads/sec  | elapsed 82m 55s
#   [progress]  673,000,000 reads scanned  | 4,348,716 telomeric  | 135,080 reads/sec  | elapsed 83m 02s
#   [progress]  674,000,000 reads scanned  | 4,356,237 telomeric  | 135,077 reads/sec  | elapsed 83m 09s
#   [progress]  675,000,000 reads scanned  | 4,362,442 telomeric  | 135,077 reads/sec  | elapsed 83m 17s
#   [progress]  676,000,000 reads scanned  | 4,369,124 telomeric  | 135,076 reads/sec  | elapsed 83m 24s
#   [progress]  677,000,000 reads scanned  | 4,376,370 telomeric  | 135,074 reads/sec  | elapsed 83m 32s
#   [progress]  678,000,000 reads scanned  | 4,383,070 telomeric  | 135,066 reads/sec  | elapsed 83m 39s
#   [progress]  679,000,000 reads scanned  | 4,391,114 telomeric  | 135,060 reads/sec  | elapsed 83m 47s
#   [progress]  680,000,000 reads scanned  | 4,397,846 telomeric  | 135,060 reads/sec  | elapsed 83m 54s
#   [progress]  681,000,000 reads scanned  | 4,404,668 telomeric  | 135,059 reads/sec  | elapsed 84m 02s
#   [progress]  682,000,000 reads scanned  | 4,411,078 telomeric  | 135,061 reads/sec  | elapsed 84m 09s
#   [progress]  683,000,000 reads scanned  | 4,418,215 telomeric  | 135,059 reads/sec  | elapsed 84m 17s
#   [progress]  684,000,000 reads scanned  | 4,424,457 telomeric  | 135,060 reads/sec  | elapsed 84m 24s
#   [progress]  685,000,000 reads scanned  | 4,429,700 telomeric  | 135,067 reads/sec  | elapsed 84m 31s
#   [progress]  686,000,000 reads scanned  | 4,430,753 telomeric  | 135,087 reads/sec  | elapsed 84m 38s
#   [progress]  687,000,000 reads scanned  | 4,434,918 telomeric  | 135,061 reads/sec  | elapsed 84m 46s
#   [progress]  688,000,000 reads scanned  | 4,441,417 telomeric  | 135,049 reads/sec  | elapsed 84m 54s
#   [progress]  689,000,000 reads scanned  | 4,448,401 telomeric  | 135,047 reads/sec  | elapsed 85m 01s
#   [progress]  690,000,000 reads scanned  | 4,457,212 telomeric  | 135,042 reads/sec  | elapsed 85m 09s
#   [progress]  691,000,000 reads scanned  | 4,465,015 telomeric  | 135,037 reads/sec  | elapsed 85m 17s
#   [progress]  692,000,000 reads scanned  | 4,471,347 telomeric  | 135,036 reads/sec  | elapsed 85m 24s
#   [progress]  693,000,000 reads scanned  | 4,477,169 telomeric  | 135,037 reads/sec  | elapsed 85m 31s
#   [progress]  694,000,000 reads scanned  | 4,484,261 telomeric  | 135,037 reads/sec  | elapsed 85m 39s
#   [progress]  695,000,000 reads scanned  | 4,490,061 telomeric  | 135,039 reads/sec  | elapsed 85m 46s
#   [progress]  696,000,000 reads scanned  | 4,494,747 telomeric  | 135,036 reads/sec  | elapsed 85m 54s
#   [progress]  697,000,000 reads scanned  | 4,498,075 telomeric  | 135,078 reads/sec  | elapsed 85m 59s
#   [progress]  698,000,000 reads scanned  | 4,504,196 telomeric  | 135,108 reads/sec  | elapsed 86m 06s
#   [progress]  699,000,000 reads scanned  | 4,508,259 telomeric  | 135,102 reads/sec  | elapsed 86m 13s
#   [progress]  700,000,000 reads scanned  | 4,513,922 telomeric  | 135,102 reads/sec  | elapsed 86m 21s
#   [progress]  701,000,000 reads scanned  | 4,519,788 telomeric  | 135,104 reads/sec  | elapsed 86m 28s
#   [progress]  702,000,000 reads scanned  | 4,525,383 telomeric  | 135,109 reads/sec  | elapsed 86m 35s
#   [progress]  703,000,000 reads scanned  | 4,531,500 telomeric  | 135,112 reads/sec  | elapsed 86m 43s
#   [progress]  704,000,000 reads scanned  | 4,538,181 telomeric  | 135,112 reads/sec  | elapsed 86m 50s
#   [progress]  705,000,000 reads scanned  | 4,545,583 telomeric  | 135,109 reads/sec  | elapsed 86m 58s
#   [progress]  706,000,000 reads scanned  | 4,553,543 telomeric  | 135,104 reads/sec  | elapsed 87m 05s
#   [progress]  707,000,000 reads scanned  | 4,560,994 telomeric  | 135,103 reads/sec  | elapsed 87m 13s
#   [progress]  708,000,000 reads scanned  | 4,567,688 telomeric  | 135,102 reads/sec  | elapsed 87m 20s
#   [progress]  709,000,000 reads scanned  | 4,573,015 telomeric  | 135,095 reads/sec  | elapsed 87m 28s
#   Elapsed: 01:27:35  [progress]  710,000,000 reads scanned  | 4,579,910 telomeric  | 135,094 reads/sec  | elapsed 87m 35s
#   [progress]  711,000,000 reads scanned  | 4,586,884 telomeric  | 135,091 reads/sec  | elapsed 87m 43s
#   [progress]  712,000,000 reads scanned  | 4,594,234 telomeric  | 135,088 reads/sec  | elapsed 87m 50s
#   [progress]  713,000,000 reads scanned  | 4,601,594 telomeric  | 135,086 reads/sec  | elapsed 87m 58s
#   [progress]  714,000,000 reads scanned  | 4,610,312 telomeric  | 135,081 reads/sec  | elapsed 88m 05s
#   [progress]  715,000,000 reads scanned  | 4,615,987 telomeric  | 135,082 reads/sec  | elapsed 88m 13s
#   [progress]  716,000,000 reads scanned  | 4,622,022 telomeric  | 135,084 reads/sec  | elapsed 88m 20s
#   [progress]  717,000,000 reads scanned  | 4,628,598 telomeric  | 135,087 reads/sec  | elapsed 88m 27s
#   [progress]  718,000,000 reads scanned  | 4,638,631 telomeric  | 135,074 reads/sec  | elapsed 88m 35s
#   [progress]  719,000,000 reads scanned  | 4,645,567 telomeric  | 135,074 reads/sec  | elapsed 88m 43s
#   [progress]  720,000,000 reads scanned  | 4,652,962 telomeric  | 135,072 reads/sec  | elapsed 88m 50s
#   [progress]  721,000,000 reads scanned  | 4,660,239 telomeric  | 135,068 reads/sec  | elapsed 88m 58s
#   [progress]  722,000,000 reads scanned  | 4,666,938 telomeric  | 135,067 reads/sec  | elapsed 89m 05s
#   [progress]  723,000,000 reads scanned  | 4,673,741 telomeric  | 135,067 reads/sec  | elapsed 89m 12s
#   [progress]  724,000,000 reads scanned  | 4,680,278 telomeric  | 135,069 reads/sec  | elapsed 89m 20s
#   [progress]  725,000,000 reads scanned  | 4,686,407 telomeric  | 135,070 reads/sec  | elapsed 89m 27s
#   [progress]  726,000,000 reads scanned  | 4,692,211 telomeric  | 135,073 reads/sec  | elapsed 89m 34s
#   [progress]  727,000,000 reads scanned  | 4,698,718 telomeric  | 135,074 reads/sec  | elapsed 89m 42s
#   [progress]  728,000,000 reads scanned  | 4,705,958 telomeric  | 135,072 reads/sec  | elapsed 89m 49s
#   [progress]  729,000,000 reads scanned  | 4,712,952 telomeric  | 135,071 reads/sec  | elapsed 89m 57s
#   [progress]  730,000,000 reads scanned  | 4,720,968 telomeric  | 135,067 reads/sec  | elapsed 90m 04s
#   [progress]  731,000,000 reads scanned  | 4,727,018 telomeric  | 135,066 reads/sec  | elapsed 90m 12s
#   [progress]  732,000,000 reads scanned  | 4,730,237 telomeric  | 135,073 reads/sec  | elapsed 90m 19s
#   [progress]  733,000,000 reads scanned  | 4,733,945 telomeric  | 135,076 reads/sec  | elapsed 90m 26s
#   [progress]  734,000,000 reads scanned  | 4,741,269 telomeric  | 135,073 reads/sec  | elapsed 90m 34s
#   [progress]  735,000,000 reads scanned  | 4,748,352 telomeric  | 135,070 reads/sec  | elapsed 90m 41s
#   [progress]  736,000,000 reads scanned  | 4,755,103 telomeric  | 135,067 reads/sec  | elapsed 90m 49s
#   [progress]  737,000,000 reads scanned  | 4,761,680 telomeric  | 135,066 reads/sec  | elapsed 90m 56s
#   [progress]  738,000,000 reads scanned  | 4,766,805 telomeric  | 135,070 reads/sec  | elapsed 91m 03s
#   [progress]  739,000,000 reads scanned  | 4,772,019 telomeric  | 135,073 reads/sec  | elapsed 91m 11s
#   [progress]  740,000,000 reads scanned  | 4,777,097 telomeric  | 135,076 reads/sec  | elapsed 91m 18s
#   [progress]  741,000,000 reads scanned  | 4,783,947 telomeric  | 135,076 reads/sec  | elapsed 91m 25s
#   [progress]  742,000,000 reads scanned  | 4,790,009 telomeric  | 135,077 reads/sec  | elapsed 91m 33s
#   Elapsed: 01:31:40  [progress]  743,000,000 reads scanned  | 4,797,262 telomeric  | 135,073 reads/sec  | elapsed 91m 40s
#   [progress]  744,000,000 reads scanned  | 4,803,615 telomeric  | 135,074 reads/sec  | elapsed 91m 48s
#   [progress]  745,000,000 reads scanned  | 4,810,320 telomeric  | 135,072 reads/sec  | elapsed 91m 55s
#   [progress]  746,000,000 reads scanned  | 4,818,999 telomeric  | 135,070 reads/sec  | elapsed 92m 03s
#   [progress]  747,000,000 reads scanned  | 4,826,689 telomeric  | 135,068 reads/sec  | elapsed 92m 10s
#   [progress]  748,000,000 reads scanned  | 4,832,776 telomeric  | 135,069 reads/sec  | elapsed 92m 17s
#   [progress]  749,000,000 reads scanned  | 4,838,352 telomeric  | 135,072 reads/sec  | elapsed 92m 25s
#   [progress]  750,000,000 reads scanned  | 4,846,382 telomeric  | 135,067 reads/sec  | elapsed 92m 32s
#   [progress]  751,000,000 reads scanned  | 4,853,405 telomeric  | 135,066 reads/sec  | elapsed 92m 40s
#   [progress]  752,000,000 reads scanned  | 4,860,229 telomeric  | 135,064 reads/sec  | elapsed 92m 47s
#   [progress]  753,000,000 reads scanned  | 4,866,651 telomeric  | 135,065 reads/sec  | elapsed 92m 55s
#   [progress]  754,000,000 reads scanned  | 4,872,757 telomeric  | 135,067 reads/sec  | elapsed 93m 02s
#   [progress]  755,000,000 reads scanned  | 4,880,287 telomeric  | 135,065 reads/sec  | elapsed 93m 09s
#   [progress]  756,000,000 reads scanned  | 4,891,725 telomeric  | 135,040 reads/sec  | elapsed 93m 18s
#   [progress]  757,000,000 reads scanned  | 4,894,567 telomeric  | 134,987 reads/sec  | elapsed 93m 27s
#   [progress]  758,000,000 reads scanned  | 4,904,076 telomeric  | 134,982 reads/sec  | elapsed 93m 35s
#   [progress]  759,000,000 reads scanned  | 4,908,445 telomeric  | 134,972 reads/sec  | elapsed 93m 43s
#   [progress]  760,000,000 reads scanned  | 4,913,531 telomeric  | 134,947 reads/sec  | elapsed 93m 51s
#   [progress]  761,000,000 reads scanned  | 4,918,781 telomeric  | 134,923 reads/sec  | elapsed 94m 00s
#   [progress]  762,000,000 reads scanned  | 4,920,345 telomeric  | 134,944 reads/sec  | elapsed 94m 06s
#   [progress]  763,000,000 reads scanned  | 4,922,368 telomeric  | 134,924 reads/sec  | elapsed 94m 15s
#   [progress]  764,000,000 reads scanned  | 4,922,610 telomeric  | 134,948 reads/sec  | elapsed 94m 21s
#   [progress]  765,000,000 reads scanned  | 4,924,323 telomeric  | 134,963 reads/sec  | elapsed 94m 28s
#   [progress]  766,000,000 reads scanned  | 4,929,188 telomeric  | 134,991 reads/sec  | elapsed 94m 34s
#   [progress]  767,000,000 reads scanned  | 4,933,643 telomeric  | 134,999 reads/sec  | elapsed 94m 41s
#   [progress]  768,000,000 reads scanned  | 4,941,636 telomeric  | 134,971 reads/sec  | elapsed 94m 50s
#   [progress]  769,000,000 reads scanned  | 4,947,527 telomeric  | 134,945 reads/sec  | elapsed 94m 58s
#   [progress]  770,000,000 reads scanned  | 4,951,768 telomeric  | 134,911 reads/sec  | elapsed 95m 07s
#   [progress]  771,000,000 reads scanned  | 4,956,135 telomeric  | 134,864 reads/sec  | elapsed 95m 16s
#   [progress]  772,000,000 reads scanned  | 4,959,761 telomeric  | 134,821 reads/sec  | elapsed 95m 26s
#   [progress]  773,000,000 reads scanned  | 4,963,982 telomeric  | 134,773 reads/sec  | elapsed 95m 35s
#   [progress]  774,000,000 reads scanned  | 4,968,418 telomeric  | 134,754 reads/sec  | elapsed 95m 43s
#   [progress]  775,000,000 reads scanned  | 4,972,220 telomeric  | 134,744 reads/sec  | elapsed 95m 51s
#   Elapsed: 01:35:58
# Sample  : 1000052_23372_0_0  (CRAM(single-file): 1000052_23372_0_0.cram)
#   Age              :
#   Telomere Length  :
#   Total Reads      : 775,937,648
#   Telomeric Reads  : 4,973,247
#   Telomeric Frac   : 0.006409
#   3x_repeat c-strand: 364554
#   3x_repeat g-strand: 239232
#   G-strand mutations: 60767
#   C-strand mutations: 62760
#   G-strand normalizer: 299999
#   C-strand normalizer: 427314
#   Total mutations  : 123527
#
# Summary written to: /opt/notebooks/output.txt
#   Elapsed: 01:35:59  (done)
#
# Total runtime: 01:35:59
# CSV written to    : /opt/notebooks/telomere_analysis_ukb.csv
# Summary written to: /opt/notebooks/output.txt

# %%
# !dx upload output.txt --path Telomere/
# Out:
# [===========================================================>] Uploaded 4,710 of 4,710 bytes (100%) output.txt
# ID                                file-J7VFYvQJ7pf5b5fBpy6VfqZb
# Class                             file
# Project                           project-J0J4VJ8J7pf8gJKjjZgYjkzJ
# Folder                            /Telomere
# Name                              output.txt
# State                             closing
# Visibility                        visible
# Types                             -
# Properties                        -
# Tags                              -
# Outgoing links                    -
# Created                           Fri Apr 17 22:53:38 2026
# Created by                        jianingy
#  via the job                      job-J7V808jJ7pfB7V95Pb7xYx6f
# Last modified                     Fri Apr 17 22:53:39 2026
# Media type
# archivalState                     "live"
# cloudAccount                      "cloudaccount-dnanexus"

# %% [markdown]
# ## Plotting (from plotting.py)
#
# Run all plotting pipelines. Uses `csv_path` from the generate step above. If you already have a CSV, set `csv_path` manually and run the plot cells.

# %%
# Derive version label from REPEAT_K (no JSON patterns file needed for plotting)
PATTERNS_VERSION = f"{REPEAT_K}x_repeat"

def _get_patterns_version(patterns_file_path=None):
    """Return the patterns version string.  Falls back to PATTERNS_VERSION (from REPEAT_K)."""
    if patterns_file_path and os.path.exists(patterns_file_path):
        try:
            with open(patterns_file_path) as f:
                return json.load(f).get('version', PATTERNS_VERSION)
        except Exception:
            pass
    return PATTERNS_VERSION

def _default_csv_path_from_patterns(patterns_file_path=None):
    """Return the default CSV output path, preferring the already-configured CSV_OUT."""
    try:
        return CSV_OUT
    except NameError:
        safe = PATTERNS_VERSION.replace(' ', '_')
        return os.path.join(_ANALYSIS_DIR, f'telomere_analysis_{safe}.csv')

# Ensure csv_path is available (set by the generate step above, or fall back)
try:
    csv_path
except NameError:
    csv_path = _default_csv_path_from_patterns()

# %%
def _plot_histograms_by_age_group(data, output_path):
    """Plot boxplots of mutation rate variables in 10-year age bins (2x2 grid)."""
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    fig, axes = plt.subplots(2, 2, figsize=(20, 12))
    fig.suptitle('Mutation Rates by Age Groups (10-year bins)', fontsize=16, fontweight='bold')
    variables = ['total_mutations_over_total_g_strand_per_1k', 'g_strand_A>G_sum_per_1k', 'g_strand_T>G_sum_per_1k', 'g_strand_T>C_sum_per_1k']
    titles = ['Total Mutations Normalized', 'G > A Mutation Rate Normalized', 'T > G Mutation Rate Normalized', 'T > C Mutation Rate Normalized']
    for i, (var, title) in enumerate(zip(variables, titles)):
        row, col = i // 2, i % 2
        ax = axes[row, col]
        plot_data = data.dropna(subset=['Age', var])
        if len(plot_data) > 0:
            age_bins = np.arange(0, plot_data['Age'].max() + 10, 10)
            age_labels = [f'{int(b)}-{int(b+9)}' for b in age_bins[:-1]]
            plot_data = plot_data.copy()
            plot_data['Age_Group'] = pd.cut(plot_data['Age'], bins=age_bins, labels=age_labels, include_lowest=True)
            sns.boxplot(data=plot_data, x='Age_Group', y=var, ax=ax)
            ax.set_xlabel('Age Group (years)')
            ax.set_ylabel('Mutations Normalized')
            plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
        else:
            ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes, fontsize=12)
        ax.set_title(title, fontweight='bold')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def _plot_mutations_per_file(data, output_path):
    """Bar plot of total mutations per file."""
    sns.set_style("whitegrid")
    mutation_columns = [col for col in data.columns if 'mutations' in col and 'per_1k' not in col]
    data_with_totals = data.copy()
    data_with_totals['Total_Mutations'] = data[mutation_columns].sum(axis=1)
    plot_data = data_with_totals.dropna(subset=['FileName', 'Total_Mutations'])
    plt.figure(figsize=(16, 10))
    if len(plot_data) > 0:
        plot_data = plot_data.sort_values('Total_Mutations', ascending=True)
        bars = plt.bar(range(len(plot_data)), plot_data['Total_Mutations'], color='steelblue', alpha=0.7, edgecolor='black', linewidth=0.5)
        plt.title('Total Number of Mutations per File', fontsize=16, fontweight='bold', pad=20)
        plt.xlabel('Files'); plt.ylabel('Total Number of Mutations')
        plt.xticks(range(len(plot_data)), plot_data['FileName'], rotation=45, ha='right')
        max_val = plot_data['Total_Mutations'].max()
        for bar in bars:
            plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + max_val*0.01, f'{int(bar.get_height())}', ha='center', va='bottom', fontsize=8)
        stats_text = f"Mean: {plot_data['Total_Mutations'].mean():.0f}\nMedian: {plot_data['Total_Mutations'].median():.0f}\nMin: {plot_data['Total_Mutations'].min():.0f}\nMax: {max_val:.0f}"
        plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
        plt.grid(axis='y', alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)
        plt.title('Total Number of Mutations per File', fontweight='bold')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()
    return len(plot_data)

def plot_histograms_from_csv(csv_path, output_dir=None):
    """Reproduce histogram-style plots given a telomere analysis CSV path."""
    if output_dir is None:
        output_dir = os.path.dirname(csv_path) or '.'
    os.makedirs(output_dir, exist_ok=True)
    data = pd.read_csv(csv_path)
    hist_path = os.path.join(output_dir, "histogram.png")
    per_file_path = os.path.join(output_dir, "mutations_per_file_histogram.png")
    _plot_histograms_by_age_group(data, hist_path)
    num_files = _plot_mutations_per_file(data, per_file_path)
    print(f"Histogram plot saved as '{hist_path}'")
    print(f"Mutations per file histogram saved as '{per_file_path}'")
    print(f"Processed {num_files} files")

# %%
def plot_trendlines(data, output_path, variables, titles, version):
    """Plot linear trendlines of mutation rate variables vs Age in 2x2 grid."""
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    fig, axes = plt.subplots(2, 2, figsize=(20, 12))
    fig.suptitle(f'Mutation Rates vs Age [{version}]', fontsize=16, fontweight='bold')
    for i, (var, title) in enumerate(zip(variables, titles)):
        row, col = i // 2, i % 2
        ax = axes[row, col]
        plot_data = data.dropna(subset=['Age', var])
        if len(plot_data) > 0:
            sns.scatterplot(data=plot_data, x='Age', y=var, ax=ax, alpha=0.6)
            if len(plot_data) > 1:
                sns.regplot(data=plot_data, x='Age', y=var, ax=ax, scatter=False, line_kws={'color': 'blue', 'linestyle': '--'})
                slope, intercept, r_value, p_value, std_err = linregress(plot_data['Age'], plot_data[var])
                ax.set_title(f"{title}\nR² = {(r_value**2):.3f}", fontweight='bold')
            else:
                ax.set_title(title, fontweight='bold')
            ax.set_xlabel('Age'); ax.set_ylabel('Mutations Normalized')
        else:
            ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes, fontsize=12)
            ax.set_title(title, fontweight='bold')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def plot_spearman_trendlines(data, output_path, variables, titles, version):
    """Plot Spearman correlation scatterplots vs Age in 2x2 grid."""
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    fig, axes = plt.subplots(2, 2, figsize=(20, 12))
    fig.suptitle(f"Spearman's Rank Correlation: Mutation Rates vs Age [{version}]", fontsize=16, fontweight='bold')
    for i, (var, title) in enumerate(zip(variables, titles)):
        row, col = i // 2, i % 2
        ax = axes[row, col]
        plot_data = data.dropna(subset=['Age', var])
        if len(plot_data) > 1:
            corr, pval = spearmanr(plot_data['Age'], plot_data[var])
            sns.scatterplot(data=plot_data, x='Age', y=var, ax=ax, alpha=0.6)
            ax.set_title(f"{title}\nSpearman r = {corr:.2f}, p = {pval:.2g}", fontweight='bold')
        else:
            ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes, fontsize=12)
            ax.set_title(title, fontweight='bold')
        ax.set_xlabel('Age'); ax.set_ylabel('Mutations Normalized')
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def plot_trendlines_main(csv_path, trendline_output_path, spearman_output_path, variables, titles, patterns_file_path):
    """Main entry for 2x2 trendline and Spearman plots."""
    version = _get_patterns_version(patterns_file_path)
    data = pd.read_csv(csv_path)
    plot_trendlines(data, trendline_output_path, variables, titles, version)
    plot_spearman_trendlines(data, spearman_output_path, variables, titles, version)
    print(f"Trendline plot saved as '{trendline_output_path}'")
    print(f"Spearman correlation plot saved as '{spearman_output_path}'")

# %%
def plot_mutational_signature_row(row, mutation_types, mutation_columns, output_path, version):
    sns.set_style("whitegrid")
    sns.set_palette("husl")
    bar_heights, bar_colors, bar_labels = [], [], []
    all_columns = []
    for mut_type, contexts in mutation_columns.items():
        for context, cols in contexts.items():
            existing_cols = [col for col in cols if col in row.index]
            all_columns.extend(existing_cols)
    if not all_columns:
        print(f"Warning: No valid mutation columns found for {row.get('FileName', 'unknown')}")
        return
    total_mutations = row[all_columns].sum()
    for mut_label, color in mutation_types:
        contexts = mutation_columns[mut_label]
        for context_name, cols in contexts.items():
            for i, col in enumerate(cols):
                if col in row.index:
                    value = row[col]
                    percentage = (value / total_mutations) * 100 if total_mutations > 0 else 0
                    bar_heights.append(percentage)
                    bar_colors.append(color)
                    bar_labels.append(f"{mut_label} {context_name} pos{i+1}")
    if not bar_heights:
        print(f"Warning: No valid data found for {row.get('FileName', 'unknown')}")
        return
    x = np.arange(len(bar_heights))
    fig, ax = plt.subplots(figsize=(16, 10))
    sns.barplot(x=x, y=bar_heights, palette=bar_colors, ax=ax, edgecolor='black', linewidth=0.5)
    for i, label in enumerate(bar_labels):
        ax.text(i, -max(bar_heights)*0.02, label, ha='center', va='center', color='black', fontsize=9, fontweight='normal', rotation=45)
    ax.set_xticks([])
    ax.set_yticks(np.linspace(0, max(bar_heights), 6))
    ax.set_xlim(-0.5, len(bar_heights) - 0.5)
    ax.set_ylim(-max(bar_heights)*0.1, max(bar_heights) + max(bar_heights)*0.2)
    ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False); ax.spines['left'].set_visible(False)
    ax.yaxis.grid(True, linestyle='--', alpha=0.3)
    ax.set_axisbelow(True)
    ax.set_ylabel('Percentage of Single Base Modifications', fontsize=14, fontweight='bold')
    age = row['Age'] if 'Age' in row else 'N/A'
    filename = row['FileName'] if 'FileName' in row else 'sample'
    ax.set_title(f"Mutational Signatures by Position and Strand Context [{version}]\nFile: {filename} | Age: {age} years", fontsize=18, fontweight='bold', pad=30)
    plt.tight_layout(rect=[0, 0.15, 1, 0.95])
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    plt.close()

def plot_mutational_signatures(csv_path, patterns_file_path):
    sns.set_theme(style="whitegrid", font_scale=1.1)
    version = _get_patterns_version(patterns_file_path)
    df = pd.read_csv(csv_path)
    mutation_types = [('C>A','blue'),('C>G','black'),('C>T','red'),('G>A','gray'),('G>C','green'),('G>T','pink')]
    mutation_columns = {
        'C>A': {'C-strand': ['c_strand_mutations_C>A_c1','c_strand_mutations_C>A_c2','c_strand_mutations_C>A_c3'], 'G-strand': ['g_strand_mutations_G>T_g1','g_strand_mutations_G>T_g2','g_strand_mutations_G>T_g3']},
        'C>G': {'C-strand': ['c_strand_mutations_C>G_c1','c_strand_mutations_C>G_c2','c_strand_mutations_C>G_c3'], 'G-strand': ['g_strand_mutations_G>C_g1','g_strand_mutations_G>C_g2','g_strand_mutations_G>C_g3']},
        'C>T': {'C-strand': ['c_strand_mutations_C>T_c1','c_strand_mutations_C>T_c2','c_strand_mutations_C>T_c3'], 'G-strand': ['g_strand_mutations_G>A_g1','g_strand_mutations_G>A_g2','g_strand_mutations_G>A_g3']},
        'G>A': {'G-strand': ['g_strand_mutations_G>A_g1','g_strand_mutations_G>A_g2','g_strand_mutations_G>A_g3'], 'C-strand': ['c_strand_mutations_C>G_c1','c_strand_mutations_C>G_c2','c_strand_mutations_C>G_c3']},
        'G>C': {'G-strand': ['g_strand_mutations_G>C_g1','g_strand_mutations_G>C_g2','g_strand_mutations_G>C_g3'], 'C-strand': ['c_strand_mutations_C>T_c1','c_strand_mutations_C>T_c2','c_strand_mutations_C>T_c3']},
        'G>T': {'G-strand': ['g_strand_mutations_G>T_g1','g_strand_mutations_G>T_g2','g_strand_mutations_G>T_g3'], 'C-strand': ['c_strand_mutations_C>A_c1','c_strand_mutations_C>A_c2','c_strand_mutations_C>A_c3']},
    }
    os.makedirs('plots', exist_ok=True)
    for idx, row in df.iterrows():
        filename = str(row['FileName']) if 'FileName' in row else f'sample_{idx}'
        filename_base = os.path.splitext(filename)[0]
        output_path = os.path.join('plots', f'{filename_base}.png')
        plot_mutational_signature_row(row, mutation_types, mutation_columns, output_path, version)

def plot_mutational_signatures_main(patterns_file_path):
    csv_path = _default_csv_path_from_patterns(patterns_file_path)
    plot_mutational_signatures(csv_path, patterns_file_path)
    print("Mutational signature plots saved in 'plots/' directory")

# %%
def plot_spearman_with_age(csv_path, patterns_file_path):
    """Plot scatter of each numeric column vs Age with Spearman correlation."""
    sns.set_theme(style="whitegrid", font_scale=1.1)
    df = pd.read_csv(csv_path)
    output_dir = "spearman's plots"
    os.makedirs(output_dir, exist_ok=True)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if 'Age' not in numeric_cols:
        print("No 'Age' column found.")
        return
    numeric_cols = [c for c in numeric_cols if c != 'Age']
    df = df.dropna(subset=['Age'])
    spearman_results = []
    version = _get_patterns_version(patterns_file_path)
    for col in numeric_cols:
        sub_df = df.dropna(subset=[col])
        if sub_df.shape[0] < 2:
            continue
        x, y = sub_df['Age'], sub_df[col]
        corr, pval = stats.spearmanr(x, y)
        spearman_results.append({'Column': col, 'Spearman_r': corr, 'p_value': pval})
        plt.figure(figsize=(8, 6))
        ax = sns.scatterplot(x=x, y=y)
        if len(x) > 1:
            sns.regplot(x=x, y=y, scatter=False, ci=None, line_kws={'color': 'red', 'linestyle': '--'}, ax=ax)
        ax.set_xlabel('Age (years)'); ax.set_ylabel(col)
        ax.set_title(f"Spearman's ρ = {corr:.2f} (p={pval:.2g})\n{col} vs Age [{version}]", fontsize=14)
        plt.tight_layout()
        safe_col = col.replace('/', '_').replace(' ', '_').replace('>', 'to').replace('<', 'lt').replace(':', '_')
        plt.savefig(os.path.join(output_dir, f"{safe_col}_vs_Age.png"), dpi=200)
        plt.close()
    pd.DataFrame(spearman_results).to_csv(os.path.join(output_dir, "spearman_results.csv"), index=False)

def plot_spearman_with_age_main(patterns_file_path):
    csv_path = _default_csv_path_from_patterns(patterns_file_path)
    plot_spearman_with_age(csv_path, patterns_file_path)
    print("Spearman plots saved in \"spearman's plots/\" directory")

def plot_mutation_r_heatmap(csv_path, target_col='Age', patterns_file_path=None):
    """Heatmap of Spearman r values between per_1k mutation columns and target."""
    df = pd.read_csv(csv_path)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if target_col not in numeric_cols:
        print(f"No '{target_col}' column found.")
        return
    mutation_cols = [c for c in numeric_cols if 'per_1k' in c or 'per1k' in c]
    if 'total_mutations_per_1k_reads' in df.columns and 'total_mutations_per_1k_reads' not in mutation_cols:
        mutation_cols.append('total_mutations_per_1k_reads')
    total_mut_col = next((c for c in numeric_cols if 'total_mutation' in c and c not in mutation_cols), None)
    if total_mut_col:
        mutation_cols.append(total_mut_col)
    frameshift_cols = [c for c in numeric_cols if 'frameshift' in c.lower() and 'per_1k' in c]
    mutation_cols.extend([c for c in frameshift_cols if c not in mutation_cols])
    if not mutation_cols:
        print("No per_1k mutation columns found.")
        return
    df = df.dropna(subset=[target_col])
    r_values = []
    for col in mutation_cols:
        sub_df = df.dropna(subset=[col])
        r_values.append(stats.spearmanr(sub_df[col], sub_df[target_col])[0] if sub_df.shape[0] >= 2 else float('nan'))
    r_df = pd.DataFrame({'Mutation': mutation_cols, 'Spearman_r': r_values}).set_index('Mutation')
    plt.figure(figsize=(max(8, len(mutation_cols)*0.4), 2.5))
    sns.heatmap(r_df.T, annot=True, cmap='coolwarm', center=0, cbar_kws={'label': "Spearman's r"})
    version = _get_patterns_version(patterns_file_path) if patterns_file_path else 'unknown'
    plt.title(f"Spearman r values: Normalized Mutations vs {target_col} [{version}]")
    plt.yticks(rotation=0)
    plt.tight_layout()
    output_dir = "spearman's plots"
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, f"mutation_r_heatmap_vs_{target_col}.png")
    plt.savefig(output_path, dpi=200)
    plt.close()
    print(f"Mutation r heatmap saved as {output_path}")

def plot_pairwise_r_heatmap(csv_path, patterns_file_path=None):
    """Pairwise Spearman r heatmap between per_1k, Age, telomere columns."""
    df = pd.read_csv(csv_path)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    mutation_cols = [c for c in numeric_cols if 'per_1k' in c or 'per1k' in c]
    if 'total_mutations_per_1k_reads' in df.columns and 'total_mutations_per_1k_reads' not in mutation_cols:
        mutation_cols.append('total_mutations_per_1k_reads')
    total_mut_col = next((c for c in numeric_cols if 'total_mutation' in c and c not in mutation_cols), None)
    if total_mut_col:
        mutation_cols.append(total_mut_col)
    frameshift_cols = [c for c in numeric_cols if 'frameshift' in c.lower() and 'per_1k' in c]
    mutation_cols.extend([c for c in frameshift_cols if c not in mutation_cols])
    if 'Total_Reads' in df.columns and 'Total_Reads' in numeric_cols and 'Total_Reads' not in mutation_cols:
        mutation_cols.append('Total_Reads')
    if 'Age' in df.columns and 'Age' in numeric_cols and 'Age' not in mutation_cols:
        mutation_cols.append('Age')
    telomere_cols = [c for c in df.columns if 'telomere' in c.lower() and c in numeric_cols and c not in mutation_cols]
    mutation_cols.extend(telomere_cols)
    if not mutation_cols:
        print("No relevant columns for pairwise heatmap.")
        return
    n = len(mutation_cols)
    r_matrix = np.zeros((n, n))
    for i, col1 in enumerate(mutation_cols):
        for j, col2 in enumerate(mutation_cols):
            sub_df = df[[col1, col2]].dropna()
            r_val = stats.spearmanr(sub_df[col1], sub_df[col2])[0] if sub_df.shape[0] >= 2 else np.nan
            r_matrix[i, j] = float(r_val) if isinstance(r_val, numbers.Number) and not isinstance(r_val, (list, tuple, np.ndarray)) else np.nan
    mask = np.eye(n, dtype=bool)
    fig_width, fig_height = max(10, n*0.7), max(8, n*0.7)
    plt.figure(figsize=(fig_width, fig_height))
    ax = sns.heatmap(r_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0, mask=mask,
                     xticklabels=mutation_cols, yticklabels=mutation_cols, cbar_kws={'label': "Spearman's r"}, annot_kws={"size": 8})
    for i in range(n):
        ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False, edgecolor='black', lw=2, hatch='xx'))
    version = _get_patterns_version(patterns_file_path) if patterns_file_path else 'unknown'
    plt.title(f"Pairwise Spearman r Heatmap (Normalized Mutations, Age, Telomere) [{version}]", fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=9)
    plt.yticks(fontsize=9)
    plt.tight_layout()
    output_dir = "spearman's plots"
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, "pairwise_mutation_r_heatmap.png")
    plt.savefig(output_path, dpi=200)
    plt.close()
    print(f"Pairwise mutation r heatmap saved as {output_path}")

def plot_pairwise_r_heatmap_main(patterns_file_path):
    csv_path = _default_csv_path_from_patterns(patterns_file_path)
    plot_pairwise_r_heatmap(csv_path, patterns_file_path=patterns_file_path)

# %% [markdown]
# ## Run All Plots (equivalent to: main.py run / main.py plot)
#
# Run the cell below to execute the full plotting pipeline: histograms, mutational signatures, Spearman correlations, pairwise heatmap, trendlines, and curve fitting.

# %%
# Run full plotting pipeline
print("[2/2] Running plots ...")
os.makedirs(_HISTOGRAM_DIR, exist_ok=True)
plot_histograms_from_csv(csv_path, output_dir=_HISTOGRAM_DIR)

# Spearman correlations (version label comes from PATTERNS_VERSION derived from REPEAT_K)
plot_spearman_with_age(csv_path, patterns_file_path=None)
print("Spearman plots saved in \"spearman's plots/\" directory")

plot_pairwise_r_heatmap(csv_path, patterns_file_path=None)

# Trendlines
def _unique_output_path(directory, base_name, ext):
    os.makedirs(directory, exist_ok=True)
    timestamp = datetime.now().strftime('%Y-%m-%d_%H%M%S')
    return os.path.join(directory, f"{base_name}_{timestamp}.{ext}")

_TRENDLINE_VARIABLES = [
    "total_mutations_over_total_g_strand_per_1k",
    "g_strand_T>C_sum_per_1k",
    "g_strand_G>T_sum_per_1k",
    "g_strand_T>G_sum_per_1k",
]
_TRENDLINE_TITLES = [
    "Total Mutations Normalized",
    "T > C Mutation Rate Normalized",
    "G > T Mutation Rate Normalized",
    "T > G Mutation Rate Normalized",
]
trendline_output = _unique_output_path(_TRENDLINES_DIR, "trendline", "png")
spearman_output = _unique_output_path(_SPEARMAN_CORRELATIONS_DIR, "spearman_correlation", "png")
plot_trendlines_main(csv_path, trendline_output, spearman_output, _TRENDLINE_VARIABLES, _TRENDLINE_TITLES, None)

print("\nAll plotting complete.")
# Out:
# [2/2] Running plots ...
# Histogram plot saved as '/opt/notebooks/histograms/histogram.png'
# Mutations per file histogram saved as '/opt/notebooks/histograms/mutations_per_file_histogram.png'
# Processed 1 files
# Spearman plots saved in "spearman's plots/" directory
# /opt/conda/lib/python3.12/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /opt/conda/lib/python3.12/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /opt/conda/lib/python3.12/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# Pairwise mutation r heatmap saved as spearman's plots/pairwise_mutation_r_heatmap.png
# Trendline plot saved as '/opt/notebooks/trendlines/trendline_2026-04-17_225356.png'
# Spearman correlation plot saved as '/opt/notebooks/spearman_correlations/spearman_correlation_2026-04-17_225356.png'
#
# All plotting complete.
